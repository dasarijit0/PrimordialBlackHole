# %%
import numpy as np 
from astropy.io import fits
import os
import time
import matplotlib.pyplot as plt
import scipy.special as sp

# %%
4*np.pi/137.036
# Out:
# 0.09170123627630092

# %%
M = 1.e21
T = 1/8/np.pi/M
Temp = 1/8/np.pi/M

# %%
file1 = open('M1L1.txt','r')
array_results_l1 = np.zeros((116,13),dtype=float)
print(array_results_l1.shape)
count = 0
count2 = 0 
omegas_l1 = []

for line in file1:
    if count%3 == 0:
        line_val = line.strip()
        omegas_l1.append(float(line_val))
        print("count mod 3 " + str(count))
    if count%3 !=0:
        line_vals = line.strip().split('\t')
        #array_results[count2]=line_vals[:]
        #print(np.array(line_vals))
        print(count)
        print("count 2 "+ str(count2))
        array_results_l1[count2][:]=np.array(line_vals)[:]
        count2+=1
    count+=1

        
file1.close()
# Out:
# (116, 13)
# count mod 3 0
# 1
# count 2 0
# 2
# count 2 1
# count mod 3 3
# 4
# count 2 2
# 5
# count 2 3
# count mod 3 6
# 7
# count 2 4
# 8
# count 2 5
# count mod 3 9
# 10
# count 2 6
# 11
# count 2 7
# count mod 3 12
# 13
# count 2 8
# 14
# count 2 9
# count mod 3 15
# 16
# count 2 10
# 17
# count 2 11
# count mod 3 18
# 19
# count 2 12
# 20
# count 2 13
# count mod 3 21
# 22
# count 2 14
# 23
# count 2 15
# count mod 3 24
# 25
# count 2 16
# 26
# count 2 17
# count mod 3 27
# 28
# count 2 18
# 29
# count 2 19
# count mod 3 30
# 31
# count 2 20
# 32
# count 2 21
# count mod 3 33
# 34
# count 2 22
# 35
# count 2 23
# count mod 3 36
# 37
# count 2 24
# 38
# count 2 25
# count mod 3 39
# 40
# count 2 26
# 41
# count 2 27
# count mod 3 42
# 43
# count 2 28
# 44
# count 2 29
# count mod 3 45
# 46
# count 2 30
# 47
# count 2 31
# count mod 3 48
# 49
# count 2 32
# 50
# count 2 33
# count mod 3 51
# 52
# count 2 34
# 53
# count 2 35
# count mod 3 54
# 55
# count 2 36
# 56
# count 2 37
# ...

# %%
file1 = open('M1L2.txt','r')
array_results_l2 = np.zeros((116,13),dtype=float)
print(array_results_l2.shape)
count = 0
count2 = 0 
omegas_l2 = []

for line in file1:
    if count%3 == 0:
        line_val = line.strip()
        omegas_l2.append(float(line_val))
        print("count mod 3 " + str(count))
    if count%3 !=0:
        line_vals = line.strip().split('\t')
        #array_results[count2]=line_vals[:]
        #print(np.array(line_vals))
        print(count)
        print("count 2 "+ str(count2))
        array_results_l2[count2][:]=np.array(line_vals)[:]
        count2+=1
    
    count+=1

        
file1.close()
# Out:
# (116, 13)
# count mod 3 0
# 1
# count 2 0
# 2
# count 2 1
# count mod 3 3
# 4
# count 2 2
# 5
# count 2 3
# count mod 3 6
# 7
# count 2 4
# 8
# count 2 5
# count mod 3 9
# 10
# count 2 6
# 11
# count 2 7
# count mod 3 12
# 13
# count 2 8
# 14
# count 2 9
# count mod 3 15
# 16
# count 2 10
# 17
# count 2 11
# count mod 3 18
# 19
# count 2 12
# 20
# count 2 13
# count mod 3 21
# 22
# count 2 14
# 23
# count 2 15
# count mod 3 24
# 25
# count 2 16
# 26
# count 2 17
# count mod 3 27
# 28
# count 2 18
# 29
# count 2 19
# count mod 3 30
# 31
# count 2 20
# 32
# count 2 21
# count mod 3 33
# 34
# count 2 22
# 35
# count 2 23
# count mod 3 36
# 37
# count 2 24
# 38
# count 2 25
# count mod 3 39
# 40
# count 2 26
# 41
# count 2 27
# count mod 3 42
# 43
# count 2 28
# 44
# count 2 29
# count mod 3 45
# 46
# count 2 30
# 47
# count 2 31
# count mod 3 48
# 49
# count 2 32
# 50
# count 2 33
# count mod 3 51
# 52
# count 2 34
# 53
# count 2 35
# count mod 3 54
# 55
# count 2 36
# 56
# count 2 37
# ...

# %%
file1 = open('M1L3.txt','r')
array_results_l3 = np.zeros((116,13),dtype=float)
print(array_results_l3.shape)
count = 0
count2 = 0 
omegas_l3 = []

for line in file1:
    if count%3 == 0:
        line_val = line.strip()
        omegas_l3.append(float(line_val))
        print("count mod 3 "+ str(count))
    if count%3 !=0:
        line_vals = line.strip().split('\t')
        #array_results[count2]=line_vals[:]
        #print(np.array(line_vals))
        print(count)
        print("count 2 "+ str(count2))
        array_results_l3[count2][:]=np.array(line_vals)[:]
        count2+=1
    
    count+=1

        
file1.close()
# Out:
# (116, 13)
# count mod 3 0
# 1
# count 2 0
# 2
# count 2 1
# count mod 3 3
# 4
# count 2 2
# 5
# count 2 3
# count mod 3 6
# 7
# count 2 4
# 8
# count 2 5
# count mod 3 9
# 10
# count 2 6
# 11
# count 2 7
# count mod 3 12
# 13
# count 2 8
# 14
# count 2 9
# count mod 3 15
# 16
# count 2 10
# 17
# count 2 11
# count mod 3 18
# 19
# count 2 12
# 20
# count 2 13
# count mod 3 21
# 22
# count 2 14
# 23
# count 2 15
# count mod 3 24
# 25
# count 2 16
# 26
# count 2 17
# count mod 3 27
# 28
# count 2 18
# 29
# count 2 19
# count mod 3 30
# 31
# count 2 20
# 32
# count 2 21
# count mod 3 33
# 34
# count 2 22
# 35
# count 2 23
# count mod 3 36
# 37
# count 2 24
# 38
# count 2 25
# count mod 3 39
# 40
# count 2 26
# 41
# count 2 27
# count mod 3 42
# 43
# count 2 28
# 44
# count 2 29
# count mod 3 45
# 46
# count 2 30
# 47
# count 2 31
# count mod 3 48
# 49
# count 2 32
# 50
# count 2 33
# count mod 3 51
# 52
# count 2 34
# 53
# count 2 35
# count mod 3 54
# 55
# count 2 36
# 56
# count 2 37
# ...

# %%
file1 = open('M1L4.txt','r')
array_results_l4 = np.zeros((116,13),dtype=float)
print(array_results_l4.shape)
count = 0
count2 = 0 
omegas_l4 = []

for line in file1:
    if count%3 == 0:
        line_val = line.strip()
        omegas_l4.append(float(line_val))
        print("count mod 3 "+ str(count))
    if count%3 !=0:
        line_vals = line.strip().split('\t')
        #array_results[count2]=line_vals[:]
        #print(np.array(line_vals))
        print(count)
        print("count 2 "+ str(count2))
        array_results_l4[count2][:]=np.array(line_vals)[:]
        count2+=1
    
    count+=1

        
file1.close()
# Out:
# (116, 13)
# count mod 3 0
# 1
# count 2 0
# 2
# count 2 1
# count mod 3 3
# 4
# count 2 2
# 5
# count 2 3
# count mod 3 6
# 7
# count 2 4
# 8
# count 2 5
# count mod 3 9
# 10
# count 2 6
# 11
# count 2 7
# count mod 3 12
# 13
# count 2 8
# 14
# count 2 9
# count mod 3 15
# 16
# count 2 10
# 17
# count 2 11
# count mod 3 18
# 19
# count 2 12
# 20
# count 2 13
# count mod 3 21
# 22
# count 2 14
# 23
# count 2 15
# count mod 3 24
# 25
# count 2 16
# 26
# count 2 17
# count mod 3 27
# 28
# count 2 18
# 29
# count 2 19
# count mod 3 30
# 31
# count 2 20
# 32
# count 2 21
# count mod 3 33
# 34
# count 2 22
# 35
# count 2 23
# count mod 3 36
# 37
# count 2 24
# 38
# count 2 25
# count mod 3 39
# 40
# count 2 26
# 41
# count 2 27
# count mod 3 42
# 43
# count 2 28
# 44
# count 2 29
# count mod 3 45
# 46
# count 2 30
# 47
# count 2 31
# count mod 3 48
# 49
# count 2 32
# 50
# count 2 33
# count mod 3 51
# 52
# count 2 34
# 53
# count 2 35
# count mod 3 54
# 55
# count 2 36
# 56
# count 2 37
# ...

# %%
file1 = open('M1L5.txt','r')
array_results_l5 = np.zeros((116,13),dtype=float)
print(array_results_l5.shape)
count = 0
count2 = 0 
omegas_l5 = []

for line in file1:
    if count%3 == 0:
        line_val = line.strip()
        omegas_l5.append(float(line_val))
        print("count mod 3 "+ str(count))
    if count%3 !=0:
        line_vals = line.strip().split('\t')
        #array_results[count2]=line_vals[:]
        #print(np.array(line_vals))
        print(count)
        print("count 2 "+ str(count2))
        array_results_l5[count2][:]=np.array(line_vals)[:]
        count2+=1
    
    count+=1

        
file1.close()
# Out:
# (116, 13)
# count mod 3 0
# 1
# count 2 0
# 2
# count 2 1
# count mod 3 3
# 4
# count 2 2
# 5
# count 2 3
# count mod 3 6
# 7
# count 2 4
# 8
# count 2 5
# count mod 3 9
# 10
# count 2 6
# 11
# count 2 7
# count mod 3 12
# 13
# count 2 8
# 14
# count 2 9
# count mod 3 15
# 16
# count 2 10
# 17
# count 2 11
# count mod 3 18
# 19
# count 2 12
# 20
# count 2 13
# count mod 3 21
# 22
# count 2 14
# 23
# count 2 15
# count mod 3 24
# 25
# count 2 16
# 26
# count 2 17
# count mod 3 27
# 28
# count 2 18
# 29
# count 2 19
# count mod 3 30
# 31
# count 2 20
# 32
# count 2 21
# count mod 3 33
# 34
# count 2 22
# 35
# count 2 23
# count mod 3 36
# 37
# count 2 24
# 38
# count 2 25
# count mod 3 39
# 40
# count 2 26
# 41
# count 2 27
# count mod 3 42
# 43
# count 2 28
# 44
# count 2 29
# count mod 3 45
# 46
# count 2 30
# 47
# count 2 31
# count mod 3 48
# 49
# count 2 32
# 50
# count 2 33
# count mod 3 51
# 52
# count 2 34
# 53
# count 2 35
# count mod 3 54
# 55
# count 2 36
# 56
# count 2 37
# ...

# %%
print(np.array(omegas_l1))
print(np.array(omegas_l2))
print(np.array(omegas_l3))
# Out:
# [ 0.05  0.06  0.07  0.09  0.11  0.14  0.17  0.2   0.25  0.31  0.37  0.46
#   0.56  0.68  0.84  1.02  1.25  1.5   1.75  2.    2.25  2.5   2.75  3.
#   3.25  3.5   3.75  4.    4.25  4.5   4.75  5.    5.25  5.5   5.75  6.
#   6.25  6.5   6.75  7.    7.25  7.5   7.75  8.    8.5   9.    9.5  10.
#  10.5  11.   11.5  12.   12.5  13.   13.5  14.   14.5  15.  ]
# [ 0.05  0.06  0.07  0.09  0.11  0.14  0.17  0.2   0.25  0.31  0.37  0.46
#   0.56  0.68  0.84  1.02  1.25  1.5   1.75  2.    2.25  2.5   2.75  3.
#   3.25  3.5   3.75  4.    4.25  4.5   4.75  5.    5.25  5.5   5.75  6.
#   6.25  6.5   6.75  7.    7.25  7.5   7.75  8.    8.5   9.    9.5  10.
#  10.5  11.   11.5  12.   12.5  13.   13.5  14.   14.5  15.  ]
# [ 0.05  0.06  0.07  0.09  0.11  0.14  0.17  0.2   0.25  0.31  0.37  0.46
#   0.56  0.68  0.84  1.02  1.25  1.5   1.75  2.    2.25  2.5   2.75  3.
#   3.25  3.5   3.75  4.    4.25  4.5   4.75  5.    5.25  5.5   5.75  6.
# ...

# %%
print(np.array(omegas_l4))
print(np.array(omegas_l5))
# Out:
# [ 0.05  0.06  0.07  0.09  0.11  0.14  0.17  0.2   0.25  0.31  0.37  0.46
#   0.56  0.68  0.84  1.02  1.25  1.5   1.75  2.    2.25  2.5   2.75  3.
#   3.25  3.5   3.75  4.    4.25  4.5   4.75  5.    5.25  5.5   5.75  6.
#   6.25  6.5   6.75  7.    7.25  7.5   7.75  8.    8.5   9.    9.5  10.
#  10.5  11.   11.5  12.   12.5  13.   13.5  14.   14.5  15.  ]
# [ 0.05  0.06  0.07  0.09  0.11  0.14  0.17  0.2   0.25  0.31  0.37  0.46
#   0.56  0.68  0.84  1.02  1.25  1.5   1.75  2.    2.25  2.5   2.75  3.
#   3.25  3.5   3.75  4.    4.25  4.5   4.75  5.    5.25  5.5   5.75  6.
#   6.25  6.5   6.75  7.    7.25  7.5   7.75  8.    8.5   9.    9.5  10.
#  10.5  11.   11.5  12.   12.5  13.   13.5  14.   14.5  15.  ]

# %%
over_omega = 1/np.array(omegas_l1)
#over_omega2 = 1/np.array(omegas_l2)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
for i in range(0,len(omegas_l1),1):
    ax.scatter(omegas_l1[i],np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:]), label = 'l1', color='r')

for i in range(0,len(omegas_l2),1):
    ax.scatter(omegas_l2[i],np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:]), label = 'l2',color='g')

for i in range(0,len(omegas_l3),1):
    ax.scatter(omegas_l3[i],np.sum(array_results_l3[2*i][:])+np.sum(array_results_l3[2*i +1][:]), label = 'l3',color='b')

for i in range(0,len(omegas_l4),1):
    ax.scatter(omegas_l4[i],np.sum(array_results_l4[2*i][:])+np.sum(array_results_l4[2*i +1][:]), label = 'l4',color='orange')

for i in range(0,len(omegas_l5),1):
    ax.scatter(omegas_l5[i],np.sum(array_results_l5[2*i][:])+np.sum(array_results_l5[2*i +1][:]), label = 'l5',color='magenta')

#ax.scatter(0.05, np.abs(np.sum(array_results_l3wrong[0][:]+array_results_l3wrong[1][:])),color='black')
#ax[0].legend()
ax.set_xscale('log')
handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0],handles[-1]],[labels[0],labels[-1]])
ax.legend([handles[0]],[labels[0]])

plt.yscale('log')
#plt.yscale('symlog')
ax.set_xlim(.05,15)
#ax.set_ylim(-1.e-4,2.e-4)
ax.set_title('all omega total')

"""

#plt.savefig('allomegatotal_zoomed.pdf',bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True)
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:]), label = 'l1', color='r')

#for i in range(0,len(omegas_l2),1):
   # ax.scatter(omegas_l2[i],np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:]), label = 'l2',color='g')

for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],np.sum(array_results_l3[2*i][:])+np.sum(array_results_l3[2*i +1][:]), label = 'l3',color='b')

    
#ax[0].legend()
ax[0].set_xscale('log')
handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-1]],[labels[0],labels[-1]])

ax[0].set_yscale('log')
#plt.yscale('symlog')
#ax.set_xlim(5,15)
#ax.set_ylim(-1.e-4,2.e-4)
ax[0].set_title('all omega total')

for i in range(0,len(omegas_l1),1):
    ax[1].scatter(omegas_l1[i],np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:])/np.sum(array_results_l3[2*i][:])+np.sum(array_results_l3[2*i +1][:]), label = 'l1/l3', color='g')

ax[1].set_ylim(-4,4)
#plt.savefig('allomegatotal_zoomed.pdf',bbox_inches='tight')
plt.show()

                              """
# Out:
# "\n\n#plt.savefig('allomegatotal_zoomed.pdf',bbox_inches='tight')\nplt.show()\n\nfig, ax = plt.subplots(nrows=2, ncols=1,sharex=True)\nfor i in range(0,len(omegas_l1),1):\n    ax[0].scatter(omegas_l1[i],np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:]), label = 'l1', color='r')\n\n#for i in range(0,len(omegas_l2),1):\n   # ax.scatter(omegas_l2[i],np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:]), label = 'l2',color='g')\n\nfor i in range(0,len(omegas_l3),1):\n    ax[0].scatter(omegas_l3[i],np.sum(array_results_l3[2*i][:])+np.sum(array_results_l3[2*i +1][:]), label = 'l3',color='b')\n\n    \n#ax[0].legend()\nax[0].set_xscale('log')\nhandles, labels = ax[0].get_legend_handles_labels()\nax[0].legend([handles[0],handles[-1]],[labels[0],labels[-1]])\n\nax[0].set_yscale('log')\n#plt.yscale('symlog')\n#ax.set_xlim(5,15)\n#ax.set_ylim(-1.e-4,2.e-4)\nax[0].set_title('all omega total')\n\nfor i in range(0,len(omegas_l1),1):\n    ax[1].scatter(omegas_l1[i],
# ...

# %% [markdown]
# xi = k*r_max = omega * 2000/(8 pi T) = 80 * omega (in units of Th)
# xi^2 * (spherical_bessel_l(xi))^2 + (xi*spherical_bessel_l(xi)' + spherical_bessel_l(xi))^2

# %%
"""fig, ax = plt.subplots(nrows=1, ncols=1)
for i in range(0,len(omegas_l1),1):
    xi = 80*omegas_l1[i]
    r1 = (1+np.cos(2*xi)/(xi**2))
    ax.scatter(omegas_l1[i],np.abs(np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:])), label = 'l1', color='r')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*r1*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*r1*array_results_l1[2*i +1][:])),label='l1*omega*scaling',color='black')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*array_results_l1[2*i +1][:])),label='l1*omega',color='purple')
#for
for i in range(0,len(omegas_l2),1):
    xi = 80*omegas_l1[i]
    r2 = (xi**2) *(sp.spherical_jn(2, xi)**2) + (xi*sp.spherical_jn(2, xi,derivative=True) + (scipy.special.spherical_jn(2, xi)))**2
    
    ax.scatter(omegas_l2[i],np.abs(np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:])), label = 'l2',color='g')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*array_results_l2[2*i][:])+np.sum(omegas_l4[i]*array_results_l2[2*i +1][:])),label='l2*omega',color='cyan')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r2*array_results_l2[2*i][:])+np.sum(omegas_l4[i]*r2*array_results_l2[2*i +1][:])),label='l2*rescaling*omega',color='black')


for i in range(0,len(omegas_l3),1):
    xi = 80*omegas_l1[i]
    r3 = (xi**2) *(sp.spherical_jn(3, xi)**2) + (xi*sp.spherical_jn(3, xi,derivative=True) + (scipy.special.spherical_jn(3, xi)))**2
    
    ax.scatter(omegas_l3[i],np.abs(np.sum(array_results_l3[2*i][:])+np.sum(array_results_l3[2*i +1][:])), label = 'l3',color='b')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*array_results_l3[2*i][:])+np.sum(omegas_l4[i]*array_results_l3[2*i +1][:])),label='l3*omega',color='magenta')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r3*array_results_l3[2*i][:])+np.sum(omegas_l4[i]*r3*array_results_l3[2*i +1][:])),label='l3*rescaliny*omega',color='black')

for i in range(0,len(omegas_l3),1):
    xi = 80*omegas_l1[i]
    r4 = (xi**2) *(sp.spherical_jn(4, xi)**2) + (xi*sp.spherical_jn(4, xi,derivative=True) + (scipy.special.spherical_jn(4, xi)))**2
    
    ax.scatter(omegas_l4[i],np.abs(np.sum(array_results_l4[2*i][:])+np.sum(array_results_l4[2*i +1][:])), label = 'l4',color='orange')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*array_results_l4[2*i][:])+np.sum(omegas_l4[i]*array_results_l4[2*i +1][:])),label='l4*omega',color='lime')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r4*array_results_l4[2*i][:])+np.sum(omegas_l4[i]*r4*array_results_l4[2*i +1][:])),label='l4*rescaling*omega',color='black')
for i in range(0,len(omegas_l3),1):
    
    ax.scatter(omegas_l5[i],np.abs(np.sum(array_results_l5[2*i][:])+np.sum(array_results_l5[2*i +1][:])), label = 'l5',color='magenta')

#ax.legend()
#ax.scatter(0.05, np.abs(np.sum(array_results_l3wrong[0][:]+array_results_l3wrong[1][:])),color='black')

#ax.plot(omegas_l1,5.e-6*over_omega,label = 'scaling of 1/$\omega$')
ax.set_xscale('log')
plt.yscale('log')
#plt.yscale('symlog')
handles, labels = ax.get_legend_handles_labels()

#ax.legend([handles[0],handles[-1]],[labels[0],labels[-1]])
ax.legend([handles[0],handles[60],handles[130],handles[-1]],[labels[0],labels[60],labels[120],labels[-1]])
#ax.set_ylim(0,1e-5)
ax.set_xlim(.04,10)
ax.set_ylim(1.e-8,1.e-2)
ax.set_title('all omega total abs')
plt.savefig("PBH/totalabs.pdf",bbox_inches='tight')
plt.show()

"""
# Out:
# 'fig, ax = plt.subplots(nrows=1, ncols=1)\nfor i in range(0,len(omegas_l1),1):\n    xi = 80*omegas_l1[i]\n    r1 = (1+np.cos(2*xi)/(xi**2))\n    ax.scatter(omegas_l1[i],np.abs(np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:])), label = \'l1\', color=\'r\')\n    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*r1*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*r1*array_results_l1[2*i +1][:])),label=\'l1*omega*scaling\',color=\'black\')\n    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*array_results_l1[2*i +1][:])),label=\'l1*omega\',color=\'purple\')\n#for\nfor i in range(0,len(omegas_l2),1):\n    xi = 80*omegas_l1[i]\n    r2 = (xi**2) *(sp.spherical_jn(2, xi)**2) + (xi*sp.spherical_jn(2, xi,derivative=True) + (scipy.special.spherical_jn(2, xi)))**2\n    \n    ax.scatter(omegas_l2[i],np.abs(np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:])), label = \'l2\',color=\'g\')\n    #ax.scatter(omegas_l
# ...

# %%
"""fig, ax = plt.subplots(nrows=1, ncols=1)
for i in range(0,len(omegas_l1),1):
    xi = 80*omegas_l1[i]
    r1 = (1+np.cos(2*xi)/(xi**2))
    #ax.scatter(omegas_l1[i],np.abs(np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:])), label = 'l1', color='r')
    ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*array_results_l1[2*i +1][:])),label='l1 data*omega',color='black')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*array_results_l1[2*i +1][:])),label='l1*omega',color='purple')
#for
for i in range(0,len(omegas_l2),1):
    xi = 80*omegas_l1[i]
    r2 = (xi**2) *(sp.spherical_jn(2, xi)**2) + (xi*sp.spherical_jn(2, xi,derivative=True) + (scipy.special.spherical_jn(2, xi)))**2
    
    #ax.scatter(omegas_l2[i],np.abs(np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:])), label = 'l2',color='g')
    ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*array_results_l2[2*i][:])+np.sum(omegas_l4[i]*array_results_l2[2*i +1][:])),label='l2 data*omega',color='cyan')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r2*array_results_l2[2*i][:])+np.sum(omegas_l4[i]*r2*array_results_l2[2*i +1][:])),label='l2*rescaling*omega',color='black')


for i in range(0,len(omegas_l3),1):
    xi = 80*omegas_l1[i]
    r3 = (xi**2) *(sp.spherical_jn(3, xi)**2) + (xi*sp.spherical_jn(3, xi,derivative=True) + (scipy.special.spherical_jn(3, xi)))**2
    
    #ax.scatter(omegas_l3[i],np.abs(np.sum(array_results_l3[2*i][:])+np.sum(array_results_l3[2*i +1][:])), label = 'l3',color='b')
    ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*array_results_l3[2*i][:])+np.sum(omegas_l4[i]*array_results_l3[2*i +1][:])),label='l3 data *omega',color='magenta')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r3*array_results_l3[2*i][:])+np.sum(omegas_l4[i]*r3*array_results_l3[2*i +1][:])),label='l3*rescaliny*omega',color='black')

for i in range(0,len(omegas_l3),1):
    xi = 80*omegas_l1[i]
    r4 = (xi**2) *(sp.spherical_jn(4, xi)**2) + (xi*sp.spherical_jn(4, xi,derivative=True) + (scipy.special.spherical_jn(4, xi)))**2
    
    #ax.scatter(omegas_l4[i],np.abs(np.sum(array_results_l4[2*i][:])+np.sum(array_results_l4[2*i +1][:])), label = 'l4',color='orange')
    ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*array_results_l4[2*i][:])+np.sum(omegas_l4[i]*array_results_l4[2*i +1][:])),label='l4 data*omega',color='lime')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r4*array_results_l4[2*i][:])+np.sum(omegas_l4[i]*r4*array_results_l4[2*i +1][:])),label='l4*rescaling*omega',color='black')
for i in range(0,len(omegas_l3),1):
    xi = 80*omegas_l1[i]
    #r4 = (xi**2) *(sp.spherical_jn(4, xi)**2) + (xi*sp.spherical_jn(4, xi,derivative=True) + (scipy.special.spherical_jn(4, xi)))**2
    
    #ax.scatter(omegas_l4[i],np.abs(np.sum(array_results_l4[2*i][:])+np.sum(array_results_l4[2*i +1][:])), label = 'l4',color='orange')
    ax.scatter(omegas_l5[i],np.abs(np.sum(omegas_l5[i]*array_results_l5[2*i][:])+np.sum(omegas_l5[i]*array_results_l5[2*i +1][:])),label='l4 data*omega',color='olive')

#ax.legend()
#ax.scatter(0.05, np.abs(np.sum(array_results_l3wrong[0][:]+array_results_l3wrong[1][:])),color='black')

#ax.plot(omegas_l1,5.e-6*over_omega,label = 'scaling of 1/$\omega$')
ax.set_xscale('log')
plt.yscale('log')
#plt.yscale('symlog')
handles, labels = ax.get_legend_handles_labels()

#ax.legend([handles[0],handles[-1]],[labels[0],labels[-1]])
ax.legend([handles[0],handles[60],handles[130],handles[-1]],[labels[0],labels[60],labels[120],labels[-1]])
#ax.set_ylim(0,1e-5)
ax.set_xlim(.04,16)
ax.set_ylim(1.e-8,1.e-4)
ax.set_title('omega* dN/dw dt')
plt.savefig("PBH/omegatimesdata.pdf",bbox_inches='tight')
plt.show()

"""
# Out:
# 'fig, ax = plt.subplots(nrows=1, ncols=1)\nfor i in range(0,len(omegas_l1),1):\n    xi = 80*omegas_l1[i]\n    r1 = (1+np.cos(2*xi)/(xi**2))\n    #ax.scatter(omegas_l1[i],np.abs(np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:])), label = \'l1\', color=\'r\')\n    ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*array_results_l1[2*i +1][:])),label=\'l1 data*omega\',color=\'black\')\n    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*array_results_l1[2*i +1][:])),label=\'l1*omega\',color=\'purple\')\n#for\nfor i in range(0,len(omegas_l2),1):\n    xi = 80*omegas_l1[i]\n    r2 = (xi**2) *(sp.spherical_jn(2, xi)**2) + (xi*sp.spherical_jn(2, xi,derivative=True) + (scipy.special.spherical_jn(2, xi)))**2\n    \n    #ax.scatter(omegas_l2[i],np.abs(np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:])), label = \'l2\',color=\'g\')\n    ax.scatter(omegas_l1[i],np.a
# ...

# %%
import scipy

# %%
"""fig, ax = plt.subplots(nrows=1, ncols=1)
for i in range(0,len(omegas_l1),1):
    xi = 2000*omegas_l1[i]/8/np.pi
    r1 = (1+np.cos(2*xi)/(xi**2))
    #ax.scatter(omegas_l1[i],np.abs(np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:])), label = 'l1', color='r')
    ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*r1*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*r1*array_results_l1[2*i +1][:])),label='l1 data*omega*rescaling',color='black')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*array_results_l1[2*i +1][:])),label='l1*omega',color='purple')
#for
for i in range(0,len(omegas_l2),1):
    xi = 2000*omegas_l1[i]/8/np.pi
    r2 = (xi**2) *(sp.spherical_jn(2, xi)**2) + (xi*sp.spherical_jn(2, xi,derivative=True) + (scipy.special.spherical_jn(2, xi)))**2
    
    #ax.scatter(omegas_l2[i],np.abs(np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:])), label = 'l2',color='g')
    ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r2*array_results_l2[2*i][:])+np.sum(omegas_l4[i]*r2*array_results_l2[2*i +1][:])),label='l2 data*omega*rescaling',color='cyan')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r2*array_results_l2[2*i][:])+np.sum(omegas_l4[i]*r2*array_results_l2[2*i +1][:])),label='l2*rescaling*omega',color='black')


for i in range(0,len(omegas_l3),1):
    xi = 2000*omegas_l1[i]/8/np.pi
    r3 = (xi**2) *(sp.spherical_jn(3, xi)**2) + (xi*sp.spherical_jn(3, xi,derivative=True) + (scipy.special.spherical_jn(3, xi)))**2
    
    #ax.scatter(omegas_l3[i],np.abs(np.sum(array_results_l3[2*i][:])+np.sum(array_results_l3[2*i +1][:])), label = 'l3',color='b')
    ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r3*array_results_l3[2*i][:])+np.sum(omegas_l4[i]*r3*array_results_l3[2*i +1][:])),label='l3 data*omega*rescaling',color='magenta')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r3*array_results_l3[2*i][:])+np.sum(omegas_l4[i]*r3*array_results_l3[2*i +1][:])),label='l3*rescaliny*omega',color='black')

for i in range(0,len(omegas_l3),1):
    xi = 2000*omegas_l1[i]/8/np.pi
    r4 = (xi**2) *(sp.spherical_jn(4, xi)**2) + (xi*sp.spherical_jn(4, xi,derivative=True) + (scipy.special.spherical_jn(4, xi)))**2
    
    #ax.scatter(omegas_l4[i],np.abs(np.sum(array_results_l4[2*i][:])+np.sum(array_results_l4[2*i +1][:])), label = 'l4',color='orange')
    ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r4*array_results_l4[2*i][:])+np.sum(omegas_l4[i]*r4*array_results_l4[2*i +1][:])),label='l4 data*omega*rescaling',color='lime')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r4*array_results_l4[2*i][:])+np.sum(omegas_l4[i]*r4*array_results_l4[2*i +1][:])),label='l4*rescaling*omega',color='black')

#ax.legend()
#ax.scatter(0.05, np.abs(np.sum(array_results_l3wrong[0][:]+array_results_l3wrong[1][:])),color='black')

#ax.plot(omegas_l1,5.e-6*over_omega,label = 'scaling of 1/$\omega$')
ax.set_xscale('log')
plt.yscale('log')
#plt.yscale('symlog')
handles, labels = ax.get_legend_handles_labels()

#ax.legend([handles[0],handles[-1]],[labels[0],labels[-1]])
ax.legend([handles[0],handles[60],handles[130],handles[-1]],[labels[0],labels[60],labels[120],labels[-1]])
#ax.set_ylim(0,1e-5)
ax.set_xlim(.04,16)
ax.set_ylim(1.e-8,1.e-4)
ax.set_title('omega* dN/dw dt * rescaling')
plt.savefig("PBH/omegatimesdatarescaled.pdf",bbox_inches='tight')
plt.show()

"""
# Out:
# 'fig, ax = plt.subplots(nrows=1, ncols=1)\nfor i in range(0,len(omegas_l1),1):\n    xi = 2000*omegas_l1[i]/8/np.pi\n    r1 = (1+np.cos(2*xi)/(xi**2))\n    #ax.scatter(omegas_l1[i],np.abs(np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:])), label = \'l1\', color=\'r\')\n    ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*r1*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*r1*array_results_l1[2*i +1][:])),label=\'l1 data*omega*rescaling\',color=\'black\')\n    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*array_results_l1[2*i +1][:])),label=\'l1*omega\',color=\'purple\')\n#for\nfor i in range(0,len(omegas_l2),1):\n    xi = 2000*omegas_l1[i]/8/np.pi\n    r2 = (xi**2) *(sp.spherical_jn(2, xi)**2) + (xi*sp.spherical_jn(2, xi,derivative=True) + (scipy.special.spherical_jn(2, xi)))**2\n    \n    #ax.scatter(omegas_l2[i],np.abs(np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:])), label = \'l2\',color=\'g\
# ...

# %%
"""fig, ax = plt.subplots(nrows=1, ncols=1)
for i in range(0,len(omegas_l1),1):
    xi = 2000*omegas_l1[i]/8/np.pi
    r1 = (1+np.cos(2*xi)/(xi**2))
    #ax.scatter(omegas_l1[i],np.abs(np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:])), label = 'l1', color='r')
    ax.scatter(omegas_l1[i],np.abs(np.sum(r1*array_results_l1[2*i][:])+np.sum(r1*array_results_l1[2*i +1][:])),label='l1 data*rescaling',color='black')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*array_results_l1[2*i +1][:])),label='l1*omega',color='purple')
#for
for i in range(0,len(omegas_l2),1):
    xi = 2000*omegas_l1[i]/8/np.pi
    r2 = (xi**2) *(sp.spherical_jn(2, xi)**2) + (xi*sp.spherical_jn(2, xi,derivative=True) + (scipy.special.spherical_jn(2, xi)))**2
    
    #ax.scatter(omegas_l2[i],np.abs(np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:])), label = 'l2',color='g')
    ax.scatter(omegas_l1[i],np.abs(np.sum(r2*array_results_l2[2*i][:])+np.sum(r2*array_results_l2[2*i +1][:])),label='l2 data*rescaling',color='cyan')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r2*array_results_l2[2*i][:])+np.sum(omegas_l4[i]*r2*array_results_l2[2*i +1][:])),label='l2*rescaling*omega',color='black')


for i in range(0,len(omegas_l3),1):
    xi = 2000*omegas_l1[i]/8/np.pi
    r3 = (xi**2) *(sp.spherical_jn(3, xi)**2) + (xi*sp.spherical_jn(3, xi,derivative=True) + (scipy.special.spherical_jn(3, xi)))**2
    
    #ax.scatter(omegas_l3[i],np.abs(np.sum(array_results_l3[2*i][:])+np.sum(array_results_l3[2*i +1][:])), label = 'l3',color='b')
    ax.scatter(omegas_l1[i],np.abs(np.sum(r3*array_results_l3[2*i][:])+np.sum(r3*array_results_l3[2*i +1][:])),label='l3 data*rescaling',color='magenta')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r3*array_results_l3[2*i][:])+np.sum(omegas_l4[i]*r3*array_results_l3[2*i +1][:])),label='l3*rescaliny*omega',color='black')

for i in range(0,len(omegas_l3),1):
    xi = 2000*omegas_l1[i]/8/np.pi
    r4 = (xi**2) *(sp.spherical_jn(4, xi)**2) + (xi*sp.spherical_jn(4, xi,derivative=True) + (scipy.special.spherical_jn(4, xi)))**2
    
    #ax.scatter(omegas_l4[i],np.abs(np.sum(array_results_l4[2*i][:])+np.sum(array_results_l4[2*i +1][:])), label = 'l4',color='orange')
    ax.scatter(omegas_l1[i],np.abs(np.sum(r4*array_results_l4[2*i][:])+np.sum(r4*array_results_l4[2*i +1][:])),label='l4 data*rescaling',color='lime')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r4*array_results_l4[2*i][:])+np.sum(omegas_l4[i]*r4*array_results_l4[2*i +1][:])),label='l4*rescaling*omega',color='black')

#ax.legend()
#ax.scatter(0.05, np.abs(np.sum(array_results_l3wrong[0][:]+array_results_l3wrong[1][:])),color='black')

#ax.plot(omegas_l1,5.e-6*over_omega,label = 'scaling of 1/$\omega$')
ax.set_xscale('log')
plt.yscale('log')
#plt.yscale('symlog')
handles, labels = ax.get_legend_handles_labels()

#ax.legend([handles[0],handles[-1]],[labels[0],labels[-1]])
ax.legend([handles[0],handles[60],handles[130],handles[-1]],[labels[0],labels[60],labels[120],labels[-1]])
#ax.set_ylim(0,1e-5)
ax.set_xlim(.04,16)
ax.set_ylim(1.e-8,1.e-2)
ax.set_title('dN/dw dt * rescaling')
plt.savefig("PBH/datarescaled.pdf",bbox_inches='tight')
plt.show()

"""
# Out:
# 'fig, ax = plt.subplots(nrows=1, ncols=1)\nfor i in range(0,len(omegas_l1),1):\n    xi = 2000*omegas_l1[i]/8/np.pi\n    r1 = (1+np.cos(2*xi)/(xi**2))\n    #ax.scatter(omegas_l1[i],np.abs(np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:])), label = \'l1\', color=\'r\')\n    ax.scatter(omegas_l1[i],np.abs(np.sum(r1*array_results_l1[2*i][:])+np.sum(r1*array_results_l1[2*i +1][:])),label=\'l1 data*rescaling\',color=\'black\')\n    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*array_results_l1[2*i +1][:])),label=\'l1*omega\',color=\'purple\')\n#for\nfor i in range(0,len(omegas_l2),1):\n    xi = 2000*omegas_l1[i]/8/np.pi\n    r2 = (xi**2) *(sp.spherical_jn(2, xi)**2) + (xi*sp.spherical_jn(2, xi,derivative=True) + (scipy.special.spherical_jn(2, xi)))**2\n    \n    #ax.scatter(omegas_l2[i],np.abs(np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:])), label = \'l2\',color=\'g\')\n    ax.scatter(omegas_l1[i],
# ...

# %%
"""fig, ax = plt.subplots(nrows=1, ncols=1)


xi = 2000*np.array(omegas_l1)/8/np.pi
r1 = (1+np.cos(2*xi)/(xi**2))
ax.plot(xi,r1, label = 'rescaling l=1',color='r')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:])), label = 'l1', color='r')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*r1*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*r1*array_results_l1[2*i +1][:])),label='l1*omega*scaling',color='black')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*array_results_l1[2*i +1][:])),label='l1*omega',color='purple')
#for


r2 = (xi**2) *(sp.spherical_jn(2, xi)**2) + (xi*sp.spherical_jn(2, xi,derivative=True) + (scipy.special.spherical_jn(2, xi)))**2
    
ax.plot(xi,r2, label = 'rescaling l=2',color='g')
    #ax.scatter(omegas_l2[i],np.abs(np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:])), label = 'l2',color='g')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*array_results_l2[2*i][:])+np.sum(omegas_l4[i]*array_results_l2[2*i +1][:])),label='l2*omega',color='cyan')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r2*array_results_l2[2*i][:])+np.sum(omegas_l4[i]*r2*array_results_l2[2*i +1][:])),label='l2*rescaling*omega',color='black')




r3 = (xi**2) *(sp.spherical_jn(3, xi)**2) + (xi*sp.spherical_jn(3, xi,derivative=True) + (scipy.special.spherical_jn(3, xi)))**2
    
ax.plot(xi,r3, label = 'rescaling l=3',color='b')
    #ax.scatter(omegas_l3[i],np.abs(np.sum(array_results_l3[2*i][:])+np.sum(array_results_l3[2*i +1][:])), label = 'l3',color='b')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*array_results_l3[2*i][:])+np.sum(omegas_l4[i]*array_results_l3[2*i +1][:])),label='l3*omega',color='magenta')
    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l4[i]*r3*array_results_l3[2*i][:])+np.sum(omegas_l4[i]*r3*array_results_l3[2*i +1][:])),label='l3*rescaliny*omega',color='black')


r4 = (xi**2) *(sp.spherical_jn(4, xi)**2) + (xi*sp.spherical_jn(4, xi,derivative=True) + (scipy.special.spherical_jn(4, xi)))**2
    
ax.plot(xi,r4, label = 'rescaling l=4',color='orange')
    
#ax.legend()
#ax.scatter(0.05, np.abs(np.sum(array_results_l3wrong[0][:]+array_results_l3wrong[1][:])),color='black')

#ax.plot(omegas_l1,5.e-6*over_omega,label = 'scaling of 1/$\omega$')
ax.set_xscale('log')
#plt.yscale('log')
#plt.yscale('symlog')
#handles, labels = ax.get_legend_handles_labels()

#ax.legend([handles[0],handles[-1]],[labels[0],labels[-1]])
#ax.legend([handles[0],handles[60],handles[130],handles[-1]],[labels[0],labels[60],labels[120],labels[-1]])
#ax.set_ylim(0,1e-5)
ax.legend()
ax.set_xlim(2,500)
#ax.set_ylim(1.e-7,1.e-2)
ax.set_xlabel('2000*omega/(8 pi Th)')
ax.set_ylabel('rescalings')
ax.set_title('rescaling coefficients')
#plt.savefig("PBH/totalabs.pdf",bbox_inches='tight')
plt.show()

"""
# Out:
# 'fig, ax = plt.subplots(nrows=1, ncols=1)\n\n\nxi = 2000*np.array(omegas_l1)/8/np.pi\nr1 = (1+np.cos(2*xi)/(xi**2))\nax.plot(xi,r1, label = \'rescaling l=1\',color=\'r\')\n    #ax.scatter(omegas_l1[i],np.abs(np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:])), label = \'l1\', color=\'r\')\n    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*r1*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*r1*array_results_l1[2*i +1][:])),label=\'l1*omega*scaling\',color=\'black\')\n    #ax.scatter(omegas_l1[i],np.abs(np.sum(omegas_l1[i]*array_results_l1[2*i][:])+np.sum(omegas_l1[i]*array_results_l1[2*i +1][:])),label=\'l1*omega\',color=\'purple\')\n#for\n\n\nr2 = (xi**2) *(sp.spherical_jn(2, xi)**2) + (xi*sp.spherical_jn(2, xi,derivative=True) + (scipy.special.spherical_jn(2, xi)))**2\n    \nax.plot(xi,r2, label = \'rescaling l=2\',color=\'g\')\n    #ax.scatter(omegas_l2[i],np.abs(np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:])), label = \'l2\',color=\'g\')\
# ...

# %%
"""# matplotlib settings 
SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('lines', linewidth=2)
plt.rc('axes', linewidth=1)
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)   # fontsize of the figure title


fig, ax = plt.subplots(nrows=1, ncols=1)
for i in range(0,len(omegas_l1),1):
    ax.scatter(omegas_l1[i],4*np.pi*Temp*omegas_l1[i]*(np.abs(np.sum(array_results_l1[2*i][:]))+np.abs(np.sum(array_results_l1[2*i +1][:]))), label = 'l1', color='r')
for i in range(0,len(omegas_l2),1):
    ax.scatter(omegas_l2[i],4*np.pi*Temp*omegas_l2[i]*(np.abs(np.sum(array_results_l2[2*i][:]))+np.abs(np.sum(array_results_l2[2*i +1][:]))), label = 'l2', color='b')

#for i in range(0,len(omegas_l2),1):
#    ax.scatter(omegas_l2[i],1.22090164e28*4*np.pi*Temp*omegas_l2[i]*((np.abs(np.sum(array_results_l2[2*i][:]))+np.abs(np.sum(array_results_l2[2*i +1][:])))+(np.abs(np.sum(array_results_l1[2*i][:]))+np.abs(np.sum(array_results_l1[2*i +1][:])))), label = 'summed', color='g')

ax.set_xscale('log')
plt.yscale('log')
#ax.set_ylim(5,100)
handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0],handles[-40],handles[-1]],[labels[0],labels[-40],labels[-1]])
#ax.legend([handles[0]],[labels[0]])
#ax.set_xlim(.04,3)
ax.set_xlabel("$\omega$ (units: $T_{Hawking}$)")
ax.set_ylabel("dE/d$\omega $dt (units: eV)")
ax.set_title('Energy Spectra for Hawking Radiation \n PBH with mass 2.12 x $10^{16}$ g')
plt.savefig("ForProposal.pdf",bbox_inches='tight')
plt.show()"""
# Out:
# '# matplotlib settings \nSMALL_SIZE = 14\nMEDIUM_SIZE = 16\nBIGGER_SIZE = 18\n\nplt.rc(\'font\', size=SMALL_SIZE)          # controls default text sizes\nplt.rc(\'axes\', titlesize=MEDIUM_SIZE)     # fontsize of the axes title\nplt.rc(\'axes\', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels\nplt.rc(\'lines\', linewidth=2)\nplt.rc(\'axes\', linewidth=1)\nplt.rc(\'xtick\', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels\nplt.rc(\'ytick\', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels\nplt.rc(\'legend\', fontsize=MEDIUM_SIZE)    # legend fontsize\nplt.rc(\'figure\', titlesize=BIGGER_SIZE)   # fontsize of the figure title\n\n\nfig, ax = plt.subplots(nrows=1, ncols=1)\nfor i in range(0,len(omegas_l1),1):\n    ax.scatter(omegas_l1[i],4*np.pi*Temp*omegas_l1[i]*(np.abs(np.sum(array_results_l1[2*i][:]))+np.abs(np.sum(array_results_l1[2*i +1][:]))), label = \'l1\', color=\'r\')\nfor i in range(0,len(omegas_l2),1):\n    ax.scatter(omegas_l2[i],4*np.pi*Temp*omegas_l
# ...

# %%
2000/8/np.pi
# Out:
# 79.57747154594767

# %%
np.sqrt(8*np.log(2))
# Out:
# 2.3548200450309493

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][:]))+(np.sum(array_results_l1[2*i +1][:]))), label = 'l1', color='r')
for i in range(0,len(omegas_l2),1):
    ax[0].scatter(omegas_l2[i],((np.sum(array_results_l2[2*i][:]))+(np.sum(array_results_l2[2*i +1][:]))), label = 'l2', color='g')
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],((np.sum(array_results_l3[2*i][:]))+(np.sum(array_results_l3[2*i +1][:]))), label = 'l3', color='b')

for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],((np.sum(array_results_l4[2*i][:]))+(np.sum(array_results_l4[2*i +1][:]))), label = 'l4', color='orange')
for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],((np.sum(array_results_l5[2*i][:]))+(np.sum(array_results_l5[2*i +1][:]))), label = 'l5', color='magenta')

#for i in range(0,len(omegas_l2),1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*(((np.sum(array_results_l2[2*i][:]))+(np.sum(array_results_l2[2*i +1][:])))+((np.sum(array_results_l1[2*i][:]))+(np.sum(array_results_l1[2*i +1][:])))), label = 'summed', color='g')
ax[0].scatter(10,0,color='black')
ax[0].set_xscale('log')
ax[0].set_yscale('symlog')

handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[-40],handles[-1]],[labels[0],labels[-40],labels[-1]])
ax[1].set_xlim(.04,16)
#ax[0].set_ylim(-4e-4,3e-3)
"""
for i in range(0,len(omegas_l2),1):
    val_l2 = ((np.sum(array_results_l2[2*i][:]))+(np.sum(array_results_l2[2*i +1][:])))
    val_l1 = ((np.sum(array_results_l1[2*i][:]))+(np.sum(array_results_l1[2*i +1][:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega total not rescaled')
#plt.savefig("PBH/total.pdf",bbox_inches='tight')
plt.show()

# %%
m1_rescale = [[0.0500,     1.166673,  1.574394,  2.243118,  3.159226,  4.401768],[0.0600,      1.163991,  1.500292,  2.154954,  3.078227,  4.322734],[0.0700,      1.154228,  1.464067,  2.045400,  2.975217,  4.226242],[0.0900,      1.120542,  1.432737,  1.917950,  2.681729,  3.953557],[0.1100,      1.113046,  1.358532,  1.846224,  2.577924,  3.538052],[0.1400,      1.092114,  1.304129,  1.732152,  2.312884,  3.391012],[0.1700,      1.073672,  1.270785,  1.604377,  2.200126,  3.092237],[0.2000,      1.062683,  1.233078,  1.523868,  2.076711,  2.790291],[0.2500,      1.049428,  1.183126,  1.425498,  1.864849,  2.528652],[0.3100,      1.038563,  1.137635,  1.340325,  1.676344,  2.238247],[0.3700,      1.029448,  1.109215,  1.265859,  1.548399,  2.002587],[0.4600,      1.021210,  1.074400,  1.195878,  1.388998,  1.758306],[0.5600,      1.013454,  1.054158,  1.130464,  1.288542,  1.526912],[0.6800,      1.008571,  1.034774,  1.085885,  1.192555,  1.360454],[0.8400,      1.004708,  1.019070,  1.049360,  1.111905,  1.218203],[1.0200,      1.002243,  1.009447,  1.025582,  1.059661,  1.122493],[1.2500,      1.000809,  1.002954,  1.010419,  1.023586,  1.056505],[1.5000,      0.999915,  1.000617,  1.001425,  1.007924,  1.017397],[1.7500,      0.999779,  0.999176,  0.999036,  0.999066,  1.003248],[2.0000,      0.999722,  0.998901,  0.998002,  0.996368,  0.996547]]


for i in range(3+4+4+4+4+2+2+2+2+2+2+2+2+2+1):
    m1_rescale.append([100, 1,1,1,1,1])
    
m1_rescale = np.array(m1_rescale)

# %%
np.array(m1_rescale).T.shape
# Out:
# (6, 58)

# %%
l_data = np.zeros((6,len(omegas_l1)))
for i in range(0,len(omegas_l1),1):
    l_data[0,i] = omegas_l1[i]
    l_data[1,i] = ((np.sum(array_results_l1[2*i][:]))+(np.sum(array_results_l1[2*i +1][:])))/m1_rescale[i,1]
    l_data[2,i] = ((np.sum(array_results_l2[2*i][:]))+(np.sum(array_results_l2[2*i +1][:])))/m1_rescale[i,2]
    l_data[3,i] = ((np.sum(array_results_l3[2*i][:]))+(np.sum(array_results_l3[2*i +1][:])))/m1_rescale[i,3]
    l_data[4,i] = ((np.sum(array_results_l4[2*i][:]))+(np.sum(array_results_l4[2*i +1][:])))/m1_rescale[i,4]
    l_data[5,i] = ((np.sum(array_results_l5[2*i][:]))+(np.sum(array_results_l5[2*i +1][:])))/m1_rescale[i,5]

# %%
np.savetxt("M1Trial.csv", l_data, delimiter=",")

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][:]))+(np.sum(array_results_l1[2*i +1][:])))/m1_rescale[i,1], label = 'l1', color='r')
for i in range(0,len(omegas_l2),1):
    ax[0].scatter(omegas_l2[i],((np.sum(array_results_l2[2*i][:]))+(np.sum(array_results_l2[2*i +1][:])))/m1_rescale[i,2], label = 'l2', color='g')
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],((np.sum(array_results_l3[2*i][:]))+(np.sum(array_results_l3[2*i +1][:])))/m1_rescale[i,3], label = 'l3', color='b')

for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],((np.sum(array_results_l4[2*i][:]))+(np.sum(array_results_l4[2*i +1][:])))/m1_rescale[i,4], label = 'l4', color='orange')
for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],((np.sum(array_results_l5[2*i][:]))+(np.sum(array_results_l5[2*i +1][:])))/m1_rescale[i,5], label = 'l5', color='magenta')

#for i in range(0,len(omegas_l2),1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*(((np.sum(array_results_l2[2*i][:]))+(np.sum(array_results_l2[2*i +1][:])))+((np.sum(array_results_l1[2*i][:]))+(np.sum(array_results_l1[2*i +1][:])))), label = 'summed', color='g')
ax[0].scatter(10,0,color='black')
ax[0].set_xscale('log')
ax[0].set_yscale('symlog')

handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[-40],handles[-1]],[labels[0],labels[-40],labels[-1]])
ax[1].set_xlim(.04,16)
#ax[0].set_ylim(-4e-4,3e-3)
"""
for i in range(0,len(omegas_l2),1):
    val_l2 = ((np.sum(array_results_l2[2*i][:]))+(np.sum(array_results_l2[2*i +1][:])))
    val_l1 = ((np.sum(array_results_l1[2*i][:]))+(np.sum(array_results_l1[2*i +1][:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega total rescaled')
#plt.savefig("PBH/total.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],np.abs((np.sum(array_results_l1[2*i][:]))+(np.sum(array_results_l1[2*i +1][:])))/m1_rescale[i,1], label = 'l1', color='r')
for i in range(0,len(omegas_l2),1):
    ax[0].scatter(omegas_l2[i],np.abs((np.sum(array_results_l2[2*i][:]))+(np.sum(array_results_l2[2*i +1][:])))/m1_rescale[i,2], label = 'l2', color='g')
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],np.abs((np.sum(array_results_l3[2*i][:]))+(np.sum(array_results_l3[2*i +1][:])))/m1_rescale[i,3], label = 'l3', color='b')

for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],np.abs((np.sum(array_results_l4[2*i][:]))+(np.sum(array_results_l4[2*i +1][:])))/m1_rescale[i,4], label = 'l4', color='orange')
for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],np.abs((np.sum(array_results_l5[2*i][:]))+(np.sum(array_results_l5[2*i +1][:])))/m1_rescale[i,5], label = 'l5', color='magenta')

#for i in range(0,len(omegas_l2),1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*(((np.sum(array_results_l2[2*i][:]))+(np.sum(array_results_l2[2*i +1][:])))+((np.sum(array_results_l1[2*i][:]))+(np.sum(array_results_l1[2*i +1][:])))), label = 'summed', color='g')
ax[0].scatter(10,0,color='black')
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[-40],handles[-1]],[labels[0],labels[-40],labels[-1]])
ax[1].set_xlim(.04,16)
#ax[0].set_ylim(-4e-4,3e-3)
"""
for i in range(0,len(omegas_l2),1):
    val_l2 = ((np.sum(array_results_l2[2*i][:]))+(np.sum(array_results_l2[2*i +1][:])))
    val_l1 = ((np.sum(array_results_l1[2*i][:]))+(np.sum(array_results_l1[2*i +1][:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega total abs rescaled')
#plt.savefig("PBH/total.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],np.abs((np.sum(array_results_l1[2*i][:]))+(np.sum(array_results_l1[2*i +1][:])))/m1_rescale[i,1], label = 'l1', color='r')
for i in range(0,len(omegas_l2),1):
    ax[0].scatter(omegas_l2[i],np.abs((np.sum(array_results_l2[2*i][:]))+(np.sum(array_results_l2[2*i +1][:])))/m1_rescale[i,2], label = 'l2', color='g')
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],np.abs((np.sum(array_results_l3[2*i][:]))+(np.sum(array_results_l3[2*i +1][:])))/m1_rescale[i,3], label = 'l3', color='b')

for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],np.abs((np.sum(array_results_l4[2*i][:]))+(np.sum(array_results_l4[2*i +1][:])))/m1_rescale[i,4], label = 'l4', color='orange')
for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],np.abs((np.sum(array_results_l5[2*i][:]))+(np.sum(array_results_l5[2*i +1][:])))/m1_rescale[i,5], label = 'l5', color='magenta')

#for i in range(0,len(omegas_l2),1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*(((np.sum(array_results_l2[2*i][:]))+(np.sum(array_results_l2[2*i +1][:])))+((np.sum(array_results_l1[2*i][:]))+(np.sum(array_results_l1[2*i +1][:])))), label = 'summed', color='g')
ax[0].scatter(10,0,color='black')
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[-40],handles[-1]],[labels[0],labels[-40],labels[-1]])
ax[1].set_xlim(.04,3)
ax[0].set_ylim(1e-6,1e-2)
"""
for i in range(0,len(omegas_l2),1):
    val_l2 = ((np.sum(array_results_l2[2*i][:]))+(np.sum(array_results_l2[2*i +1][:])))
    val_l1 = ((np.sum(array_results_l1[2*i][:]))+(np.sum(array_results_l1[2*i +1][:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega total abs rescaled')
#plt.savefig("PBH/total.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][:])))/m1_rescale[i,1], label = 'l1', color='r')
for i in range(0,len(omegas_l2),1):
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][:])))/m1_rescale[i,2], label = 'l2', color='g')

for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][:])))/m1_rescale[i,3], label = 'l3', color='b')

for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][:])))/m1_rescale[i,4], label = 'l4', color='orange')
for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][:])))/m1_rescale[i,5], label = 'l5', color='magenta')

#for i in range(0,len(omegas_l2),1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*((np.abs(np.sum(array_results_l2[2*i][:])))+(np.abs(np.sum(array_results_l1[2*i][:])))), label = 'summed', color='g')
#ax[0].scatter(0.05, np.abs(np.sum(array_results_l3wrong[0][:])),color='black')
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-130],handles[-60],handles[-1]],[labels[0],labels[-130],labels[-60],labels[-1]])
ax[1].set_xlim(.04,16)

for i in range(0,len(omegas_l3),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')

ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega even only abs')
#plt.savefig("PBH/evenabsrescaled.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i+1][:])))/m1_rescale[i,1], label = 'l1', color='r')
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i+1][:])))/m1_rescale[i,2], label = 'l2', color='g')

for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i+1][:])))/m1_rescale[i,3], label = 'l3', color='b')

for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i+1][:])))/m1_rescale[i,4], label = 'l4', color='orange')
for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l5[i],(np.abs(np.sum(array_results_l5[2*i+1][:])))/m1_rescale[i,5], label = 'l5', color='magenta')

#for i in range(0,len(omegas_l3),1):
#    ax[0].scatter(omegas_l3[i],4*np.pi*((np.abs(np.sum(array_results_l3[2*i+1][:])))+(np.abs(np.sum(array_results_l3[2*i+1][:])))), label = 'summed', color='g')
#ax[0].scatter(0.05, np.abs(np.sum(array_results_l3wrong[1][:])),color='black')
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-130],handles[-60],handles[-1]],[labels[0],labels[-130],labels[-60],labels[-1]])
ax[1].set_xlim(.04,16)

for i in range(0,len(omegas_l3),1):
    val_l3 = (np.abs(np.sum(array_results_l2[2*i+1][:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i+1][:])))
    val = val_l1/val_l3
    ax[1].scatter(omegas_l3[i],val, label = 'l1/l2', color='y')

ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega odd only abs')
#plt.savefig("PBH/oddabs.pdf",bbox_inches='tight')
plt.show()

# %%
#R only

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][:3]))+(np.sum(array_results_l1[2*i +1][:3])))/m1_rescale[i,1], label = 'l1', color='r')
for i in range(0,len(omegas_l2),1):
    ax[0].scatter(omegas_l2[i],((np.sum(array_results_l2[2*i][:3]))+(np.sum(array_results_l2[2*i +1][:3])))/m1_rescale[i,2], label = 'l2', color='g')

for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],((np.sum(array_results_l3[2*i][:3]))+(np.sum(array_results_l3[2*i +1][:3])))/m1_rescale[i,3], label = 'l3', color='b')

for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],((np.sum(array_results_l4[2*i][:3]))+(np.sum(array_results_l4[2*i +1][:3])))/m1_rescale[i,4], label = 'l4', color='orange')
for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],((np.sum(array_results_l5[2*i][:3]))+(np.sum(array_results_l5[2*i +1][:3])))/m1_rescale[i,5], label = 'l5', color='magenta')

#for i in range(0,len(omegas_l2),1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*(((np.sum(array_results_l2[2*i][:3]))+(np.sum(array_results_l2[2*i +1][:3])))+((np.sum(array_results_l1[2*i][:3]))+(np.sum(array_results_l1[2*i +1][:3])))), label = 'summed', color='g')

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-130],handles[-60],handles[-1]],[labels[0],labels[-130],labels[-60],labels[-1]])
#ax[0].legend([handles[0],handles[-40],handles[-1]],[labels[0],labels[-40],labels[-1]])
ax[1].set_xlim(.04,16)

#for i in range(0,len(omegas_l2),1):
#    val_l2 = ((np.sum(array_results_l2[2*i][:3]))+(np.sum(array_results_l2[2*i +1][:3])))
#    val_l1 = ((np.sum(array_results_l1[2*i][:3]))+(np.sum(array_results_l1[2*i +1][:3])))
#    val = val_l1/val_l2
#    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Reflection terms')
#plt.savefig("PBH/allreflectabs.pdf",bbox_inches='tight')
plt.show()

# %%
#fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
fig, ax = plt.subplots(nrows=1, ncols=1)
for i in range(0,len(omegas_l1),1):
    ax.scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][:3]))+np.abs(np.sum(array_results_l1[2*i +1][:3])))/m1_rescale[i,1], label = 'l1', color='r')
for i in range(0,len(omegas_l3),1):
    ax.scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][:3]))+np.abs(np.sum(array_results_l2[2*i +1][:3])))/m1_rescale[i,2], label = 'l2', color='g')

for i in range(0,len(omegas_l3),1):
    ax.scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][:3]))+np.abs(np.sum(array_results_l3[2*i +1][:3])))/m1_rescale[i,3], label = 'l3', color='b')
for i in range(0,len(omegas_l4),1):
    ax.scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][:3]))+np.abs(np.sum(array_results_l4[2*i +1][:3])))/m1_rescale[i,4], label = 'l4', color='orange')
for i in range(0,len(omegas_l4),1):
    ax.scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][:3]))+np.abs(np.sum(array_results_l5[2*i +1][:3])))/m1_rescale[i,5], label = 'l5', color='magenta')

#for i in range(0,len(omegas_l2),1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*((np.abs(np.sum(array_results_l2[2*i][:3]))+np.abs(np.sum(array_results_l2[2*i +1][:3])))+(np.abs(np.sum(array_results_l1[2*i][:3]))+np.abs(np.sum(array_results_l1[2*i +1][:3])))), label = 'summed', color='g')

ax.set_xscale('log')
ax.set_yscale('log')

handles, labels = ax.get_legend_handles_labels()
ax.legend([handles[0],handles[-130],handles[-60],handles[-1]],[labels[0],labels[-130],labels[-60],labels[-1]])
ax.set_xlim(.04,16)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][:3]))+np.abs(np.sum(array_results_l2[2*i +1][:3])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][:3]))+np.abs(np.sum(array_results_l1[2*i +1][:3])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""

ax.set_title('all omega Reflection terms abs')
#plt.savefig("PBH/allreflectabs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][:3]))+np.abs(np.sum(array_results_l1[2*i +1][:3])))/m1_rescale[i,1], label = 'l=1', color='black')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][0:1]))+np.abs(np.sum(array_results_l1[2*i +1][0:1])))/m1_rescale[i,1], label = 'term 1', color='r')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][1:2]))+np.abs(np.sum(array_results_l1[2*i +1][1:2])))/m1_rescale[i,1], label = 'term 2', color='g')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][2:3]))+np.abs(np.sum(array_results_l1[2*i +1][2:3])))/m1_rescale[i,1], label = 'term 3', color='b')

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[25],handles[70],handles[-1]],[labels[0],labels[5],labels[70],labels[-1]])
#ax[1].set_xlim(4,16)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][:3]))+np.abs(np.sum(array_results_l2[2*i +1][:3])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][:3]))+np.abs(np.sum(array_results_l1[2*i +1][:3])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Reflection terms abs l1')
plt.savefig("PBH/reflectl1.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][:3]))+np.abs(np.sum(array_results_l2[2*i +1][:3])))/m1_rescale[i,2], label = 'l=2', color='black')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][0:1]))+np.abs(np.sum(array_results_l2[2*i +1][0:1])))/m1_rescale[i,2], label = 'term 1', color='r')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][1:2]))+np.abs(np.sum(array_results_l2[2*i +1][1:2])))/m1_rescale[i,2], label = 'term 2', color='g')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][2:3]))+np.abs(np.sum(array_results_l2[2*i +1][2:3])))/m1_rescale[i,2], label = 'term 3', color='b')

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[25],handles[70],handles[-1]],[labels[0],labels[5],labels[70],labels[-1]])
#ax[1].set_xlim(4,16)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][:3]))+np.abs(np.sum(array_results_l2[2*i +1][:3])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][:3]))+np.abs(np.sum(array_results_l1[2*i +1][:3])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Reflection terms abs l2')
plt.savefig("PBH/reflectl2.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][:3]))+np.abs(np.sum(array_results_l3[2*i +1][:3])))/m1_rescale[i,3], label = 'l=3', color='black')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][0:1]))+np.abs(np.sum(array_results_l3[2*i +1][0:1])))/m1_rescale[i,3], label = 'term 1', color='r')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][1:2]))+np.abs(np.sum(array_results_l3[2*i +1][1:2])))/m1_rescale[i,3], label = 'term 2', color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][2:3]))+np.abs(np.sum(array_results_l3[2*i +1][2:3])))/m1_rescale[i,3], label = 'term 3', color='b')

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[25],handles[70],handles[-1]],[labels[0],labels[5],labels[70],labels[-1]])
ax[1].set_xlim(.4,16)
#ax[0].set_ylim(1e-12,1e-8)
ax[0].set_ylim(1e-20,1e-4)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][:3]))+np.abs(np.sum(array_results_l2[2*i +1][:3])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][:3]))+np.abs(np.sum(array_results_l1[2*i +1][:3])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Reflection terms abs l3')
plt.savefig("PBH/reflectl3.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][:3]))+np.abs(np.sum(array_results_l4[2*i +1][:3])))/m1_rescale[i,4], label = 'l=4', color='black')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][0:1]))+np.abs(np.sum(array_results_l4[2*i +1][0:1])))/m1_rescale[i,4], label = 'term 1', color='r')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][1:2]))+np.abs(np.sum(array_results_l4[2*i +1][1:2])))/m1_rescale[i,4], label = 'term 2', color='g')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][2:3]))+np.abs(np.sum(array_results_l4[2*i +1][2:3])))/m1_rescale[i,4], label = 'term 3', color='b')

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[25],handles[70],handles[-1]],[labels[0],labels[5],labels[70],labels[-1]])
ax[1].set_xlim(.4,16)
#ax[0].set_ylim(1e-12,1e-8)
ax[0].set_ylim(1e-20,1e-4)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][:3]))+np.abs(np.sum(array_results_l2[2*i +1][:3])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][:3]))+np.abs(np.sum(array_results_l1[2*i +1][:3])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Reflection terms abs l4')
plt.savefig("PBH/reflectl4.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][:3]))+np.abs(np.sum(array_results_l5[2*i +1][:3])))/m1_rescale[i,5], label = 'l=5', color='black')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][0:1]))+np.abs(np.sum(array_results_l5[2*i +1][0:1])))/m1_rescale[i,5], label = 'term 1', color='r')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][1:2]))+np.abs(np.sum(array_results_l5[2*i +1][1:2])))/m1_rescale[i,5], label = 'term 2', color='g')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][2:3]))+np.abs(np.sum(array_results_l5[2*i +1][2:3])))/m1_rescale[i,5], label = 'term 3', color='b')

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[25],handles[70],handles[-1]],[labels[0],labels[5],labels[70],labels[-1]])
ax[1].set_xlim(.4,16)
#ax[0].set_ylim(1e-12,1e-8)
ax[0].set_ylim(1e-20,1e-4)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][:3]))+np.abs(np.sum(array_results_l2[2*i +1][:3])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][:3]))+np.abs(np.sum(array_results_l1[2*i +1][:3])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Reflection terms abs l5')
plt.savefig("PBH/reflectl5.pdf",bbox_inches='tight')
plt.show()

# %%
#Transmission only

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][3:7]))+(np.sum(array_results_l1[2*i +1][3:7])))/m1_rescale[i,1], label = 'l1', color='r')
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l2[i],((np.sum(array_results_l2[2*i][3:7]))+(np.sum(array_results_l2[2*i +1][3:7])))/m1_rescale[i,2], label = 'l2', color='g')

for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],((np.sum(array_results_l3[2*i][3:7]))+(np.sum(array_results_l3[2*i +1][3:7])))/m1_rescale[i,3], label = 'l3', color='b')
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l4[i],((np.sum(array_results_l4[2*i][3:7]))+(np.sum(array_results_l4[2*i +1][3:7])))/m1_rescale[i,4], label = 'l4', color='orange')
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l5[i],((np.sum(array_results_l5[2*i][3:7]))+(np.sum(array_results_l5[2*i +1][3:7])))/m1_rescale[i,5], label = 'l4', color='magenta')

#ax[0].scatter(10,0)    
#for i in range(0,len(omegas_l2),1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*(((np.sum(array_results_l2[2*i][3:7]))+(np.sum(array_results_l2[2*i +1][3:7])))+((np.sum(array_results_l1[2*i][3:7]))+(np.sum(array_results_l1[2*i +1][3:7])))), label = 'summed', color='g')

ax[0].set_xscale('log')
ax[0].set_yscale('symlog')
#ax[0].set_ylim(-2e-6, 7e-8)
#ax[0].set_ylim(4e-12, 7e-10)

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[60],handles[-60],handles[-1]],[labels[0],labels[60],labels[-60],labels[-1]])
ax[1].set_xlim(.04,16)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = ((np.sum(array_results_l2[2*i][3:7]))+(np.sum(array_results_l2[2*i +1][3:7])))
    val_l1 = ((np.sum(array_results_l1[2*i][3:7]))+(np.sum(array_results_l1[2*i +1][3:7])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Transmission terms')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][3:7])+(np.sum(array_results_l1[2*i +1][3:7]))))/m1_rescale[i,1], label = 'l1', color='r')
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][3:7])+(np.sum(array_results_l2[2*i +1][3:7]))))/m1_rescale[i,2], label = 'l2', color='g')

for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][3:7])+(np.sum(array_results_l3[2*i +1][3:7]))))/m1_rescale[i,3], label = 'l3', color='b')

for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][3:7])+(np.sum(array_results_l4[2*i +1][3:7]))))/m1_rescale[i,4], label = 'l4', color='orange')
for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][3:7])+(np.sum(array_results_l5[2*i +1][3:7]))))/m1_rescale[i,5], label = 'l5', color='magenta')

#for i in range(0,len(omegas_l2),1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*((np.abs(np.sum(array_results_l2[2*i][3:7]))+np.abs(np.sum(array_results_l2[2*i +1][3:7])))+(np.abs(np.sum(array_results_l1[2*i][3:7]))+np.abs(np.sum(array_results_l1[2*i +1][3:7])))), label = 'summed', color='g')

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-130],handles[-60],handles[-1]],[labels[0],labels[-130],labels[-60],labels[-1]])
ax[1].set_xlim(.04,16)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][3:7]))+np.abs(np.sum(array_results_l2[2*i +1][3:7])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][3:7]))+np.abs(np.sum(array_results_l1[2*i +1][3:7])))
    val = val_l1/val_l2
   ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')"""
ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Transmission terms abs')
plt.savefig("PBH/alltransmissionabs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[5, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][3:7])+np.sum(array_results_l1[2*i +1][3:7])))/m1_rescale[i,1], label = 'l=1', color='black')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][3:4])+np.sum(array_results_l1[2*i +1][3:4])))/m1_rescale[i,1], label = 'term 4', color='b')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][4:5])+np.sum(array_results_l1[2*i +1][3:5])))/m1_rescale[i,1], label = 'term 5', color='g')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][5:6])+np.sum(array_results_l1[2*i +1][3:6])))/m1_rescale[i,1], label = 'term 6', color='y')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][6:7])+np.sum(array_results_l1[2*i +1][3:7])))/m1_rescale[i,1], label = 'term 7', color='r')

    
    
handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-4],labels[-3],labels[-2],labels[-1]])

#ax[1].set_xlim(4,16)
ax[0].set_yscale('log')
ax[0].set_xscale('log')


"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][3:7]))+np.abs(np.sum(array_results_l2[2*i +1][3:7])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][3:7]))+np.abs(np.sum(array_results_l1[2*i +1][3:7])))
    val = val_l1/val_l2
   ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Transmission terms abs l1')
plt.savefig("PBH/transmissionl1.pdf",bbox_inches='tight')
plt.show()     

#problem with l=1

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[5, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][3:7]))+(np.sum(array_results_l1[2*i +1][3:7])))/m1_rescale[i,1], label = 'l=1', color='black')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][3:4]))+(np.sum(array_results_l1[2*i +1][3:4])))/m1_rescale[i,1], label = 'term 4', color='b')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][4:5]))+(np.sum(array_results_l1[2*i +1][3:5])))/m1_rescale[i,1], label = 'term 5', color='g')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][5:6]))+(np.sum(array_results_l1[2*i +1][3:6])))/m1_rescale[i,1], label = 'term 6', color='y')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][6:7]))+(np.sum(array_results_l1[2*i +1][3:7])))/m1_rescale[i,1], label = 'term 7', color='r')

    
    
handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-4],labels[-3],labels[-2],labels[-1]])

#ax[1].set_xlim(4,16)
#ax[0].set_yscale('log')
ax[0].set_xscale('log')


"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][3:7]))+np.abs(np.sum(array_results_l2[2*i +1][3:7])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][3:7]))+np.abs(np.sum(array_results_l1[2*i +1][3:7])))
    val = val_l1/val_l2
   ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Transmission terms l1')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[5, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][3:7])+np.sum(array_results_l2[2*i +1][3:7])))/m1_rescale[i,2], label = 'l=2', color='black')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][3:4])+np.sum(array_results_l2[2*i +1][3:4])))/m1_rescale[i,2], label = 'term 4', color='b')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][4:5])+np.sum(array_results_l2[2*i +1][3:5])))/m1_rescale[i,2], label = 'term 5', color='g')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][5:6])+np.sum(array_results_l2[2*i +1][3:6])))/m1_rescale[i,2], label = 'term 6', color='y')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][6:7])+np.sum(array_results_l2[2*i +1][3:7])))/m1_rescale[i,2], label = 'term 7', color='r')

    
    
handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-4],labels[-3],labels[-2],labels[-1]])

#ax[1].set_xlim(4,16)
ax[0].set_yscale('log')
ax[0].set_xscale('log')


"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][3:7]))+np.abs(np.sum(array_results_l2[2*i +1][3:7])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][3:7]))+np.abs(np.sum(array_results_l1[2*i +1][3:7])))
    val = val_l1/val_l2
   ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Transmission terms abs l2')
plt.savefig("PBH/transmissionl2.pdf",bbox_inches='tight')
plt.show()     

#problem with l=1

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[5, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l2[i],((np.sum(array_results_l2[2*i][3:7])+np.sum(array_results_l2[2*i +1][3:7])))/m1_rescale[i,2], label = 'l=2', color='black')
    ax[0].scatter(omegas_l2[i],((np.sum(array_results_l2[2*i][3:4])+np.sum(array_results_l2[2*i +1][3:4])))/m1_rescale[i,2], label = 'term 4', color='b')
    ax[0].scatter(omegas_l2[i],((np.sum(array_results_l2[2*i][4:5])+np.sum(array_results_l2[2*i +1][3:5])))/m1_rescale[i,2], label = 'term 5', color='g')
    ax[0].scatter(omegas_l2[i],((np.sum(array_results_l2[2*i][5:6])+np.sum(array_results_l2[2*i +1][3:6])))/m1_rescale[i,2], label = 'term 6', color='y')
    ax[0].scatter(omegas_l2[i],((np.sum(array_results_l2[2*i][6:7])+np.sum(array_results_l2[2*i +1][3:7])))/m1_rescale[i,2], label = 'term 7', color='r')

    
    
handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-4],labels[-3],labels[-2],labels[-1]])

#ax[1].set_xlim(4,16)
#ax[0].set_yscale('log')
ax[0].set_xscale('log')


"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][3:7]))+np.abs(np.sum(array_results_l2[2*i +1][3:7])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][3:7]))+np.abs(np.sum(array_results_l1[2*i +1][3:7])))
    val = val_l1/val_l2
   ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Transmission terms abs l2')

plt.show()     

#problem with l=1

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[5, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][3:7])+np.sum(array_results_l3[2*i +1][3:7])))/m1_rescale[i,3], label = 'l=3', color='black')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][3:4])+np.sum(array_results_l3[2*i +1][3:4])))/m1_rescale[i,3], label = 'term 4', color='b')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][4:5])+np.sum(array_results_l3[2*i +1][3:5])))/m1_rescale[i,3], label = 'term 5', color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][5:6])+np.sum(array_results_l3[2*i +1][3:6])))/m1_rescale[i,3], label = 'term 6', color='y')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][6:7])+np.sum(array_results_l3[2*i +1][3:7])))/m1_rescale[i,3], label = 'term 7', color='r')

    
    
handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-4],labels[-3],labels[-2],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,1e-9)
ax[0].set_yscale('log')
ax[0].set_xscale('log')


"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][3:7]))+np.abs(np.sum(array_results_l2[2*i +1][3:7])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][3:7]))+np.abs(np.sum(array_results_l1[2*i +1][3:7])))
    val = val_l1/val_l2
   ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Transmission terms abs l3')
plt.savefig("PBH/transmissionl3.pdf",bbox_inches='tight')
plt.show()     

#use up photon wavefunctions

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[5, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][3:7])+np.sum(array_results_l4[2*i +1][3:7])))/m1_rescale[i,4], label = 'l=4', color='black')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][3:4])+np.sum(array_results_l4[2*i +1][3:4])))/m1_rescale[i,4], label = 'term 4', color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][4:5])+np.sum(array_results_l4[2*i +1][3:5])))/m1_rescale[i,4], label = 'term 5', color='g')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][5:6])+np.sum(array_results_l4[2*i +1][3:6])))/m1_rescale[i,4], label = 'term 6', color='y')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][6:7])+np.sum(array_results_l4[2*i +1][3:7])))/m1_rescale[i,4], label = 'term 7', color='r')

    
    
handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-4],labels[-3],labels[-2],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,1e-9)
ax[0].set_yscale('log')
ax[0].set_xscale('log')


"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][3:7]))+np.abs(np.sum(array_results_l2[2*i +1][3:7])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][3:7]))+np.abs(np.sum(array_results_l1[2*i +1][3:7])))
    val = val_l1/val_l2
   ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Transmission terms abs l4')
plt.savefig("PBH/transmissionl4.pdf",bbox_inches='tight')
plt.show()     

#use up photon wavefunctions

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[5, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][3:7])+np.sum(array_results_l5[2*i +1][3:7])))/m1_rescale[i,5], label = 'l=5', color='black')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][3:4])+np.sum(array_results_l5[2*i +1][3:4])))/m1_rescale[i,5], label = 'term 4', color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][4:5])+np.sum(array_results_l5[2*i +1][3:5])))/m1_rescale[i,5], label = 'term 5', color='g')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][5:6])+np.sum(array_results_l5[2*i +1][3:6])))/m1_rescale[i,5], label = 'term 6', color='y')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][6:7])+np.sum(array_results_l5[2*i +1][3:7])))/m1_rescale[i,5], label = 'term 7', color='r')

    
    
handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-4],labels[-3],labels[-2],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,1e-9)
ax[0].set_yscale('log')
ax[0].set_xscale('log')


"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][3:7]))+np.abs(np.sum(array_results_l2[2*i +1][3:7])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][3:7]))+np.abs(np.sum(array_results_l1[2*i +1][3:7])))
    val = val_l1/val_l2
   ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Transmission terms abs l5')
plt.savefig("PBH/transmissionl5.pdf",bbox_inches='tight')
plt.show()     

#use up photon wavefunctions

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[5, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],((np.sum(array_results_l3[2*i][3:7]))+(np.sum(array_results_l3[2*i +1][3:7])))/m1_rescale[i,3], label = 'l=3', color='black')
    ax[0].scatter(omegas_l3[i],((np.sum(array_results_l3[2*i][3:4]))+(np.sum(array_results_l3[2*i +1][3:4])))/m1_rescale[i,3], label = 'term 4', color='b')
    ax[0].scatter(omegas_l3[i],((np.sum(array_results_l3[2*i][4:5]))+(np.sum(array_results_l3[2*i +1][3:5])))/m1_rescale[i,3], label = 'term 5', color='g')
    ax[0].scatter(omegas_l3[i],((np.sum(array_results_l3[2*i][5:6]))+(np.sum(array_results_l3[2*i +1][3:6])))/m1_rescale[i,3], label = 'term 6', color='y')
    ax[0].scatter(omegas_l3[i],((np.sum(array_results_l3[2*i][6:7]))+(np.sum(array_results_l3[2*i +1][3:7])))/m1_rescale[i,3], label = 'term 7', color='r')

    
    
handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-4],labels[-3],labels[-2],labels[-1]])

#ax[1].set_xlim(4,16)
#ax[0].set_yscale('log')
ax[0].set_xscale('log')


"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][3:7]))+np.abs(np.sum(array_results_l2[2*i +1][3:7])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][3:7]))+np.abs(np.sum(array_results_l1[2*i +1][3:7])))
    val = val_l1/val_l2
   ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega Transmission terms l3')
plt.show()

# %%
#mixed terms

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][7:]))+(np.sum(array_results_l1[2*i +1][7:])))/m1_rescale[i,1], label = 'l1', color='r')
for i in range(0,len(omegas_l2),1):
    ax[0].scatter(omegas_l2[i],((np.sum(array_results_l2[2*i][7:]))+(np.sum(array_results_l2[2*i +1][7:])))/m1_rescale[i,2], label = 'l2', color='g')

for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],((np.sum(array_results_l3[2*i][7:]))+(np.sum(array_results_l3[2*i +1][7:])))/m1_rescale[i,3], label = 'l3', color='b')

for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l4[i],((np.sum(array_results_l4[2*i][7:]))+(np.sum(array_results_l4[2*i +1][7:])))/m1_rescale[i,4], label = 'l4', color='orange')

for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l4[i],((np.sum(array_results_l5[2*i][7:]))+(np.sum(array_results_l5[2*i +1][7:])))/m1_rescale[i,5], label = 'l5', color='magenta')

#for i in range(0,len(omegas_l2),1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*(((np.sum(array_results_l2[2*i][7:]))+(np.sum(array_results_l2[2*i +1][7:])))+((np.sum(array_results_l1[2*i][7:]))+(np.sum(array_results_l1[2*i +1][7:])))), label = 'summed', color='g')

ax[0].set_xscale('log')
ax[0].set_yscale('symlog')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-150],handles[-60],handles[-40]],[labels[0],labels[-150],labels[-60],labels[-40]])
ax[1].set_xlim(4,16)
#ax[0].set_ylim(-3e-4,6e-5)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = ((np.sum(array_results_l2[2*i][7:]))+(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = ((np.sum(array_results_l1[2*i][7:]))+(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega RT terms')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:])))/m1_rescale[i,1], label = 'l1', color='r')
for i in range(0,len(omegas_l2),1):
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][7:])+np.sum(array_results_l2[2*i +1][7:])))/m1_rescale[i,2], label = 'l2', color='g')

for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][7:])+np.sum(array_results_l3[2*i +1][7:])))/m1_rescale[i,3], label = 'l3', color='b')

for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][7:])+np.sum(array_results_l4[2*i +1][7:])))/m1_rescale[i,4], label = 'l4', color='orange')
for i in range(0,len(omegas_l4),1):
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][7:])+np.sum(array_results_l5[2*i +1][7:])))/m1_rescale[i,5], label = 'l5', color='magenta')

#for i in range(0,len(omegas_l2),1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*((np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))+(np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))), label = 'summed', color='g')

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-130],handles[-60],handles[-1]],[labels[0],labels[-130],labels[-60],labels[-1]])
#ax[1].set_xlim(4,16)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega RT terms abs')
plt.savefig("PBH/RTallabs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8])))/m1_rescale[i,1], label = '8',color='teal')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9])))/m1_rescale[i,1], label = '9',color='y')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10])))/m1_rescale[i,1], label = '10',color='b')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][10:11])+np.sum(array_results_l1[2*i +1][10:11])))/m1_rescale[i,1], label = '11',color='magenta')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][11:12])+np.sum(array_results_l1[2*i +1][11:12])))/m1_rescale[i,1], label = '12',color='g')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][12:13])+np.sum(array_results_l1[2*i +1][12:13])))/m1_rescale[i,1], label = '13',color='r')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:])))/m1_rescale[i,1], label = 'l=1', color='black')

    #for i in range(0,len(omegas_l2),1):

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])
#ax[1].set_xlim(4,16)
#ax[0].set_ylim(1e-6,1e-4)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega RT terms abs l1')
plt.savefig("PBH/RTl1noleg.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][7:8])+np.sum(array_results_l2[2*i +1][7:8])))/m1_rescale[i,2], label = '8',color='teal')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][8:9])+np.sum(array_results_l2[2*i +1][8:9])))/m1_rescale[i,2], label = '9',color='y')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][9:10])+np.sum(array_results_l2[2*i +1][9:10])))/m1_rescale[i,2], label = '10',color='b')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][10:11])+np.sum(array_results_l2[2*i +1][10:11])))/m1_rescale[i,2], label = '11',color='magenta')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][11:12])+np.sum(array_results_l2[2*i +1][11:12])))/m1_rescale[i,2], label = '12',color='g')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][12:13])+np.sum(array_results_l2[2*i +1][12:13])))/m1_rescale[i,2], label = '13',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][7:])+np.sum(array_results_l2[2*i +1][7:])))/m1_rescale[i,2], label = 'l=2', color='black')

    #for i in range(0,len(omegas_l2),1):

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])
#ax[1].set_xlim(4,16)
#ax[0].set_ylim(1e-6,1e-4)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega RT terms abs l2')
plt.savefig("PBH/RTl2noleg.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][7:8])+np.sum(array_results_l3[2*i +1][7:8])))/m1_rescale[i,3], label = '8',color='teal')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][8:9])+np.sum(array_results_l3[2*i +1][8:9])))/m1_rescale[i,3], label = '9',color='y')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][9:10])+np.sum(array_results_l3[2*i +1][9:10])))/m1_rescale[i,3], label = '10',color='b')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][10:11])+np.sum(array_results_l3[2*i +1][10:11])))/m1_rescale[i,3], label = '11',color='magenta')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][11:12])+np.sum(array_results_l3[2*i +1][11:12])))/m1_rescale[i,3], label = '12',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][12:13])+np.sum(array_results_l3[2*i +1][12:13])))/m1_rescale[i,3], label = '13',color='r')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][7:])+np.sum(array_results_l3[2*i +1][7:])))/m1_rescale[i,3], label = 'l=3', color='black')

    #for i in range(0,len(omegas_l2),1):

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])
#ax[1].set_xlim(4,16)
#ax[0].set_ylim(1e-6,1e-4)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega RT terms abs l3')
plt.savefig("PBH/RTl3.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][7:8])+np.sum(array_results_l4[2*i +1][7:8])))/m1_rescale[i,4], label = '8',color='teal')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][8:9])+np.sum(array_results_l4[2*i +1][8:9])))/m1_rescale[i,4], label = '9',color='y')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][9:10])+np.sum(array_results_l4[2*i +1][9:10])))/m1_rescale[i,4], label = '10',color='b')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][10:11])+np.sum(array_results_l4[2*i +1][10:11])))/m1_rescale[i,4], label = '11',color='magenta')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][11:12])+np.sum(array_results_l4[2*i +1][11:12])))/m1_rescale[i,4], label = '12',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][12:13])+np.sum(array_results_l4[2*i +1][12:13])))/m1_rescale[i,4], label = '13',color='r')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][7:])+np.sum(array_results_l4[2*i +1][7:])))/m1_rescale[i,4], label = 'l=4', color='black')

    #for i in range(0,len(omegas_l2),1):

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])
#ax[1].set_xlim(4,16)
#ax[0].set_ylim(1e-6,1e-4)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega RT terms abs l4')
plt.savefig("PBH/RTl4.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][7:8])+np.sum(array_results_l5[2*i +1][7:8])))/m1_rescale[i,5], label = '8',color='teal')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][8:9])+np.sum(array_results_l5[2*i +1][8:9])))/m1_rescale[i,5], label = '9',color='y')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][9:10])+np.sum(array_results_l5[2*i +1][9:10])))/m1_rescale[i,5], label = '10',color='b')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][10:11])+np.sum(array_results_l5[2*i +1][10:11])))/m1_rescale[i,5], label = '11',color='magenta')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][11:12])+np.sum(array_results_l5[2*i +1][11:12])))/m1_rescale[i,5], label = '12',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][12:13])+np.sum(array_results_l5[2*i +1][12:13])))/m1_rescale[i,5], label = '13',color='r')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][7:])+np.sum(array_results_l5[2*i +1][7:])))/m1_rescale[i,5], label = 'l=5', color='black')

    #for i in range(0,len(omegas_l2),1):

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])
#ax[1].set_xlim(4,16)
#ax[0].set_ylim(1e-6,1e-4)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega RT terms abs l5')
plt.savefig("PBH/RTl5.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8])))/m1_rescale[i,1], label = '8',color='teal')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9])))/m1_rescale[i,1], label = '9',color='y')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10])))/m1_rescale[i,1], label = '10',color='b')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][10:11])+np.sum(array_results_l1[2*i +1][10:11])))/m1_rescale[i,1], label = '11',color='magenta')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][11:12])+np.sum(array_results_l1[2*i +1][11:12])))/m1_rescale[i,1], label = '12',color='g')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][12:13])+np.sum(array_results_l1[2*i +1][12:13])))/m1_rescale[i,1], label = '13',color='r')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:])))/m1_rescale[i,1], label = 'l=1', color='black')

    #for i in range(0,len(omegas_l2),1):

ax[0].set_xscale('log')
#ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])
#ax[1].set_xlim(4,16)
#ax[0].set_ylim(1e-6,1e-4)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega RT terms l1')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l2[2*i][7:8])+np.sum(array_results_l2[2*i +1][7:8])))/m1_rescale[i,2], label = '8',color='teal')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l2[2*i][8:9])+np.sum(array_results_l2[2*i +1][8:9])))/m1_rescale[i,2], label = '9',color='y')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l2[2*i][9:10])+np.sum(array_results_l2[2*i +1][9:10])))/m1_rescale[i,2], label = '10',color='b')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l2[2*i][10:11])+np.sum(array_results_l2[2*i +1][10:11])))/m1_rescale[i,2], label = '11',color='magenta')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l2[2*i][11:12])+np.sum(array_results_l2[2*i +1][11:12])))/m1_rescale[i,2], label = '12',color='g')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l2[2*i][12:13])+np.sum(array_results_l2[2*i +1][12:13])))/m1_rescale[i,2], label = '13',color='r')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l2[2*i][7:])+np.sum(array_results_l2[2*i +1][7:])))/m1_rescale[i,2], label = 'l=2', color='black')

    #for i in range(0,len(omegas_l2),1):

ax[0].set_xscale('log')
#ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])
#ax[1].set_xlim(4,16)
#ax[0].set_ylim(1e-6,1e-4)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega RT terms l2')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l3[2*i][7:8])+np.sum(array_results_l3[2*i +1][7:8])))/m1_rescale[i,3], label = '8',color='teal')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l3[2*i][8:9])+np.sum(array_results_l3[2*i +1][8:9])))/m1_rescale[i,3], label = '9',color='y')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l3[2*i][9:10])+np.sum(array_results_l3[2*i +1][9:10])))/m1_rescale[i,3], label = '10',color='b')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l3[2*i][10:11])+np.sum(array_results_l3[2*i +1][10:11])))/m1_rescale[i,3], label = '11',color='magenta')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l3[2*i][11:12])+np.sum(array_results_l3[2*i +1][11:12])))/m1_rescale[i,3], label = '12',color='g')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l3[2*i][12:13])+np.sum(array_results_l3[2*i +1][12:13])))/m1_rescale[i,3], label = '13',color='r')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l3[2*i][7:])+np.sum(array_results_l3[2*i +1][7:])))/m1_rescale[i,3], label = 'l=3', color='black')

    #for i in range(0,len(omegas_l2),1):

ax[0].set_xscale('log')
#ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])
#ax[1].set_xlim(4,16)
#ax[0].set_ylim(1e-6,1e-4)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega RT terms abs l3')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l4[2*i][7:8])+np.sum(array_results_l4[2*i +1][7:8])))/m1_rescale[i,4], label = '8',color='teal')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l4[2*i][8:9])+np.sum(array_results_l4[2*i +1][8:9])))/m1_rescale[i,4], label = '9',color='y')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l4[2*i][9:10])+np.sum(array_results_l4[2*i +1][9:10])))/m1_rescale[i,4], label = '10',color='b')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l4[2*i][10:11])+np.sum(array_results_l4[2*i +1][10:11])))/m1_rescale[i,4], label = '11',color='magenta')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l4[2*i][11:12])+np.sum(array_results_l4[2*i +1][11:12])))/m1_rescale[i,4], label = '12',color='g')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l4[2*i][12:13])+np.sum(array_results_l4[2*i +1][12:13])))/m1_rescale[i,4], label = '13',color='r')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l4[2*i][7:])+np.sum(array_results_l4[2*i +1][7:])))/m1_rescale[i,4], label = 'l=4', color='black')

    #for i in range(0,len(omegas_l2),1):

ax[0].set_xscale('log')
#ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])
#ax[1].set_xlim(4,16)
#ax[0].set_ylim(1e-6,1e-4)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega RT terms abs l4')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l5[2*i][7:8])+np.sum(array_results_l5[2*i +1][7:8])))/m1_rescale[i,5], label = '8',color='teal')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l5[2*i][8:9])+np.sum(array_results_l5[2*i +1][8:9])))/m1_rescale[i,5], label = '9',color='y')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l5[2*i][9:10])+np.sum(array_results_l5[2*i +1][9:10])))/m1_rescale[i,5], label = '10',color='b')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l5[2*i][10:11])+np.sum(array_results_l5[2*i +1][10:11])))/m1_rescale[i,5], label = '11',color='magenta')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l5[2*i][11:12])+np.sum(array_results_l5[2*i +1][11:12])))/m1_rescale[i,5], label = '12',color='g')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l5[2*i][12:13])+np.sum(array_results_l5[2*i +1][12:13])))/m1_rescale[i,5], label = '13',color='r')
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l5[2*i][7:])+np.sum(array_results_l5[2*i +1][7:])))/m1_rescale[i,5], label = 'l=5', color='black')

    #for i in range(0,len(omegas_l2),1):

ax[0].set_xscale('log')
#ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])
#ax[1].set_xlim(4,16)
#ax[0].set_ylim(1e-6,1e-4)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega RT terms abs l5')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][0])+np.sum(array_results_l1[2*i +1][0])))/m1_rescale[i,1], label = '1',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][0])+np.sum(array_results_l2[2*i +1][0])))/m1_rescale[i,2], label = '2',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][0])+np.sum(array_results_l3[2*i +1][0])))/m1_rescale[i,3], label = '3',color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][0])+np.sum(array_results_l4[2*i +1][0])))/m1_rescale[i,4], label = '4',color='orange')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][0])+np.sum(array_results_l5[2*i +1][0])))/m1_rescale[i,5], label = '5',color='magenta')
    
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])
#handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega term 1 abs')
plt.savefig("PBH/term1abs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][0])+np.sum(array_results_l1[2*i +1][0])))/m1_rescale[i,1], label = '1',color='r')
    ax[0].scatter(omegas_l2[i],((np.sum(array_results_l2[2*i][0])+np.sum(array_results_l2[2*i +1][0])))/m1_rescale[i,2], label = '2',color='g')
    ax[0].scatter(omegas_l3[i],((np.sum(array_results_l3[2*i][0])+np.sum(array_results_l3[2*i +1][0])))/m1_rescale[i,3], label = '3',color='b')
    ax[0].scatter(omegas_l4[i],((np.sum(array_results_l4[2*i][0])+np.sum(array_results_l4[2*i +1][0])))/m1_rescale[i,4], label = '4',color='orange')
    ax[0].scatter(omegas_l4[i],((np.sum(array_results_l5[2*i][0])+np.sum(array_results_l5[2*i +1][0])))/m1_rescale[i,5], label = '5',color='magenta')
    
    
ax[0].set_xscale('log')
#ax[0].set_yscale('log')

#handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[-40],handles[-1]],[labels[0],labels[-40],labels[-1]])
handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega term 1')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][1])+np.sum(array_results_l1[2*i +1][1])))/m1_rescale[i,1], label = '1',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][1])+np.sum(array_results_l2[2*i +1][1])))/m1_rescale[i,2], label = '2',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][1])+np.sum(array_results_l3[2*i +1][1])))/m1_rescale[i,3], label = '3',color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][1])+np.sum(array_results_l4[2*i +1][1])))/m1_rescale[i,4], label = '4',color='orange')
    ax[0].scatter(omegas_l5[i],(np.abs(np.sum(array_results_l5[2*i][1])+np.sum(array_results_l5[2*i +1][1])))/m1_rescale[i,5], label = '5',color='magenta')
    
    
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])
#handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega term 2 abs')
plt.savefig("PBH/term2abs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][2])+np.sum(array_results_l1[2*i +1][2])))/m1_rescale[i,1], label = '1',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][2])+np.sum(array_results_l2[2*i +1][2])))/m1_rescale[i,2], label = '2',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][2])+np.sum(array_results_l3[2*i +1][2])))/m1_rescale[i,3], label = '3',color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][2])+np.sum(array_results_l4[2*i +1][2])))/m1_rescale[i,4], label = '4',color='orange')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][2])+np.sum(array_results_l5[2*i +1][2])))/m1_rescale[i,5], label = '5',color='magenta')
    
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])
#handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega term 3 abs')
plt.savefig("PBH/term3abs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][3])+np.sum(array_results_l1[2*i +1][3])))/m1_rescale[i,1], label = '1',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][3])+np.sum(array_results_l2[2*i +1][3])))/m1_rescale[i,2], label = '2',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][3])+np.sum(array_results_l3[2*i +1][3])))/m1_rescale[i,3], label = '3',color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][3])+np.sum(array_results_l4[2*i +1][3])))/m1_rescale[i,4], label = '4',color='orange')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][3])+np.sum(array_results_l5[2*i +1][3])))/m1_rescale[i,5], label = '5',color='magenta')
    
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])
#handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega term 4 abs')
plt.savefig("PBH/term4abs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][4])+np.sum(array_results_l1[2*i +1][4])))/m1_rescale[i,1], label = '1',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][4])+np.sum(array_results_l2[2*i +1][4])))/m1_rescale[i,2], label = '2',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][4])+np.sum(array_results_l3[2*i +1][4])))/m1_rescale[i,3], label = '3',color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][4])+np.sum(array_results_l4[2*i +1][4])))/m1_rescale[i,4], label = '4',color='orange')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][4])+np.sum(array_results_l5[2*i +1][4])))/m1_rescale[i,5], label = '5',color='magenta')
    
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])
#handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega term 5 abs')
plt.savefig("PBH/term5abs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][5])+np.sum(array_results_l1[2*i +1][5])))/m1_rescale[i,1], label = '1',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][5])+np.sum(array_results_l2[2*i +1][5])))/m1_rescale[i,2], label = '2',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][5])+np.sum(array_results_l3[2*i +1][5])))/m1_rescale[i,3], label = '3',color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][5])+np.sum(array_results_l4[2*i +1][5])))/m1_rescale[i,4], label = '4',color='orange')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][5])+np.sum(array_results_l5[2*i +1][5])))/m1_rescale[i,5], label = '5',color='magenta')
    
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])
#handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega term 6 abs')
plt.savefig("PBH/term6abs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][6])+np.sum(array_results_l1[2*i +1][6])))/m1_rescale[i,1], label = '1',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][6])+np.sum(array_results_l2[2*i +1][6])))/m1_rescale[i,2], label = '2',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][6])+np.sum(array_results_l3[2*i +1][6])))/m1_rescale[i,3], label = '3',color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][6])+np.sum(array_results_l4[2*i +1][6])))/m1_rescale[i,4], label = '4',color='orange')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][6])+np.sum(array_results_l5[2*i +1][6])))/m1_rescale[i,5], label = '5',color='magenta')
    
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])
#handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)

for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:])+np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')

ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega term 7 abs')
plt.savefig("PBH/term7abs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7])+np.sum(array_results_l1[2*i +1][7])))/m1_rescale[i,1], label = '1',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][7])+np.sum(array_results_l2[2*i +1][7])))/m1_rescale[i,2], label = '2',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][7])+np.sum(array_results_l3[2*i +1][7])))/m1_rescale[i,3], label = '3',color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][7])+np.sum(array_results_l4[2*i +1][7])))/m1_rescale[i,4], label = '4',color='orange')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][7])+np.sum(array_results_l5[2*i +1][7])))/m1_rescale[i,5], label = '5',color='magenta')
    
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])
#handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega term 8 abs')
plt.savefig("PBH/term8abs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][8])+np.sum(array_results_l1[2*i +1][8])))/m1_rescale[i,1], label = '1',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][8])+np.sum(array_results_l2[2*i +1][8])))/m1_rescale[i,2], label = '2',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][8])+np.sum(array_results_l3[2*i +1][8])))/m1_rescale[i,3], label = '3',color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][8])+np.sum(array_results_l4[2*i +1][8])))/m1_rescale[i,4], label = '4',color='orange')
    ax[0].scatter(omegas_l5[i],(np.abs(np.sum(array_results_l5[2*i][8])+np.sum(array_results_l5[2*i +1][8])))/m1_rescale[i,5], label = '5',color='magenta')
    
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])
#handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega term 9 abs')
plt.savefig("PBH/term9abs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][9])+np.sum(array_results_l1[2*i +1][9])))/m1_rescale[i,1], label = '1',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][9])+np.sum(array_results_l2[2*i +1][9])))/m1_rescale[i,2], label = '2',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][9])+np.sum(array_results_l3[2*i +1][9])))/m1_rescale[i,3], label = '3',color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][9])+np.sum(array_results_l4[2*i +1][9])))/m1_rescale[i,4], label = '4',color='orange')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][9])+np.sum(array_results_l5[2*i +1][9])))/m1_rescale[i,5], label = '5',color='magenta')
    
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])
#handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega term 10 abs')
plt.savefig("PBH/term10abs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][10])+np.sum(array_results_l1[2*i +1][10])))/m1_rescale[i,1], label = '1',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][10])+np.sum(array_results_l2[2*i +1][10])))/m1_rescale[i,2], label = '2',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][10])+np.sum(array_results_l3[2*i +1][10])))/m1_rescale[i,3], label = '3',color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][10])+np.sum(array_results_l4[2*i +1][10])))/m1_rescale[i,4], label = '4',color='orange')
    ax[0].scatter(omegas_l5[i],(np.abs(np.sum(array_results_l5[2*i][10])+np.sum(array_results_l5[2*i +1][10])))/m1_rescale[i,5], label = '5',color='magenta')
    
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])
handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega term 11 abs')
plt.savefig("PBH/term11abs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][11])+np.sum(array_results_l1[2*i +1][11])))/m1_rescale[i,1], label = '1',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][11])+np.sum(array_results_l2[2*i +1][11])))/m1_rescale[i,2], label = '2',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][11])+np.sum(array_results_l3[2*i +1][11])))/m1_rescale[i,3], label = '3',color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][11])+np.sum(array_results_l4[2*i +1][11])))/m1_rescale[i,4], label = '4',color='orange')
    ax[0].scatter(omegas_l5[i],(np.abs(np.sum(array_results_l5[2*i][11])+np.sum(array_results_l5[2*i +1][11])))/m1_rescale[i,5], label = '5',color='magenta')
    
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])
#handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega term 12 abs')
plt.savefig("PBH/term12abs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][12])+np.sum(array_results_l1[2*i +1][12])))/m1_rescale[i,1], label = '1',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][12])+np.sum(array_results_l2[2*i +1][12])))/m1_rescale[i,2], label = '2',color='g')
    ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][12])+np.sum(array_results_l3[2*i +1][12])))/m1_rescale[i,3], label = '3',color='b')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l4[2*i][12])+np.sum(array_results_l4[2*i +1][12])))/m1_rescale[i,4], label = '4',color='orange')
    ax[0].scatter(omegas_l4[i],(np.abs(np.sum(array_results_l5[2*i][12])+np.sum(array_results_l5[2*i +1][12])))/m1_rescale[i,5], label = '5',color='magenta')
    
ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])
#handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][7:]))+np.abs(np.sum(array_results_l2[2*i +1][7:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][7:]))+np.abs(np.sum(array_results_l1[2*i +1][7:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
ax[0].set_title('all omega term 13 abs')
plt.savefig("PBH/term13abs.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
y1listpos =[]
y1listneg =[]
y2listpos =[]
y2listneg =[]


y3listpos =[]
y3listneg =[]
y4listpos =[]
y4listneg =[]
y5listpos =[]
y5listneg =[]


ytotalpos =[]
ytotalneg =[]


color1 =[]
for i in range(0,len(omegas_l1),1):
    
    y1 =np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:])
    if y1>0:
        y1listpos.append(np.abs(y1)/m1_rescale[i,1])
        y1listneg.append(None)
    if y1<0:
        y1listpos.append(None)
        y1listneg.append(np.abs(y1)/m1_rescale[i,1])
    y2 =np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:])
    if y2>0:
        y2listpos.append(np.abs(y2)/m1_rescale[i,2])
        y2listneg.append(None)
    if y2<0:
        y2listpos.append(None)
        y2listneg.append(np.abs(y2)/m1_rescale[i,2])
    
    y3 =np.sum(array_results_l3[2*i][:])+np.sum(array_results_l3[2*i +1][:])
    if y3>0:
        y3listpos.append(np.abs(y3)/m1_rescale[i,3])
        y3listneg.append(None)
    if y3<0:
        y3listpos.append(None)
        y3listneg.append(np.abs(y3)/m1_rescale[i,3])
    y4 =np.sum(array_results_l4[2*i][:])+np.sum(array_results_l4[2*i +1][:])
    if y4>0:
        y4listpos.append(np.abs(y4)/m1_rescale[i,4])
        y4listneg.append(None)
    if y4<0:
        y4listpos.append(None)
        y4listneg.append(np.abs(y4)/m1_rescale[i,4])
    y5 =np.sum(array_results_l5[2*i][:])+np.sum(array_results_l5[2*i +1][:])
    if y5>0:
        y5listpos.append(np.abs(y5)/m1_rescale[i,5])
        y5listneg.append(None)
    if y5<0:
        y5listpos.append(None)
        y5listneg.append(np.abs(y5)/m1_rescale[i,5])
     
    yall =y1/m1_rescale[i,1]+y2/m1_rescale[i,2]+y3/m1_rescale[i,3]+y4/m1_rescale[i,4]+y5/m1_rescale[i,5]
    if yall>0:
        ytotalpos.append(np.abs(yall))
        ytotalneg.append(None)
    if yall<0:
        ytotalpos.append(None)
        ytotalneg.append(np.abs(yall))
        
    
    
    #color1.append('r' if y1<0 else 'g')


    
ax.plot(omegas_l1,np.array(y1listpos), label = 'l1', color ='r',linestyle='-')
ax.plot(omegas_l1,np.array(y1listneg), label = 'l1', color ='r',linestyle='--')
ax.plot(omegas_l1,np.array(y2listpos), label = 'l2', color ='g',linestyle='-')
ax.plot(omegas_l1,np.array(y2listneg), label = 'l2', color ='g',linestyle='--')

ax.plot(omegas_l3,np.array(y3listpos), label = 'l3', color ='b',linestyle='-')
ax.plot(omegas_l3,np.array(y3listneg), label = 'l3', color ='b',linestyle='--')
ax.plot(omegas_l4,np.array(y4listpos), label = 'l4', color ='orange',linestyle='-')
ax.plot(omegas_l4,np.array(y4listneg), label = 'l4', color ='orange',linestyle='--')
ax.plot(omegas_l4,np.array(y5listpos), label = 'l5', color ='magenta',linestyle='-')
ax.plot(omegas_l4,np.array(y5listneg), label = 'l5', color ='magenta',linestyle='--')

ax.plot(omegas_l4,np.array(ytotalpos), label = 'sum', color ='black',linestyle='-')
ax.plot(omegas_l4,np.array(ytotalneg), label = 'sum', color ='black',linestyle='--')

#for i in range(0,len(omegas_l2)-1,1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*(np.abs(np.sum(array_results_l2[2*i][:]))+np.abs(np.sum(array_results_l2[2*i +1][:]))), label = 'l2', color='b')

#for i in range(0,len(omegas_l2)-,1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*((np.abs(np.sum(array_results_l2[2*i][:]))+np.abs(np.sum(array_results_l2[2*i +1][:])))+(np.abs(np.sum(array_results_l1[2*i][:]))+np.abs(np.sum(array_results_l1[2*i +1][:])))), label = 'summed', color='g')

ax.set_xscale('log')
ax.set_yscale('log')

handles, labels = ax.get_legend_handles_labels()
ax.legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6],handles[7],handles[8],handles[9]],['l=1 positive','l=1 negative','l=2 positive','l=2 negative','l=3 positive','l=3 negative','l=4 positive','l=4 negative','summed positive','summed negative'])
#ax.legend([handles[0],handles[1]],['l=1 positive','l=1 negative'])

ax.set_xlim(.04,16)
#ax[0].set_ylim(0,1e-2)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][:]))+np.abs(np.sum(array_results_l2[2*i +1][:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][:]))+np.abs(np.sum(array_results_l1[2*i +1][:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
plt.xlabel('omega (units of T_Hawking)')
plt.ylabel('dN/d_omega dt')
ax.set_title('Spectra for M=1e21 l=1 ')
#plt.savefig('totall1and3.pdf',bbox_inches='tight')
plt.savefig("PBH/absnegandpos.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=5, ncols=1, sharex=True,figsize=(8, 20))
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][:3])+np.sum(array_results_l1[2*i +1][:3])))/m1_rescale[i,1], label = 'l=1 all reflection', color='black',facecolors='none' if ((np.sum(array_results_l1[2*i][:3])+np.sum(array_results_l1[2*i +1][:3])))<0 else 'black')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][0:1])+np.sum(array_results_l1[2*i +1][0:1])))/m1_rescale[i,1], label = 'term 1', color='r',facecolors='none' if  ((np.sum(array_results_l1[2*i][0:1])+np.sum(array_results_l1[2*i +1][0:1])))<0 else  'r')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][1:2])+np.sum(array_results_l1[2*i +1][1:2])))/m1_rescale[i,1], label = 'term 2', color='g',facecolors='none' if ((np.sum(array_results_l1[2*i][1:2])+np.sum(array_results_l1[2*i +1][1:2])))<0 else 'g')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][2:3])+np.sum(array_results_l1[2*i +1][2:3])))/m1_rescale[i,1], label = 'term 3', color='b',facecolors='none' if  ((np.sum(array_results_l1[2*i][2:3])+np.sum(array_results_l1[2*i +1][2:3])))<0 else 'b')

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[25],handles[70],handles[-1]],[labels[0],labels[5],labels[70],labels[-1]])

ax[0].set_title('Reflection terms abs l1')
for i in range(0,len(omegas_l1),1):
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][:3])+np.sum(array_results_l2[2*i +1][:3])))/m1_rescale[i,2], label = 'l=2 all reflection', color='black',facecolors='none' if ((np.sum(array_results_l2[2*i][:3])+np.sum(array_results_l2[2*i +1][:3])))<0 else 'black')
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][0:1])+np.sum(array_results_l2[2*i +1][0:1])))/m1_rescale[i,2], label = 'term 1', color='r',facecolors='none' if  ((np.sum(array_results_l2[2*i][0:1])+np.sum(array_results_l2[2*i +1][0:1])))<0 else  'r')
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][1:2])+np.sum(array_results_l2[2*i +1][1:2])))/m1_rescale[i,2], label = 'term 2', color='g',facecolors='none' if ((np.sum(array_results_l2[2*i][1:2])+np.sum(array_results_l2[2*i +1][1:2])))<0 else 'g')
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][2:3])+np.sum(array_results_l2[2*i +1][2:3])))/m1_rescale[i,2], label = 'term 3', color='b',facecolors='none' if  ((np.sum(array_results_l2[2*i][2:3])+np.sum(array_results_l2[2*i +1][2:3])))<0 else 'b')

ax[1].set_xscale('log')
ax[1].set_yscale('log')

handles, labels = ax[1].get_legend_handles_labels()
ax[1].legend([handles[0],handles[25],handles[70],handles[-1]],[labels[0],labels[5],labels[70],labels[-1]])

ax[1].set_title('Reflection terms abs l2')

for i in range(0,len(omegas_l3),1):
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][:3])+np.sum(array_results_l3[2*i +1][:3])))/m1_rescale[i,3], label = 'l=3 all reflection', color='black',facecolors ='none' if ((np.sum(array_results_l3[2*i][:3])+np.sum(array_results_l3[2*i +1][:3])))<0 else 'black')
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][0:1])+np.sum(array_results_l3[2*i +1][0:1])))/m1_rescale[i,3], label = 'term 1', color='r',facecolors ='none' if  ((np.sum(array_results_l3[2*i][0:1])+np.sum(array_results_l3[2*i +1][0:1])))<0 else 'r')
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][1:2])+np.sum(array_results_l3[2*i +1][1:2])))/m1_rescale[i,3], label = 'term 2', color='g',facecolors = 'none' if  ((np.sum(array_results_l3[2*i][1:2])+np.sum(array_results_l3[2*i +1][1:2])))<0 else 'g')
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][2:3])+np.sum(array_results_l3[2*i +1][2:3])))/m1_rescale[i,3], label = 'term 3', color='b',facecolors = 'none' if  ((np.sum(array_results_l3[2*i][2:3])+np.sum(array_results_l3[2*i +1][2:3])))<0 else 'b')


ax[2].set_yscale('log')

handles, labels = ax[2].get_legend_handles_labels()
ax[2].legend([handles[0],handles[25],handles[70],handles[-1]],[labels[0],labels[5],labels[70],labels[-1]])

ax[2].set_title('Reflection terms abs l3')
for i in range(0,len(omegas_l1),1):
    ax[3].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l4[2*i][:3])+np.sum(array_results_l4[2*i +1][:3])))/m1_rescale[i,4], label = 'l=4 all reflection', color='black',facecolors='none' if ((np.sum(array_results_l4[2*i][:3])+np.sum(array_results_l4[2*i +1][:3])))<0 else 'black')
    ax[3].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l4[2*i][0:1])+np.sum(array_results_l4[2*i +1][0:1])))/m1_rescale[i,4], label = 'term 1', color='r',facecolors='none' if  ((np.sum(array_results_l4[2*i][0:1])+np.sum(array_results_l4[2*i +1][0:1])))<0 else  'r')
    ax[3].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l4[2*i][1:2])+np.sum(array_results_l4[2*i +1][1:2])))/m1_rescale[i,4], label = 'term 2', color='g',facecolors='none' if ((np.sum(array_results_l4[2*i][1:2])+np.sum(array_results_l4[2*i +1][1:2])))<0 else 'g')
    ax[3].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l4[2*i][2:3])+np.sum(array_results_l4[2*i +1][2:3])))/m1_rescale[i,4], label = 'term 3', color='b',facecolors='none' if  ((np.sum(array_results_l4[2*i][2:3])+np.sum(array_results_l4[2*i +1][2:3])))<0 else 'b')

ax[3].set_xscale('log')
ax[3].set_yscale('log')

handles, labels = ax[3].get_legend_handles_labels()
ax[3].legend([handles[0],handles[25],handles[70],handles[-1]],[labels[0],labels[5],labels[70],labels[-1]])

ax[3].set_title('Reflection terms abs l4')

for i in range(0,len(omegas_l1),1):
    ax[4].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l5[2*i][:3])+np.sum(array_results_l5[2*i +1][:3])))/m1_rescale[i,5], label = 'l=5 all reflection', color='black',facecolors='none' if ((np.sum(array_results_l5[2*i][:3])+np.sum(array_results_l5[2*i +1][:3])))<0 else 'black')
    ax[4].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l5[2*i][0:1])+np.sum(array_results_l5[2*i +1][0:1])))/m1_rescale[i,5], label = 'term 1', color='r',facecolors='none' if  ((np.sum(array_results_l5[2*i][0:1])+np.sum(array_results_l5[2*i +1][0:1])))<0 else  'r')
    ax[4].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l5[2*i][1:2])+np.sum(array_results_l5[2*i +1][1:2])))/m1_rescale[i,5], label = 'term 2', color='g',facecolors='none' if ((np.sum(array_results_l5[2*i][1:2])+np.sum(array_results_l5[2*i +1][1:2])))<0 else 'g')
    ax[4].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l5[2*i][2:3])+np.sum(array_results_l5[2*i +1][2:3])))/m1_rescale[i,5], label = 'term 3', color='b',facecolors='none' if  ((np.sum(array_results_l5[2*i][2:3])+np.sum(array_results_l5[2*i +1][2:3])))<0 else 'b')

ax[4].set_xscale('log')
ax[4].set_yscale('log')

handles, labels = ax[4].get_legend_handles_labels()
ax[4].legend([handles[0],handles[25],handles[70],handles[-1]],[labels[0],labels[5],labels[70],labels[-1]])

ax[4].set_title('Reflection terms abs l5')


plt.xlabel('omega')
plt.ylabel('dN/ d_omega dt')
plt.savefig('PBH/reflection12345.pdf',bbox_inches='tight')

plt.show()

# %%
fig, ax = plt.subplots(nrows=5, ncols=1, sharex=True,figsize=(8, 20))
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][3:7])+np.sum(array_results_l1[2*i +1][3:7])))/m1_rescale[i,1], label = 'l=1 all transmission', color='black',facecolors='none' if ((np.sum(array_results_l1[2*i][3:7])+np.sum(array_results_l1[2*i +1][3:7])))<0 else 'black')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][3:4])+np.sum(array_results_l1[2*i +1][3:4])))/m1_rescale[i,1], label = 'term 4', color='r',facecolors='none' if  ((np.sum(array_results_l1[2*i][3:4])+np.sum(array_results_l1[2*i +1][3:4])))<0 else  'r')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][4:5])+np.sum(array_results_l1[2*i +1][4:5])))/m1_rescale[i,1], label = 'term 5', color='g',facecolors='none' if ((np.sum(array_results_l1[2*i][4:5])+np.sum(array_results_l1[2*i +1][4:5])))<0 else 'g')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][5:6])+np.sum(array_results_l1[2*i +1][5:6])))/m1_rescale[i,1], label = 'term 6', color='b',facecolors='none' if  ((np.sum(array_results_l1[2*i][5:6])+np.sum(array_results_l1[2*i +1][5:6])))<0 else 'b')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][6:7])+np.sum(array_results_l1[2*i +1][6:7])))/m1_rescale[i,1], label = 'term 7', color='orange',facecolors='none' if  (
        (np.sum(array_results_l1[2*i][6:7])+np.sum(array_results_l1[2*i +1][6:7])))<0 else 'orange')

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-4],labels[-3],labels[-2],labels[-1]])

ax[0].set_title('Transmission terms abs l1')
for i in range(0,len(omegas_l1),1):
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][3:7])+np.sum(array_results_l2[2*i +1][3:7])))/m1_rescale[i,2], label = 'l=2 all transmission', color='black',facecolors='none' if ((np.sum(array_results_l2[2*i][3:7])+np.sum(array_results_l2[2*i +1][3:7])))<0 else 'black')
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][3:4])+np.sum(array_results_l2[2*i +1][3:4])))/m1_rescale[i,2], label = 'term 4', color='r',facecolors='none' if  ((np.sum(array_results_l2[2*i][3:4])+np.sum(array_results_l2[2*i +1][3:4])))<0 else  'r')
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][4:5])+np.sum(array_results_l2[2*i +1][4:5])))/m1_rescale[i,2], label = 'term 5', color='g',facecolors='none' if ((np.sum(array_results_l2[2*i][4:5])+np.sum(array_results_l2[2*i +1][4:5])))<0 else 'g')
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][5:6])+np.sum(array_results_l2[2*i +1][5:6])))/m1_rescale[i,2], label = 'term 6', color='b',facecolors='none' if  ((np.sum(array_results_l2[2*i][5:6])+np.sum(array_results_l2[2*i +1][5:6])))<0 else 'b')
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][6:7])+np.sum(array_results_l2[2*i +1][6:7])))/m1_rescale[i,2], label = 'term 7', color='orange',facecolors='none' if  (
        (np.sum(array_results_l2[2*i][6:7])+np.sum(array_results_l2[2*i +1][6:7])))<0 else 'orange')

ax[1].set_xscale('log')
ax[1].set_yscale('log')

handles, labels = ax[1].get_legend_handles_labels()
ax[1].legend([handles[0],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-4],labels[-3],labels[-2],labels[-1]])

ax[1].set_title('Transmission terms abs l2')

for i in range(0,len(omegas_l3),1):
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][3:7])+np.sum(array_results_l3[2*i +1][3:7])))/m1_rescale[i,3], label = 'l=3 all transmission', color='black',facecolors='none' if (np.sum(array_results_l3[2*i][3:7])+np.sum(array_results_l3[2*i +1][3:7]))<0 else 'black')
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][3:4])+np.sum(array_results_l3[2*i +1][3:4])))/m1_rescale[i,3], label = 'term 4', color='r',facecolors='none' if  ((np.sum(array_results_l3[2*i][3:4])+np.sum(array_results_l3[2*i +1][3:4])))<0 else  'r')
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][4:5])+np.sum(array_results_l3[2*i +1][4:5])))/m1_rescale[i,3], label = 'term 5', color='g',facecolors='none' if ((np.sum(array_results_l3[2*i][4:5])+np.sum(array_results_l3[2*i +1][4:5])))<0 else 'g')
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][5:6])+np.sum(array_results_l3[2*i +1][5:6])))/m1_rescale[i,3], label = 'term 6', color='b',facecolors='none' if  ((np.sum(array_results_l3[2*i][5:6])+np.sum(array_results_l3[2*i +1][5:6])))<0 else 'b')
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][6:7])+np.sum(array_results_l3[2*i +1][6:7])))/m1_rescale[i,3], label = 'term 7', color='orange',facecolors='none' if  ((np.sum(array_results_l3[2*i][6:7])+np.sum(array_results_l3[2*i +1][6:7])))<0 else 'orange')

ax[2].set_yscale('log')

handles, labels = ax[2].get_legend_handles_labels()
ax[2].legend([handles[0],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-4],labels[-3],labels[-2],labels[-1]])

ax[2].set_title('Transmission terms abs l3')

for i in range(0,len(omegas_l3),1):
    ax[3].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][3:7])+np.sum(array_results_l4[2*i +1][3:7])))/m1_rescale[i,4], label = 'l=4 all transmission', color='black',facecolors='none' if (np.sum(array_results_l4[2*i][3:7])+np.sum(array_results_l4[2*i +1][3:7]))<0 else 'black')
    ax[3].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][3:4])+np.sum(array_results_l4[2*i +1][3:4])))/m1_rescale[i,4], label = 'term 4', color='r',facecolors='none' if  ((np.sum(array_results_l4[2*i][3:4])+np.sum(array_results_l4[2*i +1][3:4])))<0 else  'r')
    ax[3].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][4:5])+np.sum(array_results_l4[2*i +1][4:5])))/m1_rescale[i,4], label = 'term 5', color='g',facecolors='none' if ((np.sum(array_results_l4[2*i][4:5])+np.sum(array_results_l4[2*i +1][4:5])))<0 else 'g')
    ax[3].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][5:6])+np.sum(array_results_l4[2*i +1][5:6])))/m1_rescale[i,4], label = 'term 6', color='b',facecolors='none' if  ((np.sum(array_results_l4[2*i][5:6])+np.sum(array_results_l4[2*i +1][5:6])))<0 else 'b')
    ax[3].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][6:7])+np.sum(array_results_l4[2*i +1][6:7])))/m1_rescale[i,4], label = 'term 7', color='orange',facecolors='none' if  ((np.sum(array_results_l4[2*i][6:7])+np.sum(array_results_l4[2*i +1][6:7])))<0 else 'orange')

ax[3].set_yscale('log')

handles, labels = ax[3].get_legend_handles_labels()
ax[3].legend([handles[0],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-4],labels[-3],labels[-2],labels[-1]])

ax[3].set_title('Transmission terms abs l4')

for i in range(0,len(omegas_l3),1):
    ax[4].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][3:7])+np.sum(array_results_l5[2*i +1][3:7])))/m1_rescale[i,5], label = 'l=5 all transmission', color='black',facecolors='none' if (np.sum(array_results_l5[2*i][3:7])+np.sum(array_results_l5[2*i +1][3:7]))<0 else 'black')
    ax[4].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][3:4])+np.sum(array_results_l5[2*i +1][3:4])))/m1_rescale[i,5], label = 'term 4', color='r',facecolors='none' if  ((np.sum(array_results_l5[2*i][3:4])+np.sum(array_results_l5[2*i +1][3:4])))<0 else  'r')
    ax[4].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][4:5])+np.sum(array_results_l5[2*i +1][4:5])))/m1_rescale[i,5], label = 'term 5', color='g',facecolors='none' if ((np.sum(array_results_l5[2*i][4:5])+np.sum(array_results_l5[2*i +1][4:5])))<0 else 'g')
    ax[4].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][5:6])+np.sum(array_results_l5[2*i +1][5:6])))/m1_rescale[i,5], label = 'term 6', color='b',facecolors='none' if  ((np.sum(array_results_l5[2*i][5:6])+np.sum(array_results_l5[2*i +1][5:6])))<0 else 'b')
    ax[4].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][6:7])+np.sum(array_results_l5[2*i +1][6:7])))/m1_rescale[i,5], label = 'term 7', color='orange',facecolors='none' if  ((np.sum(array_results_l5[2*i][6:7])+np.sum(array_results_l5[2*i +1][6:7])))<0 else 'orange')

ax[4].set_yscale('log')

handles, labels = ax[4].get_legend_handles_labels()
ax[4].legend([handles[0],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-4],labels[-3],labels[-2],labels[-1]])

ax[4].set_title('Transmission terms abs l5')


plt.savefig('PBH/Transmission12345.pdf',bbox_inches='tight')

plt.show()

# %%
fig, ax = plt.subplots(nrows=5, ncols=1, sharex=True,figsize=(8, 20))
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:])))/m1_rescale[i,1], label = 'l=1 all RT', color='black',facecolors='none' if ((np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:])))<0 else 'black')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8])))/m1_rescale[i,1], label = 'term 8', color='r',facecolors='none' if  ((np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8])))<0 else  'r')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9])))/m1_rescale[i,1], label = 'term 9', color='g',facecolors='none' if ((np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9])))<0 else 'g')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10])))/m1_rescale[i,1], label = 'term 10', color='b',facecolors='none' if  ((np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10])))<0 else 'b')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][10:11])+np.sum(array_results_l1[2*i +1][10:11])))/m1_rescale[i,1], label = 'term 11', color='orange',facecolors='none' if ((np.sum(array_results_l1[2*i][10:11])+np.sum(array_results_l1[2*i +1][10:11])))<0 else 'orange')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][11:12])+np.sum(array_results_l1[2*i +1][11:12])))/m1_rescale[i,1], label = 'term 12', color='cyan',facecolors='none' if ((np.sum(array_results_l1[2*i][11:12])+np.sum(array_results_l1[2*i +1][11:12])))<0 else 'cyan')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][12:13])+np.sum(array_results_l1[2*i +1][12:13])))/m1_rescale[i,1], label = 'term 13', color='magenta',facecolors='none' if ((np.sum(array_results_l1[2*i][12:13])+np.sum(array_results_l1[2*i +1][12:13])))<0 else 'magenta')

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-6],handles[-5],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-6],labels[-5],labels[-4],labels[-3],labels[-2],labels[-1]])

ax[0].set_title('RT terms abs l1')
for i in range(0,len(omegas_l1),1):
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][7:])+np.sum(array_results_l2[2*i +1][7:])))/m1_rescale[i,2], label = 'l=2 all RT', color='black',facecolors='none' if ((np.sum(array_results_l2[2*i][7:])+np.sum(array_results_l2[2*i +1][7:])))<0 else 'black')
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][7:8])+np.sum(array_results_l2[2*i +1][7:8])))/m1_rescale[i,2], label = 'term 8', color='r',facecolors='none' if  ((np.sum(array_results_l2[2*i][7:8])+np.sum(array_results_l2[2*i +1][7:8])))<0 else  'r')
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][8:9])+np.sum(array_results_l2[2*i +1][8:9])))/m1_rescale[i,2], label = 'term 9', color='g',facecolors='none' if ((np.sum(array_results_l2[2*i][8:9])+np.sum(array_results_l2[2*i +1][8:9])))<0 else 'g')
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][9:10])+np.sum(array_results_l2[2*i +1][9:10])))/m1_rescale[i,2], label = 'term 10', color='b',facecolors='none' if  ((np.sum(array_results_l2[2*i][9:10])+np.sum(array_results_l2[2*i +1][9:10])))<0 else 'b')
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][10:11])+np.sum(array_results_l2[2*i +1][10:11])))/m1_rescale[i,2], label = 'term 11', color='orange',facecolors='none' if ((np.sum(array_results_l2[2*i][10:11])+np.sum(array_results_l2[2*i +1][10:11])))<0 else 'orange')
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][11:12])+np.sum(array_results_l2[2*i +1][11:12])))/m1_rescale[i,2], label = 'term 12', color='cyan',facecolors='none' if ((np.sum(array_results_l2[2*i][11:12])+np.sum(array_results_l2[2*i +1][11:12])))<0 else 'cyan')
    ax[1].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l2[2*i][12:13])+np.sum(array_results_l2[2*i +1][12:13])))/m1_rescale[i,2], label = 'term 13', color='magenta',facecolors='none' if ((np.sum(array_results_l2[2*i][12:13])+np.sum(array_results_l2[2*i +1][12:13])))<0 else 'magenta')

ax[1].set_xscale('log')
ax[1].set_yscale('log')

handles, labels = ax[1].get_legend_handles_labels()
ax[1].legend([handles[0],handles[-6],handles[-5],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-6],labels[-5],labels[-4],labels[-3],labels[-2],labels[-1]])

ax[1].set_title('RT terms abs l2')

for i in range(0,len(omegas_l3),1):
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][7:])+np.sum(array_results_l3[2*i +1][7:])))/m1_rescale[i,3], label = 'l=3 all RT', color='black',facecolors='none' if ((np.sum(array_results_l3[2*i][7:])+np.sum(array_results_l3[2*i +1][7:])))<0 else 'black')
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][7:8])+np.sum(array_results_l3[2*i +1][7:8])))/m1_rescale[i,3], label = 'term 8', color='r',facecolors='none' if  ((np.sum(array_results_l3[2*i][7:8])+np.sum(array_results_l3[2*i +1][7:8])))<0 else  'r')
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][8:9])+np.sum(array_results_l3[2*i +1][8:9])))/m1_rescale[i,3], label = 'term 9', color='g',facecolors='none' if ((np.sum(array_results_l3[2*i][8:9])+np.sum(array_results_l3[2*i +1][8:9])))<0 else 'g')
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][9:10])+np.sum(array_results_l3[2*i +1][9:10])))/m1_rescale[i,3], label = 'term 10', color='b',facecolors='none' if  ((np.sum(array_results_l3[2*i][9:10])+np.sum(array_results_l3[2*i +1][9:10])))<0 else 'b')
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][10:11])+np.sum(array_results_l3[2*i +1][10:11])))/m1_rescale[i,3], label = 'term 11', color='orange',facecolors='none' if ((np.sum(array_results_l3[2*i][10:11])+np.sum(array_results_l3[2*i +1][10:11])))<0 else 'orange')
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][11:12])+np.sum(array_results_l3[2*i +1][11:12])))/m1_rescale[i,3], label = 'term 12', color='cyan',facecolors='none' if ((np.sum(array_results_l3[2*i][11:12])+np.sum(array_results_l3[2*i +1][11:12])))<0 else 'cyan')
    ax[2].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][12:13])+np.sum(array_results_l3[2*i +1][12:13])))/m1_rescale[i,3], label = 'term 13', color='magenta',facecolors='none' if ((np.sum(array_results_l3[2*i][12:13])+np.sum(array_results_l3[2*i +1][12:13])))<0 else 'magenta')

ax[2].set_yscale('log')

handles, labels = ax[2].get_legend_handles_labels()
ax[2].legend([handles[0],handles[-6],handles[-5],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-6],labels[-5],labels[-4],labels[-3],labels[-2],labels[-1]])

ax[2].set_title('RT terms abs l3')


for i in range(0,len(omegas_l3),1):
    ax[3].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][7:])+np.sum(array_results_l4[2*i +1][7:])))/m1_rescale[i,4], label = 'l=4 all RT', color='black',facecolors='none' if ((np.sum(array_results_l4[2*i][7:])+np.sum(array_results_l4[2*i +1][7:])))<0 else 'black')
    ax[3].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][7:8])+np.sum(array_results_l4[2*i +1][7:8])))/m1_rescale[i,4], label = 'term 8', color='r',facecolors='none' if  ((np.sum(array_results_l4[2*i][7:8])+np.sum(array_results_l4[2*i +1][7:8])))<0 else  'r')
    ax[3].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][8:9])+np.sum(array_results_l4[2*i +1][8:9])))/m1_rescale[i,4], label = 'term 9', color='g',facecolors='none' if ((np.sum(array_results_l4[2*i][8:9])+np.sum(array_results_l4[2*i +1][8:9])))<0 else 'g')
    ax[3].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][9:10])+np.sum(array_results_l4[2*i +1][9:10])))/m1_rescale[i,4], label = 'term 10', color='b',facecolors='none' if  ((np.sum(array_results_l4[2*i][9:10])+np.sum(array_results_l4[2*i +1][9:10])))<0 else 'b')
    ax[3].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][10:11])+np.sum(array_results_l4[2*i +1][10:11])))/m1_rescale[i,4], label = 'term 11', color='orange',facecolors='none' if ((np.sum(array_results_l4[2*i][10:11])+np.sum(array_results_l4[2*i +1][10:11])))<0 else 'orange')
    ax[3].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][11:12])+np.sum(array_results_l4[2*i +1][11:12])))/m1_rescale[i,4], label = 'term 12', color='cyan',facecolors='none' if ((np.sum(array_results_l4[2*i][11:12])+np.sum(array_results_l4[2*i +1][11:12])))<0 else 'cyan')
    ax[3].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l4[2*i][12:13])+np.sum(array_results_l4[2*i +1][12:13])))/m1_rescale[i,4], label = 'term 13', color='magenta',facecolors='none' if ((np.sum(array_results_l4[2*i][12:13])+np.sum(array_results_l4[2*i +1][12:13])))<0 else 'magenta')

ax[3].set_yscale('log')

handles, labels = ax[3].get_legend_handles_labels()
ax[3].legend([handles[0],handles[-6],handles[-5],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-6],labels[-5],labels[-4],labels[-3],labels[-2],labels[-1]])

ax[3].set_title('RT terms abs l4')


for i in range(0,len(omegas_l3),1):
    ax[4].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][7:])+np.sum(array_results_l5[2*i +1][7:])))/m1_rescale[i,5], label = 'l=5 all RT', color='black',facecolors='none' if ((np.sum(array_results_l5[2*i][7:])+np.sum(array_results_l5[2*i +1][7:])))<0 else 'black')
    ax[4].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][7:8])+np.sum(array_results_l5[2*i +1][7:8])))/m1_rescale[i,5], label = 'term 8', color='r',facecolors='none' if  ((np.sum(array_results_l5[2*i][7:8])+np.sum(array_results_l5[2*i +1][7:8])))<0 else  'r')
    ax[4].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][8:9])+np.sum(array_results_l5[2*i +1][8:9])))/m1_rescale[i,5], label = 'term 9', color='g',facecolors='none' if ((np.sum(array_results_l5[2*i][8:9])+np.sum(array_results_l5[2*i +1][8:9])))<0 else 'g')
    ax[4].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][9:10])+np.sum(array_results_l5[2*i +1][9:10])))/m1_rescale[i,5], label = 'term 10', color='b',facecolors='none' if  ((np.sum(array_results_l5[2*i][9:10])+np.sum(array_results_l5[2*i +1][9:10])))<0 else 'b')
    ax[4].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][10:11])+np.sum(array_results_l5[2*i +1][10:11])))/m1_rescale[i,5]/m1_rescale[i,5], label = 'term 11', color='orange',facecolors='none' if ((np.sum(array_results_l5[2*i][10:11])+np.sum(array_results_l5[2*i +1][10:11])))<0 else 'orange')
    ax[4].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][11:12])+np.sum(array_results_l5[2*i +1][11:12])))/m1_rescale[i,5], label = 'term 12', color='cyan',facecolors='none' if ((np.sum(array_results_l5[2*i][11:12])+np.sum(array_results_l5[2*i +1][11:12])))<0 else 'cyan')
    ax[4].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l5[2*i][12:13])+np.sum(array_results_l5[2*i +1][12:13])))/m1_rescale[i,5], label = 'term 13', color='magenta',facecolors='none' if ((np.sum(array_results_l5[2*i][12:13])+np.sum(array_results_l5[2*i +1][12:13])))<0 else 'magenta')

ax[4].set_yscale('log')

handles, labels = ax[4].get_legend_handles_labels()
ax[4].legend([handles[0],handles[-6],handles[-5],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-6],labels[-5],labels[-4],labels[-3],labels[-2],labels[-1]])

ax[4].set_title('RT terms abs l5')


plt.savefig('PBH/RT12345.pdf',bbox_inches='tight')

plt.show()

# %%
"""fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True,figsize=(8, 10))
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:]))), label = 'l=1 all RT', color='black',facecolors='none' if ((np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:])))<0 else 'black')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8]))), label = 'term 8', color='r',facecolors='none' if  ((np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8])))<0 else  'r')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9]))), label = 'term 9', color='g',facecolors='none' if ((np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9])))<0 else 'g')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10]))), label = 'term 10', color='b',facecolors='none' if  ((np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10])))<0 else 'b')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][10:11])+np.sum(array_results_l1[2*i +1][10:11]))), label = 'term 11', color='orange',facecolors='none' if ((np.sum(array_results_l1[2*i][10:11])+np.sum(array_results_l1[2*i +1][10:11])))<0 else 'orange')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][11:12])+np.sum(array_results_l1[2*i +1][11:12]))), label = 'term 12', color='cyan',facecolors='none' if ((np.sum(array_results_l1[2*i][11:12])+np.sum(array_results_l1[2*i +1][11:12])))<0 else 'cyan')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][12:13])+np.sum(array_results_l1[2*i +1][12:13]))), label = 'term 13', color='magenta',facecolors='none' if ((np.sum(array_results_l1[2*i][12:13])+np.sum(array_results_l1[2*i +1][12:13])))<0 else 'magenta')

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-6],handles[-5],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-6],labels[-5],labels[-4],labels[-3],labels[-2],labels[-1]])

ax[0].set_title('RT terms abs l1')
for i in range(0,len(omegas_l3),1):
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][7:])+np.sum(array_results_l3[2*i +1][7:]))), label = 'l=3 all RT', color='black',facecolors='none' if ((np.sum(array_results_l3[2*i][7:])+np.sum(array_results_l3[2*i +1][7:])))<0 else 'black')
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][7:8])+np.sum(array_results_l3[2*i +1][7:8]))), label = 'term 8', color='r',facecolors='none' if  ((np.sum(array_results_l3[2*i][7:8])+np.sum(array_results_l3[2*i +1][7:8])))<0 else  'r')
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][8:9])+np.sum(array_results_l3[2*i +1][8:9]))), label = 'term 9', color='g',facecolors='none' if ((np.sum(array_results_l3[2*i][8:9])+np.sum(array_results_l3[2*i +1][8:9])))<0 else 'g')
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][9:10])+np.sum(array_results_l3[2*i +1][9:10]))), label = 'term 10', color='b',facecolors='none' if  ((np.sum(array_results_l3[2*i][9:10])+np.sum(array_results_l3[2*i +1][9:10])))<0 else 'b')
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][10:11])+np.sum(array_results_l3[2*i +1][10:11]))), label = 'term 11', color='orange',facecolors='none' if ((np.sum(array_results_l3[2*i][10:11])+np.sum(array_results_l3[2*i +1][10:11])))<0 else 'orange')
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][11:12])+np.sum(array_results_l3[2*i +1][11:12]))), label = 'term 12', color='cyan',facecolors='none' if ((np.sum(array_results_l3[2*i][11:12])+np.sum(array_results_l3[2*i +1][11:12])))<0 else 'cyan')
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][12:13])+np.sum(array_results_l3[2*i +1][12:13]))), label = 'term 13', color='magenta',facecolors='none' if ((np.sum(array_results_l3[2*i][12:13])+np.sum(array_results_l3[2*i +1][12:13])))<0 else 'magenta')

ax[1].set_yscale('log')

handles, labels = ax[1].get_legend_handles_labels()
ax[1].legend([handles[0],handles[-6],handles[-5],handles[-4],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-6],labels[-5],labels[-4],labels[-3],labels[-2],labels[-1]])
ax[1].set_ylim((1e-15,1e-9))
ax[0].set_xlim(1,16)
ax[1].set_title('RT terms abs l3')
plt.savefig('Plots010824/RT1and3Zoomed.pdf',bbox_inches='tight')

plt.show()           """
# Out:
# "fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True,figsize=(8, 10))\nfor i in range(0,len(omegas_l1),1):\n    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:]))), label = 'l=1 all RT', color='black',facecolors='none' if ((np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:])))<0 else 'black')\n    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8]))), label = 'term 8', color='r',facecolors='none' if  ((np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8])))<0 else  'r')\n    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9]))), label = 'term 9', color='g',facecolors='none' if ((np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9])))<0 else 'g')\n    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10]))), 
# ...

# %%
"""fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True,figsize=(8, 10))
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:]))), label = 'l=1 all RT', color='black',facecolors='none' if ((np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:])))<0 else 'black')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8]))), label = 'term 8', color='r',facecolors='none' if  ((np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8])))<0 else  'r')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9]))), label = 'term 9', color='g',facecolors='none' if ((np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9])))<0 else 'g')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10]))), label = 'term 10', color='b',facecolors='none' if  ((np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10])))<0 else 'b')
    #ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][10:11])+np.sum(array_results_l1[2*i +1][10:11]))), label = 'term 11', color='orange',facecolors='none' if ((np.sum(array_results_l1[2*i][10:11])+np.sum(array_results_l1[2*i +1][10:11])))<0 else 'orange')
    #ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][11:12])+np.sum(array_results_l1[2*i +1][11:12]))), label = 'term 12', color='cyan',facecolors='none' if ((np.sum(array_results_l1[2*i][11:12])+np.sum(array_results_l1[2*i +1][11:12])))<0 else 'cyan')
    #ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][12:13])+np.sum(array_results_l1[2*i +1][12:13]))), label = 'term 13', color='magenta',facecolors='none' if ((np.sum(array_results_l1[2*i][12:13])+np.sum(array_results_l1[2*i +1][12:13])))<0 else 'magenta')

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])

ax[0].set_title('RT terms abs l1')
for i in range(0,len(omegas_l3),1):
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][7:])+np.sum(array_results_l3[2*i +1][7:]))), label = 'l=3 all RT', color='black',facecolors='none' if ((np.sum(array_results_l3[2*i][7:])+np.sum(array_results_l3[2*i +1][7:])))<0 else 'black')
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][7:8])+np.sum(array_results_l3[2*i +1][7:8]))), label = 'term 8', color='r',facecolors='none' if  ((np.sum(array_results_l3[2*i][7:8])+np.sum(array_results_l3[2*i +1][7:8])))<0 else  'r')
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][8:9])+np.sum(array_results_l3[2*i +1][8:9]))), label = 'term 9', color='g',facecolors='none' if ((np.sum(array_results_l3[2*i][8:9])+np.sum(array_results_l3[2*i +1][8:9])))<0 else 'g')
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][9:10])+np.sum(array_results_l3[2*i +1][9:10]))), label = 'term 10', color='b',facecolors='none' if  ((np.sum(array_results_l3[2*i][9:10])+np.sum(array_results_l3[2*i +1][9:10])))<0 else 'b')
    #ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][10:11])+np.sum(array_results_l3[2*i +1][10:11]))), label = 'term 11', color='orange',facecolors='none' if ((np.sum(array_results_l3[2*i][10:11])+np.sum(array_results_l3[2*i +1][10:11])))<0 else 'orange')
    #ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][11:12])+np.sum(array_results_l3[2*i +1][11:12]))), label = 'term 12', color='cyan',facecolors='none' if ((np.sum(array_results_l3[2*i][11:12])+np.sum(array_results_l3[2*i +1][11:12])))<0 else 'cyan')
    #ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][12:13])+np.sum(array_results_l3[2*i +1][12:13]))), label = 'term 13', color='magenta',facecolors='none' if ((np.sum(array_results_l3[2*i][12:13])+np.sum(array_results_l3[2*i +1][12:13])))<0 else 'magenta')

ax[1].set_yscale('log')

handles, labels = ax[1].get_legend_handles_labels()
ax[1].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])

ax[1].set_title('RT terms abs l3')
plt.savefig('Plots010824/RT1and3Terms8-10.pdf',bbox_inches='tight')
ax[1].set_ylim((1e-19,1e-9))
plt.show()           """
# Out:
# "fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True,figsize=(8, 10))\nfor i in range(0,len(omegas_l1),1):\n    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:]))), label = 'l=1 all RT', color='black',facecolors='none' if ((np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:])))<0 else 'black')\n    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8]))), label = 'term 8', color='r',facecolors='none' if  ((np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8])))<0 else  'r')\n    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9]))), label = 'term 9', color='g',facecolors='none' if ((np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9])))<0 else 'g')\n    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10]))), 
# ...

# %%
"""fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True,figsize=(8, 10))
for i in range(0,len(omegas_l1),1):
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:]))), label = 'l=1 all RT', color='black',facecolors='none' if ((np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:])))<0 else 'black')
    #ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8]))), label = 'term 8', color='r',facecolors='none' if  ((np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8])))<0 else  'r')
    #ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9]))), label = 'term 9', color='g',facecolors='none' if ((np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9])))<0 else 'g')
    #ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10]))), label = 'term 10', color='b',facecolors='none' if  ((np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10])))<0 else 'b')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][10:11])+np.sum(array_results_l1[2*i +1][10:11]))), label = 'term 11', color='orange',facecolors='none' if ((np.sum(array_results_l1[2*i][10:11])+np.sum(array_results_l1[2*i +1][10:11])))<0 else 'orange')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][11:12])+np.sum(array_results_l1[2*i +1][11:12]))), label = 'term 12', color='cyan',facecolors='none' if ((np.sum(array_results_l1[2*i][11:12])+np.sum(array_results_l1[2*i +1][11:12])))<0 else 'cyan')
    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][12:13])+np.sum(array_results_l1[2*i +1][12:13]))), label = 'term 13', color='magenta',facecolors='none' if ((np.sum(array_results_l1[2*i][12:13])+np.sum(array_results_l1[2*i +1][12:13])))<0 else 'magenta')

ax[0].set_xscale('log')
ax[0].set_yscale('log')

handles, labels = ax[0].get_legend_handles_labels()
ax[0].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])

ax[0].set_title('RT terms abs l1')
for i in range(0,len(omegas_l3),1):
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][7:])+np.sum(array_results_l3[2*i +1][7:]))), label = 'l=3 all RT', color='black',facecolors='none' if ((np.sum(array_results_l3[2*i][7:])+np.sum(array_results_l3[2*i +1][7:])))<0 else 'black')
    #ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][7:8])+np.sum(array_results_l3[2*i +1][7:8]))), label = 'term 8', color='r',facecolors='none' if  ((np.sum(array_results_l3[2*i][7:8])+np.sum(array_results_l3[2*i +1][7:8])))<0 else  'r')
    #ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][8:9])+np.sum(array_results_l3[2*i +1][8:9]))), label = 'term 9', color='g',facecolors='none' if ((np.sum(array_results_l3[2*i][8:9])+np.sum(array_results_l3[2*i +1][8:9])))<0 else 'g')
    #ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][9:10])+np.sum(array_results_l3[2*i +1][9:10]))), label = 'term 10', color='b',facecolors='none' if  ((np.sum(array_results_l3[2*i][9:10])+np.sum(array_results_l3[2*i +1][9:10])))<0 else 'b')
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][10:11])+np.sum(array_results_l3[2*i +1][10:11]))), label = 'term 11', color='orange',facecolors='none' if ((np.sum(array_results_l3[2*i][10:11])+np.sum(array_results_l3[2*i +1][10:11])))<0 else 'orange')
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][11:12])+np.sum(array_results_l3[2*i +1][11:12]))), label = 'term 12', color='cyan',facecolors='none' if ((np.sum(array_results_l3[2*i][11:12])+np.sum(array_results_l3[2*i +1][11:12])))<0 else 'cyan')
    ax[1].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][12:13])+np.sum(array_results_l3[2*i +1][12:13]))), label = 'term 13', color='magenta',facecolors='none' if ((np.sum(array_results_l3[2*i][12:13])+np.sum(array_results_l3[2*i +1][12:13])))<0 else 'magenta')

ax[1].set_yscale('log')

handles, labels = ax[1].get_legend_handles_labels()
ax[1].legend([handles[0],handles[-3],handles[-2],handles[-1]],[labels[0],labels[-3],labels[-2],labels[-1]])

ax[1].set_title('RT terms abs l3')
plt.savefig('Plots010824/RT1and3Terms11-13.pdf',bbox_inches='tight')
ax[1].set_ylim((1e-19,1e-9))
plt.show()           """
# Out:
# "fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True,figsize=(8, 10))\nfor i in range(0,len(omegas_l1),1):\n    ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:]))), label = 'l=1 all RT', color='black',facecolors='none' if ((np.sum(array_results_l1[2*i][7:])+np.sum(array_results_l1[2*i +1][7:])))<0 else 'black')\n    #ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8]))), label = 'term 8', color='r',facecolors='none' if  ((np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8])))<0 else  'r')\n    #ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9]))), label = 'term 9', color='g',facecolors='none' if ((np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9])))<0 else 'g')\n    #ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10]))
# ...

# %%
def gettermpercentcontributionsl1_other(i):
    #i indicates omega
    term1 = (np.abs(np.sum(array_results_l1[2*i][:1])+np.sum(array_results_l1[2*i +1][:1])))/m1_rescale[i,1]
    term2 = (np.abs(np.sum(array_results_l1[2*i][1:2])+np.sum(array_results_l1[2*i +1][1:2])))/m1_rescale[i,1]
    term3 = (np.abs(np.sum(array_results_l1[2*i][2:3])+np.sum(array_results_l1[2*i +1][2:3])))/m1_rescale[i,1]
    term4 = (np.abs(np.sum(array_results_l1[2*i][3:4])+np.sum(array_results_l1[2*i +1][3:4])))/m1_rescale[i,1]
    term5 = (np.abs(np.sum(array_results_l1[2*i][4:5])+np.sum(array_results_l1[2*i +1][4:5])))/m1_rescale[i,1]
    term6 = (np.abs(np.sum(array_results_l1[2*i][5:6])+np.sum(array_results_l1[2*i +1][5:6])))/m1_rescale[i,1]
    term7 = (np.abs(np.sum(array_results_l1[2*i][6:7])+np.sum(array_results_l1[2*i +1][6:7])))/m1_rescale[i,1]
    term8 = (np.abs(np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8])))/m1_rescale[i,1]
    term9 = (np.abs(np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9])))/m1_rescale[i,1]
    term10 = (np.abs(np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10])))/m1_rescale[i,1]
    term11 = (np.abs(np.sum(array_results_l1[2*i][10:11])+np.sum(array_results_l1[2*i +1][10:11])))/m1_rescale[i,1]
    term12 = (np.abs(np.sum(array_results_l1[2*i][11:12])+np.sum(array_results_l1[2*i +1][11:12])))/m1_rescale[i,1]
    term13 = (np.abs(np.sum(array_results_l1[2*i][12:13])+np.sum(array_results_l1[2*i +1][12:13])))/m1_rescale[i,1]
    
    
    total = term1+term2+term3+term4+term5+term6+term7+term8+term9+term10+term11+term12+term13
    
    percent_term1 = term1/total
    if (np.sum(array_results_l1[2*i][:1])+np.sum(array_results_l1[2*i +1][:1]))<0:
        percent_term1=-1*percent_term1
    percent_term2 = term2/total
    if (np.sum(array_results_l1[2*i][1:2])+np.sum(array_results_l1[2*i +1][1:2]))<0:
        percent_term2=-1*percent_term2
    percent_term3 = term3/total
    if (np.sum(array_results_l1[2*i][2:3])+np.sum(array_results_l1[2*i +1][2:3]))<0:
        percent_term3=-1*percent_term3
    percent_term4 = term4/total
    if (np.sum(array_results_l1[2*i][3:4])+np.sum(array_results_l1[2*i +1][3:4]))<0:
        percent_term4=-1*percent_term4
    percent_term5 = term5/total
    if (np.sum(array_results_l1[2*i][4:5])+np.sum(array_results_l1[2*i +1][4:5]))<0:
        percent_term5=-1*percent_term5
    percent_term6 = term6/total
    if (np.sum(array_results_l1[2*i][5:6])+np.sum(array_results_l1[2*i +1][5:6]))<0:
        percent_term6=-1*percent_term6
    percent_term7 = term7/total
    if (np.sum(array_results_l1[2*i][6:7])+np.sum(array_results_l1[2*i +1][6:7]))<0:
        percent_term7=-1*percent_term7
    percent_term8 = term8/total
    if (np.sum(array_results_l1[2*i][7:8])+np.sum(array_results_l1[2*i +1][7:8]))<0:
        percent_term8=-1*percent_term8
    percent_term9 = term9/total
    if (np.sum(array_results_l1[2*i][8:9])+np.sum(array_results_l1[2*i +1][8:9]))<0:
        percent_term9=-1*percent_term9
    percent_term10 = term10/total
    if (np.sum(array_results_l1[2*i][9:10])+np.sum(array_results_l1[2*i +1][9:10]))<0:
        percent_term10=-1*percent_term10
    percent_term11 = term11/total
    if (np.sum(array_results_l1[2*i][10:11])+np.sum(array_results_l1[2*i +1][10:11]))<0:
        percent_term11=-1*percent_term11
    percent_term12 = term12/total
    if (np.sum(array_results_l1[2*i][11:12])+np.sum(array_results_l1[2*i +1][11:12]))<0:
        percent_term12=-1*percent_term12
    percent_term13 = term13/total
    if (np.sum(array_results_l1[2*i][12:13])+np.sum(array_results_l1[2*i +1][12:13]))<0:
        percent_term13=-1*percent_term13

    return(percent_term1,percent_term2,percent_term3,percent_term4,percent_term5,percent_term6,percent_term7,percent_term8,percent_term9,percent_term10,percent_term11,percent_term12,percent_term13)

def gettermpercentcontributionsl2_other(i):
    #i indicates omega
    term1 = (np.abs(np.sum(array_results_l2[2*i][:1])+np.sum(array_results_l2[2*i +1][:1])))/m1_rescale[i,2]
    term2 = (np.abs(np.sum(array_results_l2[2*i][1:2])+np.sum(array_results_l2[2*i +1][1:2])))/m1_rescale[i,2]
    term3 = (np.abs(np.sum(array_results_l2[2*i][2:3])+np.sum(array_results_l2[2*i +1][2:3])))/m1_rescale[i,2]
    term4 = (np.abs(np.sum(array_results_l2[2*i][3:4])+np.sum(array_results_l2[2*i +1][3:4])))/m1_rescale[i,2]
    term5 = (np.abs(np.sum(array_results_l2[2*i][4:5])+np.sum(array_results_l2[2*i +1][4:5])))/m1_rescale[i,2]
    term6 = (np.abs(np.sum(array_results_l2[2*i][5:6])+np.sum(array_results_l2[2*i +1][5:6])))/m1_rescale[i,2]
    term7 = (np.abs(np.sum(array_results_l2[2*i][6:7])+np.sum(array_results_l2[2*i +1][6:7])))/m1_rescale[i,2]
    term8 = (np.abs(np.sum(array_results_l2[2*i][7:8])+np.sum(array_results_l2[2*i +1][7:8])))/m1_rescale[i,2]
    term9 = (np.abs(np.sum(array_results_l2[2*i][8:9])+np.sum(array_results_l2[2*i +1][8:9])))/m1_rescale[i,2]
    term10 = (np.abs(np.sum(array_results_l2[2*i][9:10])+np.sum(array_results_l2[2*i +1][9:10])))/m1_rescale[i,2]
    term11 = (np.abs(np.sum(array_results_l2[2*i][10:11])+np.sum(array_results_l2[2*i +1][10:11])))/m1_rescale[i,2]
    term12 = (np.abs(np.sum(array_results_l2[2*i][11:12])+np.sum(array_results_l2[2*i +1][11:12])))/m1_rescale[i,2]
    term13 = (np.abs(np.sum(array_results_l2[2*i][12:13])+np.sum(array_results_l2[2*i +1][12:13])))/m1_rescale[i,2]
    
    
    total = term1+term2+term3+term4+term5+term6+term7+term8+term9+term10+term11+term12+term13
    
    percent_term1 = term1/total
    if (np.sum(array_results_l2[2*i][:1])+np.sum(array_results_l2[2*i +1][:1]))<0:
        percent_term1=-1*percent_term1
    percent_term2 = term2/total
    if (np.sum(array_results_l2[2*i][1:2])+np.sum(array_results_l2[2*i +1][1:2]))<0:
        percent_term2=-1*percent_term2
    percent_term3 = term3/total
    if (np.sum(array_results_l2[2*i][2:3])+np.sum(array_results_l2[2*i +1][2:3]))<0:
        percent_term3=-1*percent_term3
    percent_term4 = term4/total
    if (np.sum(array_results_l2[2*i][3:4])+np.sum(array_results_l2[2*i +1][3:4]))<0:
        percent_term4=-1*percent_term4
    percent_term5 = term5/total
    if (np.sum(array_results_l2[2*i][4:5])+np.sum(array_results_l2[2*i +1][4:5]))<0:
        percent_term5=-1*percent_term5
    percent_term6 = term6/total
    if (np.sum(array_results_l2[2*i][5:6])+np.sum(array_results_l2[2*i +1][5:6]))<0:
        percent_term6=-1*percent_term6
    percent_term7 = term7/total
    if (np.sum(array_results_l2[2*i][6:7])+np.sum(array_results_l2[2*i +1][6:7]))<0:
        percent_term7=-1*percent_term7
    percent_term8 = term8/total
    if (np.sum(array_results_l2[2*i][7:8])+np.sum(array_results_l2[2*i +1][7:8]))<0:
        percent_term8=-1*percent_term8
    percent_term9 = term9/total
    if (np.sum(array_results_l2[2*i][8:9])+np.sum(array_results_l2[2*i +1][8:9]))<0:
        percent_term9=-1*percent_term9
    percent_term10 = term10/total
    if (np.sum(array_results_l2[2*i][9:10])+np.sum(array_results_l2[2*i +1][9:10]))<0:
        percent_term10=-1*percent_term10
    percent_term11 = term11/total
    if (np.sum(array_results_l2[2*i][10:11])+np.sum(array_results_l2[2*i +1][10:11]))<0:
        percent_term11=-1*percent_term11
    percent_term12 = term12/total
    if (np.sum(array_results_l2[2*i][11:12])+np.sum(array_results_l2[2*i +1][11:12]))<0:
        percent_term12=-1*percent_term12
    percent_term13 = term13/total
    if (np.sum(array_results_l2[2*i][12:13])+np.sum(array_results_l2[2*i +1][12:13]))<0:
        percent_term13=-1*percent_term13

    return(percent_term1,percent_term2,percent_term3,percent_term4,percent_term5,percent_term6,percent_term7,percent_term8,percent_term9,percent_term10,percent_term11,percent_term12,percent_term13)


def gettermpercentcontributionsl3_other(i):
    #i indicates omega
    term1 = (np.abs(np.sum(array_results_l3[2*i][:1])+np.sum(array_results_l3[2*i +1][:1])))/m1_rescale[i,3]
    term2 = (np.abs(np.sum(array_results_l3[2*i][1:2])+np.sum(array_results_l3[2*i +1][1:2])))/m1_rescale[i,3]
    term3 = (np.abs(np.sum(array_results_l3[2*i][2:3])+np.sum(array_results_l3[2*i +1][2:3])))/m1_rescale[i,3]
    term4 = (np.abs(np.sum(array_results_l3[2*i][3:4])+np.sum(array_results_l3[2*i +1][3:4])))/m1_rescale[i,3]
    term5 = (np.abs(np.sum(array_results_l3[2*i][4:5])+np.sum(array_results_l3[2*i +1][4:5])))/m1_rescale[i,3]
    term6 = (np.abs(np.sum(array_results_l3[2*i][5:6])+np.sum(array_results_l3[2*i +1][5:6])))/m1_rescale[i,3]
    term7 = (np.abs(np.sum(array_results_l3[2*i][6:7])+np.sum(array_results_l3[2*i +1][6:7])))/m1_rescale[i,3]
    term8 = (np.abs(np.sum(array_results_l3[2*i][7:8])+np.sum(array_results_l3[2*i +1][7:8])))/m1_rescale[i,3]
    term9 = (np.abs(np.sum(array_results_l3[2*i][8:9])+np.sum(array_results_l3[2*i +1][8:9])))/m1_rescale[i,3]
    term10 = (np.abs(np.sum(array_results_l3[2*i][9:10])+np.sum(array_results_l3[2*i +1][9:10])))/m1_rescale[i,3]
    term11 = (np.abs(np.sum(array_results_l3[2*i][10:11])+np.sum(array_results_l3[2*i +1][10:11])))/m1_rescale[i,3]
    term12 = (np.abs(np.sum(array_results_l3[2*i][11:12])+np.sum(array_results_l3[2*i +1][11:12])))/m1_rescale[i,3]
    term13 = (np.abs(np.sum(array_results_l3[2*i][12:13])+np.sum(array_results_l3[2*i +1][12:13])))/m1_rescale[i,3]
    
    
    total = term1+term2+term3+term4+term5+term6+term7+term8+term9+term10+term11+term12+term13
    
    percent_term1 = term1/total
    if (np.sum(array_results_l3[2*i][:1])+np.sum(array_results_l3[2*i +1][:1]))<0:
        percent_term1=-1*percent_term1
    percent_term2 = term2/total
    if (np.sum(array_results_l3[2*i][1:2])+np.sum(array_results_l3[2*i +1][1:2]))<0:
        percent_term2=-1*percent_term2
    percent_term3 = term3/total
    if (np.sum(array_results_l3[2*i][2:3])+np.sum(array_results_l3[2*i +1][2:3]))<0:
        percent_term3=-1*percent_term3
    percent_term4 = term4/total
    if (np.sum(array_results_l3[2*i][3:4])+np.sum(array_results_l3[2*i +1][3:4]))<0:
        percent_term4=-1*percent_term4
    percent_term5 = term5/total
    if (np.sum(array_results_l3[2*i][4:5])+np.sum(array_results_l3[2*i +1][4:5]))<0:
        percent_term5=-1*percent_term5
    percent_term6 = term6/total
    if (np.sum(array_results_l3[2*i][5:6])+np.sum(array_results_l3[2*i +1][5:6]))<0:
        percent_term6=-1*percent_term6
    percent_term7 = term7/total
    if (np.sum(array_results_l3[2*i][6:7])+np.sum(array_results_l3[2*i +1][6:7]))<0:
        percent_term7=-1*percent_term7
    percent_term8 = term8/total
    if (np.sum(array_results_l3[2*i][7:8])+np.sum(array_results_l3[2*i +1][7:8]))<0:
        percent_term8=-1*percent_term8
    percent_term9 = term9/total
    if (np.sum(array_results_l3[2*i][8:9])+np.sum(array_results_l3[2*i +1][8:9]))<0:
        percent_term9=-1*percent_term9
    percent_term10 = term10/total
    if (np.sum(array_results_l3[2*i][9:10])+np.sum(array_results_l3[2*i +1][9:10]))<0:
        percent_term10=-1*percent_term10
    percent_term11 = term11/total
    if (np.sum(array_results_l3[2*i][10:11])+np.sum(array_results_l3[2*i +1][10:11]))<0:
        percent_term11=-1*percent_term11
    percent_term12 = term12/total
    if (np.sum(array_results_l3[2*i][11:12])+np.sum(array_results_l3[2*i +1][11:12]))<0:
        percent_term12=-1*percent_term12
    percent_term13 = term13/total
    if (np.sum(array_results_l3[2*i][12:13])+np.sum(array_results_l3[2*i +1][12:13]))<0:
        percent_term13=-1*percent_term13

    return(percent_term1,percent_term2,percent_term3,percent_term4,percent_term5,percent_term6,percent_term7,percent_term8,percent_term9,percent_term10,percent_term11,percent_term12,percent_term13)

def gettermpercentcontributionsl4_other(i):
    #i indicates omega
    term1 = (np.abs(np.sum(array_results_l4[2*i][:1])+np.sum(array_results_l4[2*i +1][:1])))/m1_rescale[i,4]
    term2 = (np.abs(np.sum(array_results_l4[2*i][1:2])+np.sum(array_results_l4[2*i +1][1:2])))/m1_rescale[i,4]
    term3 = (np.abs(np.sum(array_results_l4[2*i][2:3])+np.sum(array_results_l4[2*i +1][2:3])))/m1_rescale[i,4]
    term4 = (np.abs(np.sum(array_results_l4[2*i][3:4])+np.sum(array_results_l4[2*i +1][3:4])))/m1_rescale[i,4]
    term5 = (np.abs(np.sum(array_results_l4[2*i][4:5])+np.sum(array_results_l4[2*i +1][4:5])))/m1_rescale[i,4]
    term6 = (np.abs(np.sum(array_results_l4[2*i][5:6])+np.sum(array_results_l4[2*i +1][5:6])))/m1_rescale[i,4]
    term7 = (np.abs(np.sum(array_results_l4[2*i][6:7])+np.sum(array_results_l4[2*i +1][6:7])))/m1_rescale[i,4]
    term8 = (np.abs(np.sum(array_results_l4[2*i][7:8])+np.sum(array_results_l4[2*i +1][7:8])))/m1_rescale[i,4]
    term9 = (np.abs(np.sum(array_results_l4[2*i][8:9])+np.sum(array_results_l4[2*i +1][8:9])))/m1_rescale[i,4]
    term10 = (np.abs(np.sum(array_results_l4[2*i][9:10])+np.sum(array_results_l4[2*i +1][9:10])))/m1_rescale[i,4]
    term11 = (np.abs(np.sum(array_results_l4[2*i][10:11])+np.sum(array_results_l4[2*i +1][10:11])))/m1_rescale[i,4]
    term12 = (np.abs(np.sum(array_results_l4[2*i][11:12])+np.sum(array_results_l4[2*i +1][11:12])))/m1_rescale[i,4]
    term13 = (np.abs(np.sum(array_results_l4[2*i][12:13])+np.sum(array_results_l4[2*i +1][12:13])))/m1_rescale[i,4]
    
    
    total = term1+term2+term3+term4+term5+term6+term7+term8+term9+term10+term11+term12+term13
    
    percent_term1 = term1/total
    if (np.sum(array_results_l4[2*i][:1])+np.sum(array_results_l4[2*i +1][:1]))<0:
        percent_term1=-1*percent_term1
    percent_term2 = term2/total
    if (np.sum(array_results_l4[2*i][1:2])+np.sum(array_results_l4[2*i +1][1:2]))<0:
        percent_term2=-1*percent_term2
    percent_term3 = term3/total
    if (np.sum(array_results_l4[2*i][2:3])+np.sum(array_results_l4[2*i +1][2:3]))<0:
        percent_term3=-1*percent_term3
    percent_term4 = term4/total
    if (np.sum(array_results_l4[2*i][3:4])+np.sum(array_results_l4[2*i +1][3:4]))<0:
        percent_term4=-1*percent_term4
    percent_term5 = term5/total
    if (np.sum(array_results_l4[2*i][4:5])+np.sum(array_results_l4[2*i +1][4:5]))<0:
        percent_term5=-1*percent_term5
    percent_term6 = term6/total
    if (np.sum(array_results_l4[2*i][5:6])+np.sum(array_results_l4[2*i +1][5:6]))<0:
        percent_term6=-1*percent_term6
    percent_term7 = term7/total
    if (np.sum(array_results_l4[2*i][6:7])+np.sum(array_results_l4[2*i +1][6:7]))<0:
        percent_term7=-1*percent_term7
    percent_term8 = term8/total
    if (np.sum(array_results_l4[2*i][7:8])+np.sum(array_results_l4[2*i +1][7:8]))<0:
        percent_term8=-1*percent_term8
    percent_term9 = term9/total
    if (np.sum(array_results_l4[2*i][8:9])+np.sum(array_results_l4[2*i +1][8:9]))<0:
        percent_term9=-1*percent_term9
    percent_term10 = term10/total
    if (np.sum(array_results_l4[2*i][9:10])+np.sum(array_results_l4[2*i +1][9:10]))<0:
        percent_term10=-1*percent_term10
    percent_term11 = term11/total
    if (np.sum(array_results_l4[2*i][10:11])+np.sum(array_results_l4[2*i +1][10:11]))<0:
        percent_term11=-1*percent_term11
    percent_term12 = term12/total
    if (np.sum(array_results_l4[2*i][11:12])+np.sum(array_results_l4[2*i +1][11:12]))<0:
        percent_term12=-1*percent_term12
    percent_term13 = term13/total
    if (np.sum(array_results_l4[2*i][12:13])+np.sum(array_results_l4[2*i +1][12:13]))<0:
        percent_term13=-1*percent_term13

    return(percent_term1,percent_term2,percent_term3,percent_term4,percent_term5,percent_term6,percent_term7,percent_term8,percent_term9,percent_term10,percent_term11,percent_term12,percent_term13)

def gettermpercentcontributionsl5_other(i):
    #i indicates omega
    term1 = (np.abs(np.sum(array_results_l5[2*i][:1])+np.sum(array_results_l5[2*i +1][:1])))/m1_rescale[i,5]
    term2 = (np.abs(np.sum(array_results_l5[2*i][1:2])+np.sum(array_results_l5[2*i +1][1:2])))/m1_rescale[i,5]
    term3 = (np.abs(np.sum(array_results_l5[2*i][2:3])+np.sum(array_results_l5[2*i +1][2:3])))/m1_rescale[i,5]
    term4 = (np.abs(np.sum(array_results_l5[2*i][3:4])+np.sum(array_results_l5[2*i +1][3:4])))/m1_rescale[i,5]
    term5 = (np.abs(np.sum(array_results_l5[2*i][4:5])+np.sum(array_results_l5[2*i +1][4:5])))/m1_rescale[i,5]
    term6 = (np.abs(np.sum(array_results_l5[2*i][5:6])+np.sum(array_results_l5[2*i +1][5:6])))/m1_rescale[i,5]
    term7 = (np.abs(np.sum(array_results_l5[2*i][6:7])+np.sum(array_results_l5[2*i +1][6:7])))/m1_rescale[i,5]
    term8 = (np.abs(np.sum(array_results_l5[2*i][7:8])+np.sum(array_results_l5[2*i +1][7:8])))/m1_rescale[i,5]
    term9 = (np.abs(np.sum(array_results_l5[2*i][8:9])+np.sum(array_results_l5[2*i +1][8:9])))/m1_rescale[i,5]
    term10 = (np.abs(np.sum(array_results_l5[2*i][9:10])+np.sum(array_results_l5[2*i +1][9:10])))/m1_rescale[i,5]
    term11 = (np.abs(np.sum(array_results_l5[2*i][10:11])+np.sum(array_results_l5[2*i +1][10:11])))/m1_rescale[i,5]
    term12 = (np.abs(np.sum(array_results_l5[2*i][11:12])+np.sum(array_results_l5[2*i +1][11:12])))/m1_rescale[i,5]
    term13 = (np.abs(np.sum(array_results_l5[2*i][12:13])+np.sum(array_results_l5[2*i +1][12:13])))/m1_rescale[i,5]
    
    
    total = term1+term2+term3+term4+term5+term6+term7+term8+term9+term10+term11+term12+term13
    
    percent_term1 = term1/total
    if (np.sum(array_results_l5[2*i][:1])+np.sum(array_results_l5[2*i +1][:1]))<0:
        percent_term1=-1*percent_term1
    percent_term2 = term2/total
    if (np.sum(array_results_l5[2*i][1:2])+np.sum(array_results_l5[2*i +1][1:2]))<0:
        percent_term2=-1*percent_term2
    percent_term3 = term3/total
    if (np.sum(array_results_l5[2*i][2:3])+np.sum(array_results_l5[2*i +1][2:3]))<0:
        percent_term3=-1*percent_term3
    percent_term4 = term4/total
    if (np.sum(array_results_l5[2*i][3:4])+np.sum(array_results_l5[2*i +1][3:4]))<0:
        percent_term4=-1*percent_term4
    percent_term5 = term5/total
    if (np.sum(array_results_l5[2*i][4:5])+np.sum(array_results_l5[2*i +1][4:5]))<0:
        percent_term5=-1*percent_term5
    percent_term6 = term6/total
    if (np.sum(array_results_l5[2*i][5:6])+np.sum(array_results_l5[2*i +1][5:6]))<0:
        percent_term6=-1*percent_term6
    percent_term7 = term7/total
    if (np.sum(array_results_l5[2*i][6:7])+np.sum(array_results_l5[2*i +1][6:7]))<0:
        percent_term7=-1*percent_term7
    percent_term8 = term8/total
    if (np.sum(array_results_l5[2*i][7:8])+np.sum(array_results_l5[2*i +1][7:8]))<0:
        percent_term8=-1*percent_term8
    percent_term9 = term9/total
    if (np.sum(array_results_l5[2*i][8:9])+np.sum(array_results_l5[2*i +1][8:9]))<0:
        percent_term9=-1*percent_term9
    percent_term10 = term10/total
    if (np.sum(array_results_l5[2*i][9:10])+np.sum(array_results_l5[2*i +1][9:10]))<0:
        percent_term10=-1*percent_term10
    percent_term11 = term11/total
    if (np.sum(array_results_l5[2*i][10:11])+np.sum(array_results_l5[2*i +1][10:11]))<0:
        percent_term11=-1*percent_term11
    percent_term12 = term12/total
    if (np.sum(array_results_l5[2*i][11:12])+np.sum(array_results_l5[2*i +1][11:12]))<0:
        percent_term12=-1*percent_term12
    percent_term13 = term13/total
    if (np.sum(array_results_l5[2*i][12:13])+np.sum(array_results_l5[2*i +1][12:13]))<0:
        percent_term13=-1*percent_term13

    return(percent_term1,percent_term2,percent_term3,percent_term4,percent_term5,percent_term6,percent_term7,percent_term8,percent_term9,percent_term10,percent_term11,percent_term12,percent_term13)

# %%
gettermpercentcontributionsl1_other(40)
# Out:
# (0.0020446819832243565,
#  0.14862706318909835,
#  0.05448016521141828,
#  -0.12141857750979491,
#  0.033888158886659324,
#  -0.29942222185975287,
#  -0.030885841342374133,
#  0.012855576782330656,
#  -0.15880348776681968,
#  -0.060267993848196345,
#  -0.03039418356848328,
#  0.02467569394924409,
#  0.022236354102603637)

# %%
all_data_percents_l1 = np.array([gettermpercentcontributionsl1_other(i) for i in range(58)])
all_data_percents_l1_pos = np.zeros_like(all_data_percents_l1 )
all_data_percents_l1_neg = np.zeros_like(all_data_percents_l1 )
for i in range(13):
    for j in range(len(all_data_percents_l1.T[i])):
        if all_data_percents_l1.T[i][j]>0:
            all_data_percents_l1_pos.T[i][j] =  all_data_percents_l1.T[i][j]
            all_data_percents_l1_neg.T[i][j] = 0.0
        else:
            all_data_percents_l1_neg.T[i][j] =  all_data_percents_l1.T[i][j]
            all_data_percents_l1_pos.T[i][j] = 0.0

# %%
diffs = np.diff(omegas_l1)

# %%
widths = np.zeros_like(omegas_l1)

# %%
widths[-1] = .5

# %%
widths[:-1]=diffs[:]

# %%
all_data_percents_l1 = np.array([gettermpercentcontributionsl1_other(i) for i in range(58)])
all_data_percents_l1_pos = np.zeros_like(all_data_percents_l1 )
all_data_percents_l1_neg = np.zeros_like(all_data_percents_l1 )
for i in range(13):
    for j in range(len(all_data_percents_l1.T[i])):
        if all_data_percents_l1.T[i][j]>0:
            all_data_percents_l1_pos.T[i][j] =  all_data_percents_l1.T[i][j]*100
            all_data_percents_l1_neg.T[i][j] = 0.0
        else:
            all_data_percents_l1_neg.T[i][j] =  all_data_percents_l1.T[i][j]*100
            all_data_percents_l1_pos.T[i][j] = 0.0

import matplotlib.colors as colors
import matplotlib.cm as cmx
colors1 = plt.cm.tab20(np.linspace(0, 1, 20))
#colors2 = plt.cm.Paired(np.linspace(0, 1, 12))
#colors3 = plt.cm.spring(np.linspace(0.3, 1, 6))

bottom_set= 0
plt.figure(figsize=(10,5))
plt.bar(omegas_l1,all_data_percents_l1_pos.T[0],width=widths*1, label ='Term 1',color=colors1[0])
bottom_set= all_data_percents_l1_pos.T[0]
plt.bar(omegas_l1,all_data_percents_l1_pos.T[1],width=widths*1, bottom = bottom_set,label ='Term 2',color=colors1[1])
bottom_set += all_data_percents_l1_pos.T[1]
plt.bar(omegas_l1,all_data_percents_l1_pos.T[2],width=widths*1, bottom = bottom_set,label ='Term 3',color=colors1[2])
bottom_set += all_data_percents_l1_pos.T[2]
plt.bar(omegas_l1,all_data_percents_l1_pos.T[3],width=widths*1, bottom = bottom_set,label ='Term 4',color=colors1[3])
bottom_set += all_data_percents_l1_pos.T[3]
plt.bar(omegas_l1,all_data_percents_l1_pos.T[4],width=widths*1, bottom = bottom_set,label ='Term 5',color=colors1[4])
bottom_set += all_data_percents_l1_pos.T[4]
plt.bar(omegas_l1,all_data_percents_l1_pos.T[5],width=widths*1, bottom = bottom_set,label ='Term 6',color=colors1[5])
bottom_set += all_data_percents_l1_pos.T[5]
plt.bar(omegas_l1,all_data_percents_l1_pos.T[6],width=widths*1, bottom = bottom_set,label ='Term 7',color=colors1[6])
bottom_set += all_data_percents_l1_pos.T[6]
plt.bar(omegas_l1,all_data_percents_l1_pos.T[7],width=widths*1, bottom = bottom_set,label ='Term 8',color=colors1[7])
bottom_set += all_data_percents_l1_pos.T[7]
plt.bar(omegas_l1,all_data_percents_l1_pos.T[8],width=widths*1, bottom = bottom_set,label ='Term 9',color=colors1[8])
bottom_set += all_data_percents_l1_pos.T[8]
plt.bar(omegas_l1,all_data_percents_l1_pos.T[9],width=widths*1, bottom = bottom_set,label ='Term 10',color=colors1[9])
bottom_set += all_data_percents_l1_pos.T[9]
plt.bar(omegas_l1,all_data_percents_l1_pos.T[10],width=widths*1,bottom = bottom_set, label ='Term 11',color=colors1[12])
bottom_set += all_data_percents_l1_pos.T[10]
plt.bar(omegas_l1,all_data_percents_l1_pos.T[11],width=widths*1,bottom = bottom_set, label ='Term 12',color=colors1[13])
bottom_set += all_data_percents_l1_pos.T[11]
plt.bar(omegas_l1,all_data_percents_l1_pos.T[12],width=widths*1,bottom = bottom_set, label ='Term 13',color=colors1[16])

plt.bar(omegas_l1,all_data_percents_l1_neg.T[0],width=widths*1,color=colors1[0],edgecolor='black')
bottom_set= all_data_percents_l1_neg.T[0]
plt.bar(omegas_l1,all_data_percents_l1_neg.T[1],width=widths*1, bottom = bottom_set,color=colors1[1])
bottom_set += all_data_percents_l1_neg.T[1]
plt.bar(omegas_l1,all_data_percents_l1_neg.T[2],width=widths*1, bottom = bottom_set,color=colors1[2])
bottom_set += all_data_percents_l1_neg.T[2]
plt.bar(omegas_l1,all_data_percents_l1_neg.T[3],width=widths*1, bottom = bottom_set,color=colors1[3])
bottom_set += all_data_percents_l1_neg.T[3]
plt.bar(omegas_l1,all_data_percents_l1_neg.T[4],width=widths*1, bottom = bottom_set,color=colors1[4])
bottom_set += all_data_percents_l1_neg.T[4]
plt.bar(omegas_l1,all_data_percents_l1_neg.T[5],width=widths*1, bottom = bottom_set,color=colors1[5])
bottom_set += all_data_percents_l1_neg.T[5]
plt.bar(omegas_l1,all_data_percents_l1_neg.T[6],width=widths*1, bottom = bottom_set,color=colors1[6])
bottom_set += all_data_percents_l1_neg.T[6]
plt.bar(omegas_l1,all_data_percents_l1_neg.T[7],width=widths*1, bottom = bottom_set,color=colors1[7])
bottom_set += all_data_percents_l1_neg.T[7]
plt.bar(omegas_l1,all_data_percents_l1_neg.T[8],width=widths*1, bottom = bottom_set,color=colors1[8])
bottom_set += all_data_percents_l1_neg.T[8]
plt.bar(omegas_l1,all_data_percents_l1_neg.T[9],width=widths*1, bottom = bottom_set,color=colors1[9])
bottom_set += all_data_percents_l1_neg.T[9]
plt.bar(omegas_l1,all_data_percents_l1_neg.T[10],width=widths*1,bottom = bottom_set,color=colors1[12])
bottom_set += all_data_percents_l1_neg.T[10]
plt.bar(omegas_l1,all_data_percents_l1_neg.T[11],width=widths*1,bottom = bottom_set,color=colors1[13])
bottom_set += all_data_percents_l1_neg.T[11]
plt.bar(omegas_l1,all_data_percents_l1_neg.T[12],width=widths*1,bottom = bottom_set,color=colors1[16])


plt.plot(np.linspace(.002,18,2000),np.zeros(2000),color='black')
plt.xscale('log')
plt.ylim(-110.0,110.0)
plt.xlim(0.04,16)
#plt.yscale('symlog')
plt.legend(bbox_to_anchor=(1.05,1))
plt.title('Relative % Contribution to Overall Spectra per Term for $\ell=1$',size=14)
plt.xlabel('$\omega$ in units $T_{Hawking}$',size=14)
plt.ylabel('Relative % Contribition',size=14)
plt.savefig('RelContributionl1FIXED.pdf',bbox_inches='tight')

plt.show()

# %%
all_data_percents_l2 = np.array([gettermpercentcontributionsl2_other(i) for i in range(58)])
all_data_percents_l2_pos = np.zeros_like(all_data_percents_l2 )
all_data_percents_l2_neg = np.zeros_like(all_data_percents_l2 )
for i in range(13):
    for j in range(len(all_data_percents_l2.T[i])):
        if all_data_percents_l2.T[i][j]>0:
            all_data_percents_l2_pos.T[i][j] =  all_data_percents_l2.T[i][j]*100
            all_data_percents_l2_neg.T[i][j] = 0.0
        else:
            all_data_percents_l2_neg.T[i][j] =  all_data_percents_l2.T[i][j]*100
            all_data_percents_l2_pos.T[i][j] = 0.0

import matplotlib.colors as colors
import matplotlib.cm as cmx
colors1 = plt.cm.tab20(np.linspace(0, 1, 20))
#colors2 = plt.cm.Paired(np.linspace(0, 1, 12))
#colors3 = plt.cm.spring(np.linspace(0.3, 1, 6))

bottom_set= 0
plt.figure(figsize=(10,5 ))
plt.bar(omegas_l3,all_data_percents_l2_pos.T[0],width=widths*1, label ='Term 1',color=colors1[0])
bottom_set= all_data_percents_l2_pos.T[0]
plt.bar(omegas_l3,all_data_percents_l2_pos.T[1],width=widths*1, bottom = bottom_set,label ='Term 2',color=colors1[1])
bottom_set += all_data_percents_l2_pos.T[1]
plt.bar(omegas_l3,all_data_percents_l2_pos.T[2],width=widths*1, bottom = bottom_set,label ='Term 3',color=colors1[2])
bottom_set += all_data_percents_l2_pos.T[2]
plt.bar(omegas_l3,all_data_percents_l2_pos.T[3],width=widths*1, bottom = bottom_set,label ='Term 4',color=colors1[3])
bottom_set += all_data_percents_l2_pos.T[3]
plt.bar(omegas_l3,all_data_percents_l2_pos.T[4],width=widths*1, bottom = bottom_set,label ='Term 5',color=colors1[4])
bottom_set += all_data_percents_l2_pos.T[4]
plt.bar(omegas_l3,all_data_percents_l2_pos.T[5],width=widths*1, bottom = bottom_set,label ='Term 6',color=colors1[5])
bottom_set += all_data_percents_l2_pos.T[5]
plt.bar(omegas_l3,all_data_percents_l2_pos.T[6],width=widths*1, bottom = bottom_set,label ='Term 7',color=colors1[6])
bottom_set += all_data_percents_l2_pos.T[6]
plt.bar(omegas_l3,all_data_percents_l2_pos.T[7],width=widths*1, bottom = bottom_set,label ='Term 8',color=colors1[7])
bottom_set += all_data_percents_l2_pos.T[7]
plt.bar(omegas_l3,all_data_percents_l2_pos.T[8],width=widths*1, bottom = bottom_set,label ='Term 9',color=colors1[8])
bottom_set += all_data_percents_l2_pos.T[8]
plt.bar(omegas_l3,all_data_percents_l2_pos.T[9],width=widths*1, bottom = bottom_set,label ='Term 10',color=colors1[9])
bottom_set += all_data_percents_l2_pos.T[9]
plt.bar(omegas_l3,all_data_percents_l2_pos.T[10],width=widths*1,bottom = bottom_set, label ='Term 11',color=colors1[12])
bottom_set += all_data_percents_l2_pos.T[10]
plt.bar(omegas_l3,all_data_percents_l2_pos.T[11],width=widths*1,bottom = bottom_set, label ='Term 12',color=colors1[13])
bottom_set += all_data_percents_l2_pos.T[11]
plt.bar(omegas_l3,all_data_percents_l2_pos.T[12],width=widths*1,bottom = bottom_set, label ='Term 13',color=colors1[16])

plt.bar(omegas_l3,all_data_percents_l2_neg.T[0],width=widths*1,color=colors1[0],edgecolor='black')
bottom_set= all_data_percents_l2_neg.T[0]
plt.bar(omegas_l3,all_data_percents_l2_neg.T[1],width=widths*1, bottom = bottom_set,color=colors1[1])
bottom_set += all_data_percents_l2_neg.T[1]
plt.bar(omegas_l3,all_data_percents_l2_neg.T[2],width=widths*1, bottom = bottom_set,color=colors1[2])
bottom_set += all_data_percents_l2_neg.T[2]
plt.bar(omegas_l3,all_data_percents_l2_neg.T[3],width=widths*1, bottom = bottom_set,color=colors1[3])
bottom_set += all_data_percents_l2_neg.T[3]
plt.bar(omegas_l3,all_data_percents_l2_neg.T[4],width=widths*1, bottom = bottom_set,color=colors1[4])
bottom_set += all_data_percents_l2_neg.T[4]
plt.bar(omegas_l3,all_data_percents_l2_neg.T[5],width=widths*1, bottom = bottom_set,color=colors1[5])
bottom_set += all_data_percents_l2_neg.T[5]
plt.bar(omegas_l3,all_data_percents_l2_neg.T[6],width=widths*1, bottom = bottom_set,color=colors1[6])
bottom_set += all_data_percents_l2_neg.T[6]
plt.bar(omegas_l3,all_data_percents_l2_neg.T[7],width=widths*1, bottom = bottom_set,color=colors1[7])
bottom_set += all_data_percents_l2_neg.T[7]
plt.bar(omegas_l3,all_data_percents_l2_neg.T[8],width=widths*1, bottom = bottom_set,color=colors1[8])
bottom_set += all_data_percents_l2_neg.T[8]
plt.bar(omegas_l3,all_data_percents_l2_neg.T[9],width=widths*1, bottom = bottom_set,color=colors1[9])
bottom_set += all_data_percents_l2_neg.T[9]
plt.bar(omegas_l3,all_data_percents_l2_neg.T[10],width=widths*1,bottom = bottom_set,color=colors1[12])
bottom_set += all_data_percents_l2_neg.T[10]
plt.bar(omegas_l3,all_data_percents_l2_neg.T[11],width=widths*1,bottom = bottom_set,color=colors1[13])
bottom_set += all_data_percents_l2_neg.T[11]
plt.bar(omegas_l3,all_data_percents_l2_neg.T[12],width=widths*1,bottom = bottom_set,color=colors1[16])


plt.plot(np.linspace(.002,18,2000),np.zeros(2000),color='black')
plt.xscale('log')
plt.ylim(-110.0,110.)
plt.xlim(0.04,16)
#plt.yscale('symlog')
plt.legend(bbox_to_anchor=(1.05,1))
plt.title('Relative % Contribution to Overall Spectra per Term for $\ell=2$',size=14)
plt.xlabel('$\omega$ in units $T_{Hawking}$',size=14)
plt.ylabel('Relative % Contribition',size=14)
plt.savefig('RelContributionl2FIXED.pdf',bbox_inches='tight')

plt.show()

# %%
all_data_percents_l3 = np.array([gettermpercentcontributionsl3_other(i) for i in range(58)])
all_data_percents_l3_pos = np.zeros_like(all_data_percents_l3 )
all_data_percents_l3_neg = np.zeros_like(all_data_percents_l3 )
for i in range(13):
    for j in range(len(all_data_percents_l3.T[i])):
        if all_data_percents_l3.T[i][j]>0:
            all_data_percents_l3_pos.T[i][j] =  all_data_percents_l3.T[i][j]*100
            all_data_percents_l3_neg.T[i][j] = 0.0
        else:
            all_data_percents_l3_neg.T[i][j] =  all_data_percents_l3.T[i][j]*100
            all_data_percents_l3_pos.T[i][j] = 0.0

import matplotlib.colors as colors
import matplotlib.cm as cmx
colors1 = plt.cm.tab20(np.linspace(0, 1, 20))
#colors2 = plt.cm.Paired(np.linspace(0, 1, 12))
#colors3 = plt.cm.spring(np.linspace(0.3, 1, 6))

bottom_set= 0
plt.figure(figsize=(10,5))
plt.bar(omegas_l3,all_data_percents_l3_pos.T[0],width=widths*1, label ='Term 1',color=colors1[0])
bottom_set= all_data_percents_l3_pos.T[0]
plt.bar(omegas_l3,all_data_percents_l3_pos.T[1],width=widths*1, bottom = bottom_set,label ='Term 2',color=colors1[1])
bottom_set += all_data_percents_l3_pos.T[1]
plt.bar(omegas_l3,all_data_percents_l3_pos.T[2],width=widths*1, bottom = bottom_set,label ='Term 3',color=colors1[2])
bottom_set += all_data_percents_l3_pos.T[2]
plt.bar(omegas_l3,all_data_percents_l3_pos.T[3],width=widths*1, bottom = bottom_set,label ='Term 4',color=colors1[3])
bottom_set += all_data_percents_l3_pos.T[3]
plt.bar(omegas_l3,all_data_percents_l3_pos.T[4],width=widths*1, bottom = bottom_set,label ='Term 5',color=colors1[4])
bottom_set += all_data_percents_l3_pos.T[4]
plt.bar(omegas_l3,all_data_percents_l3_pos.T[5],width=widths*1, bottom = bottom_set,label ='Term 6',color=colors1[5])
bottom_set += all_data_percents_l3_pos.T[5]
plt.bar(omegas_l3,all_data_percents_l3_pos.T[6],width=widths*1, bottom = bottom_set,label ='Term 7',color=colors1[6])
bottom_set += all_data_percents_l3_pos.T[6]
plt.bar(omegas_l3,all_data_percents_l3_pos.T[7],width=widths*1, bottom = bottom_set,label ='Term 8',color=colors1[7])
bottom_set += all_data_percents_l3_pos.T[7]
plt.bar(omegas_l3,all_data_percents_l3_pos.T[8],width=widths*1, bottom = bottom_set,label ='Term 9',color=colors1[8])
bottom_set += all_data_percents_l3_pos.T[8]
plt.bar(omegas_l3,all_data_percents_l3_pos.T[9],width=widths*1, bottom = bottom_set,label ='Term 10',color=colors1[9])
bottom_set += all_data_percents_l3_pos.T[9]
plt.bar(omegas_l3,all_data_percents_l3_pos.T[10],width=widths*1,bottom = bottom_set, label ='Term 11',color=colors1[12])
bottom_set += all_data_percents_l3_pos.T[10]
plt.bar(omegas_l3,all_data_percents_l3_pos.T[11],width=widths*1,bottom = bottom_set, label ='Term 12',color=colors1[13])
bottom_set += all_data_percents_l3_pos.T[11]
plt.bar(omegas_l3,all_data_percents_l3_pos.T[12],width=widths*1,bottom = bottom_set, label ='Term 13',color=colors1[16])

plt.bar(omegas_l3,all_data_percents_l3_neg.T[0],width=widths*1,color=colors1[0],edgecolor='black')
bottom_set= all_data_percents_l3_neg.T[0]
plt.bar(omegas_l3,all_data_percents_l3_neg.T[1],width=widths*1, bottom = bottom_set,color=colors1[1])
bottom_set += all_data_percents_l3_neg.T[1]
plt.bar(omegas_l3,all_data_percents_l3_neg.T[2],width=widths*1, bottom = bottom_set,color=colors1[2])
bottom_set += all_data_percents_l3_neg.T[2]
plt.bar(omegas_l3,all_data_percents_l3_neg.T[3],width=widths*1, bottom = bottom_set,color=colors1[3])
bottom_set += all_data_percents_l3_neg.T[3]
plt.bar(omegas_l3,all_data_percents_l3_neg.T[4],width=widths*1, bottom = bottom_set,color=colors1[4])
bottom_set += all_data_percents_l3_neg.T[4]
plt.bar(omegas_l3,all_data_percents_l3_neg.T[5],width=widths*1, bottom = bottom_set,color=colors1[5])
bottom_set += all_data_percents_l3_neg.T[5]
plt.bar(omegas_l3,all_data_percents_l3_neg.T[6],width=widths*1, bottom = bottom_set,color=colors1[6])
bottom_set += all_data_percents_l3_neg.T[6]
plt.bar(omegas_l3,all_data_percents_l3_neg.T[7],width=widths*1, bottom = bottom_set,color=colors1[7])
bottom_set += all_data_percents_l3_neg.T[7]
plt.bar(omegas_l3,all_data_percents_l3_neg.T[8],width=widths*1, bottom = bottom_set,color=colors1[8])
bottom_set += all_data_percents_l3_neg.T[8]
plt.bar(omegas_l3,all_data_percents_l3_neg.T[9],width=widths*1, bottom = bottom_set,color=colors1[9])
bottom_set += all_data_percents_l3_neg.T[9]
plt.bar(omegas_l3,all_data_percents_l3_neg.T[10],width=widths*1,bottom = bottom_set,color=colors1[12])
bottom_set += all_data_percents_l3_neg.T[10]
plt.bar(omegas_l3,all_data_percents_l3_neg.T[11],width=widths*1,bottom = bottom_set,color=colors1[13])
bottom_set += all_data_percents_l3_neg.T[11]
plt.bar(omegas_l3,all_data_percents_l3_neg.T[12],width=widths*1,bottom = bottom_set,color=colors1[16])


plt.plot(np.linspace(.002,18,2000),np.zeros(2000),color='black')
plt.xscale('log')
plt.ylim(-110.0,110.)
plt.xlim(0.04,16)
#plt.yscale('symlog')
plt.legend(bbox_to_anchor=(1.05,1))
plt.title('Relative % Contribution to Overall Spectra per Term for $\ell=3$',size=14)
plt.xlabel('$\omega$ in units $T_{Hawking}$',size=14)
plt.ylabel('Relative % Contribition',size=14)
plt.savefig('RelContributionl3FIXED.pdf',bbox_inches='tight')

plt.show()

# %%
all_data_percents_l4 = np.array([gettermpercentcontributionsl4_other(i) for i in range(58)])
all_data_percents_l4_pos = np.zeros_like(all_data_percents_l4 )
all_data_percents_l4_neg = np.zeros_like(all_data_percents_l4 )
for i in range(13):
    for j in range(len(all_data_percents_l4.T[i])):
        if all_data_percents_l4.T[i][j]>0:
            all_data_percents_l4_pos.T[i][j] =  all_data_percents_l4.T[i][j]*100
            all_data_percents_l4_neg.T[i][j] = 0.0
        else:
            all_data_percents_l4_neg.T[i][j] =  all_data_percents_l4.T[i][j]*100
            all_data_percents_l4_pos.T[i][j] = 0.0

import matplotlib.colors as colors
import matplotlib.cm as cmx
colors1 = plt.cm.tab20(np.linspace(0, 1, 20))
#colors2 = plt.cm.Paired(np.linspace(0, 1, 12))
#colors3 = plt.cm.spring(np.linspace(0.3, 1, 6))

bottom_set= 0
plt.figure(figsize=(14,6))
plt.bar(omegas_l3,all_data_percents_l4_pos.T[0],width=widths*1, label ='term1',color=colors1[0])
bottom_set= all_data_percents_l4_pos.T[0]
plt.bar(omegas_l3,all_data_percents_l4_pos.T[1],width=widths*1, bottom = bottom_set,label ='term2',color=colors1[1])
bottom_set += all_data_percents_l4_pos.T[1]
plt.bar(omegas_l3,all_data_percents_l4_pos.T[2],width=widths*1, bottom = bottom_set,label ='term3',color=colors1[2])
bottom_set += all_data_percents_l4_pos.T[2]
plt.bar(omegas_l3,all_data_percents_l4_pos.T[3],width=widths*1, bottom = bottom_set,label ='term4',color=colors1[3])
bottom_set += all_data_percents_l4_pos.T[3]
plt.bar(omegas_l3,all_data_percents_l4_pos.T[4],width=widths*1, bottom = bottom_set,label ='term5',color=colors1[4])
bottom_set += all_data_percents_l4_pos.T[4]
plt.bar(omegas_l3,all_data_percents_l4_pos.T[5],width=widths*1, bottom = bottom_set,label ='term6',color=colors1[5])
bottom_set += all_data_percents_l4_pos.T[5]
plt.bar(omegas_l3,all_data_percents_l4_pos.T[6],width=widths*1, bottom = bottom_set,label ='term7',color=colors1[6])
bottom_set += all_data_percents_l4_pos.T[6]
plt.bar(omegas_l3,all_data_percents_l4_pos.T[7],width=widths*1, bottom = bottom_set,label ='term8',color=colors1[7])
bottom_set += all_data_percents_l4_pos.T[7]
plt.bar(omegas_l3,all_data_percents_l4_pos.T[8],width=widths*1, bottom = bottom_set,label ='term9',color=colors1[8])
bottom_set += all_data_percents_l4_pos.T[8]
plt.bar(omegas_l3,all_data_percents_l4_pos.T[9],width=widths*1, bottom = bottom_set,label ='term10',color=colors1[9])
bottom_set += all_data_percents_l4_pos.T[9]
plt.bar(omegas_l3,all_data_percents_l4_pos.T[10],width=widths*1,bottom = bottom_set, label ='term11',color=colors1[12])
bottom_set += all_data_percents_l4_pos.T[10]
plt.bar(omegas_l3,all_data_percents_l4_pos.T[11],width=widths*1,bottom = bottom_set, label ='term12',color=colors1[13])
bottom_set += all_data_percents_l4_pos.T[11]
plt.bar(omegas_l3,all_data_percents_l4_pos.T[12],width=widths*1,bottom = bottom_set, label ='term13',color=colors1[16])

plt.bar(omegas_l3,all_data_percents_l4_neg.T[0],width=widths*1,color=colors1[0],edgecolor='black')
bottom_set= all_data_percents_l4_neg.T[0]
plt.bar(omegas_l3,all_data_percents_l4_neg.T[1],width=widths*1, bottom = bottom_set,color=colors1[1])
bottom_set += all_data_percents_l4_neg.T[1]
plt.bar(omegas_l3,all_data_percents_l4_neg.T[2],width=widths*1, bottom = bottom_set,color=colors1[2])
bottom_set += all_data_percents_l4_neg.T[2]
plt.bar(omegas_l3,all_data_percents_l4_neg.T[3],width=widths*1, bottom = bottom_set,color=colors1[3])
bottom_set += all_data_percents_l4_neg.T[3]
plt.bar(omegas_l3,all_data_percents_l4_neg.T[4],width=widths*1, bottom = bottom_set,color=colors1[4])
bottom_set += all_data_percents_l4_neg.T[4]
plt.bar(omegas_l3,all_data_percents_l4_neg.T[5],width=widths*1, bottom = bottom_set,color=colors1[5])
bottom_set += all_data_percents_l4_neg.T[5]
plt.bar(omegas_l3,all_data_percents_l4_neg.T[6],width=widths*1, bottom = bottom_set,color=colors1[6])
bottom_set += all_data_percents_l4_neg.T[6]
plt.bar(omegas_l3,all_data_percents_l4_neg.T[7],width=widths*1, bottom = bottom_set,color=colors1[7])
bottom_set += all_data_percents_l4_neg.T[7]
plt.bar(omegas_l3,all_data_percents_l4_neg.T[8],width=widths*1, bottom = bottom_set,color=colors1[8])
bottom_set += all_data_percents_l4_neg.T[8]
plt.bar(omegas_l3,all_data_percents_l4_neg.T[9],width=widths*1, bottom = bottom_set,color=colors1[9])
bottom_set += all_data_percents_l4_neg.T[9]
plt.bar(omegas_l3,all_data_percents_l4_neg.T[10],width=widths*1,bottom = bottom_set,color=colors1[12])
bottom_set += all_data_percents_l4_neg.T[10]
plt.bar(omegas_l3,all_data_percents_l4_neg.T[11],width=widths*1,bottom = bottom_set,color=colors1[13])
bottom_set += all_data_percents_l4_neg.T[11]
plt.bar(omegas_l3,all_data_percents_l4_neg.T[12],width=widths*1,bottom = bottom_set,color=colors1[16])


plt.plot(np.linspace(.002,18,2000),np.zeros(2000),color='black')
plt.xscale('log')
plt.ylim(-110.0,110.)
plt.xlim(0.04,16)
#plt.yscale('symlog')
plt.legend(bbox_to_anchor=(1.05,1))
plt.title('relative % contribution per term l=4')
plt.xlabel('omega')
plt.ylabel('relative % contribition')

plt.savefig('RelContributionl4FIXED.pdf',bbox_inches='tight')

plt.show()

# %%
all_data_percents_l5 = np.array([gettermpercentcontributionsl5_other(i) for i in range(58)])
all_data_percents_l5_pos = np.zeros_like(all_data_percents_l5 )
all_data_percents_l5_neg = np.zeros_like(all_data_percents_l5 )
for i in range(13):
    for j in range(len(all_data_percents_l5.T[i])):
        if all_data_percents_l5.T[i][j]>0:
            all_data_percents_l5_pos.T[i][j] =  all_data_percents_l5.T[i][j]*100
            all_data_percents_l5_neg.T[i][j] = 0.0
        else:
            all_data_percents_l5_neg.T[i][j] =  all_data_percents_l5.T[i][j]*100
            all_data_percents_l5_pos.T[i][j] = 0.0

import matplotlib.colors as colors
import matplotlib.cm as cmx
colors1 = plt.cm.tab20(np.linspace(0, 1, 20))
#colors2 = plt.cm.Paired(np.linspace(0, 1, 12))
#colors3 = plt.cm.spring(np.linspace(0.3, 1, 6))

bottom_set= 0
plt.figure(figsize=(14,6))
plt.bar(omegas_l3,all_data_percents_l5_pos.T[0],width=widths*1, label ='term1',color=colors1[0])
bottom_set= all_data_percents_l5_pos.T[0]
plt.bar(omegas_l3,all_data_percents_l5_pos.T[1],width=widths*1, bottom = bottom_set,label ='term2',color=colors1[1])
bottom_set += all_data_percents_l5_pos.T[1]
plt.bar(omegas_l3,all_data_percents_l5_pos.T[2],width=widths*1, bottom = bottom_set,label ='term3',color=colors1[2])
bottom_set += all_data_percents_l5_pos.T[2]
plt.bar(omegas_l3,all_data_percents_l5_pos.T[3],width=widths*1, bottom = bottom_set,label ='term4',color=colors1[3])
bottom_set += all_data_percents_l5_pos.T[3]
plt.bar(omegas_l3,all_data_percents_l5_pos.T[4],width=widths*1, bottom = bottom_set,label ='term5',color=colors1[4])
bottom_set += all_data_percents_l5_pos.T[4]
plt.bar(omegas_l3,all_data_percents_l5_pos.T[5],width=widths*1, bottom = bottom_set,label ='term6',color=colors1[5])
bottom_set += all_data_percents_l5_pos.T[5]
plt.bar(omegas_l3,all_data_percents_l5_pos.T[6],width=widths*1, bottom = bottom_set,label ='term7',color=colors1[6])
bottom_set += all_data_percents_l5_pos.T[6]
plt.bar(omegas_l3,all_data_percents_l5_pos.T[7],width=widths*1, bottom = bottom_set,label ='term8',color=colors1[7])
bottom_set += all_data_percents_l5_pos.T[7]
plt.bar(omegas_l3,all_data_percents_l5_pos.T[8],width=widths*1, bottom = bottom_set,label ='term9',color=colors1[8])
bottom_set += all_data_percents_l5_pos.T[8]
plt.bar(omegas_l3,all_data_percents_l5_pos.T[9],width=widths*1, bottom = bottom_set,label ='term10',color=colors1[9])
bottom_set += all_data_percents_l5_pos.T[9]
plt.bar(omegas_l3,all_data_percents_l5_pos.T[10],width=widths*1,bottom = bottom_set, label ='term11',color=colors1[12])
bottom_set += all_data_percents_l5_pos.T[10]
plt.bar(omegas_l3,all_data_percents_l5_pos.T[11],width=widths*1,bottom = bottom_set, label ='term12',color=colors1[13])
bottom_set += all_data_percents_l5_pos.T[11]
plt.bar(omegas_l3,all_data_percents_l5_pos.T[12],width=widths*1,bottom = bottom_set, label ='term13',color=colors1[16])

plt.bar(omegas_l3,all_data_percents_l5_neg.T[0],width=widths*1,color=colors1[0],edgecolor='black')
bottom_set= all_data_percents_l5_neg.T[0]
plt.bar(omegas_l3,all_data_percents_l5_neg.T[1],width=widths*1, bottom = bottom_set,color=colors1[1])
bottom_set += all_data_percents_l5_neg.T[1]
plt.bar(omegas_l3,all_data_percents_l5_neg.T[2],width=widths*1, bottom = bottom_set,color=colors1[2])
bottom_set += all_data_percents_l5_neg.T[2]
plt.bar(omegas_l3,all_data_percents_l5_neg.T[3],width=widths*1, bottom = bottom_set,color=colors1[3])
bottom_set += all_data_percents_l5_neg.T[3]
plt.bar(omegas_l3,all_data_percents_l5_neg.T[4],width=widths*1, bottom = bottom_set,color=colors1[4])
bottom_set += all_data_percents_l5_neg.T[4]
plt.bar(omegas_l3,all_data_percents_l5_neg.T[5],width=widths*1, bottom = bottom_set,color=colors1[5])
bottom_set += all_data_percents_l5_neg.T[5]
plt.bar(omegas_l3,all_data_percents_l5_neg.T[6],width=widths*1, bottom = bottom_set,color=colors1[6])
bottom_set += all_data_percents_l5_neg.T[6]
plt.bar(omegas_l3,all_data_percents_l5_neg.T[7],width=widths*1, bottom = bottom_set,color=colors1[7])
bottom_set += all_data_percents_l5_neg.T[7]
plt.bar(omegas_l3,all_data_percents_l5_neg.T[8],width=widths*1, bottom = bottom_set,color=colors1[8])
bottom_set += all_data_percents_l5_neg.T[8]
plt.bar(omegas_l3,all_data_percents_l5_neg.T[9],width=widths*1, bottom = bottom_set,color=colors1[9])
bottom_set += all_data_percents_l5_neg.T[9]
plt.bar(omegas_l3,all_data_percents_l5_neg.T[10],width=widths*1,bottom = bottom_set,color=colors1[12])
bottom_set += all_data_percents_l5_neg.T[10]
plt.bar(omegas_l3,all_data_percents_l5_neg.T[11],width=widths*1,bottom = bottom_set,color=colors1[13])
bottom_set += all_data_percents_l5_neg.T[11]
plt.bar(omegas_l3,all_data_percents_l5_neg.T[12],width=widths*1,bottom = bottom_set,color=colors1[16])


plt.plot(np.linspace(.002,18,2000),np.zeros(2000),color='black')
plt.xscale('log')
plt.ylim(-110.0,110.)
plt.xlim(0.04,16)
#plt.yscale('symlog')
plt.legend(bbox_to_anchor=(1.05,1))
plt.title('relative % contribution per term l=5')
plt.xlabel('omega')
plt.ylabel('relative % contribition')

plt.savefig('RelContributionl5FIXED.pdf',bbox_inches='tight')

plt.show()

# %%
"""fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})
for i in range(0,len(omegas_l3),1):
    #ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][1])+np.sum(array_results_l1[2*i +1][1]))), label = '1',color='r')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][1])+np.sum(array_results_l2[2*i +1][1]))), label = '2',color='g')
    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2old[2*i][1])+np.sum(array_results_l2old[2*i +1][1]))), label = '2old',color='orange')
    #ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][1])+np.sum(array_results_l3[2*i +1][1]))), label = '3',color='b')
    
ax[0].set_xscale('log')
ax[0].set_yscale('log')

#handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[-40],handles[-1]],[labels[0],labels[-40],labels[-1]])
handles, labels = ax[0].get_legend_handles_labels()
#ax[0].legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6]],[labels[0],labels[1],labels[2],labels[3],labels[4],labels[5],labels[-1]])

ax[1].set_xlim(.04,16)
#ax[0].set_ylim(1e-12,5e-11)
for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][1])+np.sum(array_results_l2[2*i +1][7])))
    val_l2old = (np.abs(np.sum(array_results_l2old[2*i][1])+np.sum(array_results_l2old[2*i +1][1])))
    val = val_l2old/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l2old/l2', color='y')

ax[1].set_ylim(0.01,5)
#ax[1].set_yscale('log')
ax[0].set_title('all omega term 2 abs')
plt.show()           """
# Out:
# "fig, ax = plt.subplots(nrows=2, ncols=1,sharex=True,gridspec_kw={'height_ratios':[3, 1]})\nfor i in range(0,len(omegas_l3),1):\n    #ax[0].scatter(omegas_l1[i],(np.abs(np.sum(array_results_l1[2*i][1])+np.sum(array_results_l1[2*i +1][1]))), label = '1',color='r')\n    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2[2*i][1])+np.sum(array_results_l2[2*i +1][1]))), label = '2',color='g')\n    ax[0].scatter(omegas_l2[i],(np.abs(np.sum(array_results_l2old[2*i][1])+np.sum(array_results_l2old[2*i +1][1]))), label = '2old',color='orange')\n    #ax[0].scatter(omegas_l3[i],(np.abs(np.sum(array_results_l3[2*i][1])+np.sum(array_results_l3[2*i +1][1]))), label = '3',color='b')\n    \nax[0].set_xscale('log')\nax[0].set_yscale('log')\n\n#handles, labels = ax[0].get_legend_handles_labels()\n#ax[0].legend([handles[0],handles[-40],handles[-1]],[labels[0],labels[-40],labels[-1]])\nhandles, labels = ax[0].get_legend_handles_labels()\n#ax[0].legend([handles[0],handles[1],handles[2],handles[3],
# ...

# %%
plt.bar(1,1,width=.8)
plt.show()

# %%
x = np.array([3,4,7,10,12,13.])

# %%
y = [1,2,3,4,5,6]

# %%
dx = np.zeros_like(x)

# %%
dx[1:-1]= (x[2:]-x[:-2])/2

# %%
dx[0]=x[1]-x[0]

# %%
dx[-1]=x[-1]-x[-2]

# %%
xc = np.zeros_like(x)

# %%
xc[1:-1]= (x[2:]+x[:-2]+2*x[1:-1])/4

# %%
xc[0] = x[0]

# %%
xc[-1]= x[-1]

# %%
dx
# Out:
# array([1. , 2. , 3. , 2.5, 1.5, 1. ])

# %%
plt.bar(xc,y,width=dx)
# Out:
# <BarContainer object of 6 artists>

# %%
def getrellpercent(i):
    term1 = (np.abs(np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:])))/m1_rescale[i,1]
    term2 = (np.abs(np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:])))/m1_rescale[i,2]
    term3 = (np.abs(np.sum(array_results_l3[2*i][:])+np.sum(array_results_l3[2*i +1][:])))/m1_rescale[i,3]
    term4 = (np.abs(np.sum(array_results_l4[2*i][:])+np.sum(array_results_l4[2*i +1][:])))/m1_rescale[i,4]
    term5 = (np.abs(np.sum(array_results_l5[2*i][:])+np.sum(array_results_l5[2*i +1][:])))/m1_rescale[i,5]
    
    total = term1+term2+term3+term4 +term5
    print(term1/total,term2/total,term3/total, term4/total,term5/total)
    
    percent_term1 = term1/total
    if (np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:]))<0:
        percent_term1=-1*percent_term1
    percent_term2 = term2/total
    if (np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:]))<0:
        percent_term2=-1*percent_term2
    percent_term3 = term3/total
    if (np.sum(array_results_l3[2*i][:])+np.sum(array_results_l3[2*i +1][:]))<0:
        percent_term3=-1*percent_term3
    percent_term4 = term4/total
    if (np.sum(array_results_l4[2*i][:])+np.sum(array_results_l4[2*i +1][:]))<0:
        percent_term4=-1*percent_term4
    percent_term5 = term5/total
    if (np.sum(array_results_l5[2*i][:])+np.sum(array_results_l5[2*i +1][:]))<0:
        percent_term5=-1*percent_term5
    return(percent_term1,percent_term2,percent_term3,percent_term4,percent_term5)

# %%
all_percents = np.array([getrellpercent(i) for i in range(58)])
all_percents_pos = np.zeros_like(all_percents )
all_percents_neg = np.zeros_like(all_percents )

for i in range(5):
    for j in range(len(all_percents.T[i])):
        if all_percents.T[i][j]>0:
            all_percents_pos.T[i][j] =  all_percents.T[i][j]*100
            all_percents_neg.T[i][j] = 0.0
        else:
            all_percents_neg.T[i][j] =  all_percents.T[i][j]*100
            all_percents_pos.T[i][j] = 0.0
f=open("percentcontM1L1-5.txt", "w")
for x in range(56):
    f.write(str((omegas_l1[x],all_percents_pos[x],all_percents_neg[x])) + '\n')
f.close()

import matplotlib.colors as colors
import matplotlib.cm as cmx

#colors2 = plt.cm.Paired(np.linspace(0, 1, 12))
#colors3 = plt.cm.spring(np.linspace(0.3, 1, 6))

bottom_set= 0
plt.figure(figsize=(10,5))
plt.bar(omegas_l3,all_percents_pos.T[0],width=widths*1, label =r'$\ell$=1',color='r')
bottom_set= all_percents_pos.T[0]
plt.bar(omegas_l3,all_percents_pos.T[1],width=widths*1, bottom = bottom_set,label =r'$\ell$=2',color='g')
bottom_set += all_percents_pos.T[1]
plt.bar(omegas_l3,all_percents_pos.T[2],width=widths*1, bottom = bottom_set,label =r'$\ell$=3',color='b')
bottom_set += all_percents_pos.T[2]
plt.bar(omegas_l3,all_percents_pos.T[3],width=widths*1, bottom = bottom_set,label =r'$\ell$=4',color='orange')
bottom_set += all_percents_pos.T[3]
plt.bar(omegas_l3,all_percents_pos.T[4],width=widths*1, bottom = bottom_set,label =r'$\ell$=5',color='magenta')
bottom_set += all_percents_pos.T[4]


plt.bar(omegas_l3,all_percents_neg.T[0],width=widths*1,color='r')
bottom_set= all_percents_neg.T[0]
plt.bar(omegas_l3,all_percents_neg.T[1],width=widths*1, bottom = bottom_set,color='g')
bottom_set += all_percents_neg.T[1]
plt.bar(omegas_l3,all_percents_neg.T[2],width=widths*1, bottom = bottom_set,color='b')
bottom_set += all_percents_neg.T[2]
plt.bar(omegas_l3,all_percents_neg.T[3],width=widths*1, bottom = bottom_set,color='orange')
bottom_set += all_percents_neg.T[3]
plt.bar(omegas_l3,all_percents_neg.T[4],width=widths*1, bottom = bottom_set,color='magenta')
bottom_set += all_percents_neg.T[4]


plt.plot(np.linspace(.002,18,2000),np.zeros(2000),color='black')
plt.xscale('log')
plt.ylim(-110.0,110.)
plt.xlim(0.04,16)
#plt.yscale('symlog')
plt.legend(bbox_to_anchor=(1.,1))
plt.title(r'Relative % contribution by each $\ell$',size=12)
plt.xlabel(r'$\omega$/$T_{Hawking}$',size=12)
plt.ylabel('Relative % Contribition',size=12)

plt.savefig('RelContributionperLFIXED.pdf',bbox_inches='tight')

plt.show()
# Out:
# 0.5382463327571944 0.23465161376184804 0.11989412339284192 0.06728572751013993 0.039922202577975886
# 0.5398630338794732 0.2337007258954409 0.11955367083982808 0.06708592187770002 0.039796647507557834
# 0.5406917570274233 0.2329252982060307 0.11951984273528712 0.06707970065288246 0.039783401378376264
# 0.5404187536550178 0.23319328889682597 0.11915090109060598 0.06730734117338867 0.039929715184161725
# 0.5420111558404573 0.2320154261953471 0.11920801749561265 0.06683640268326252 0.03992899778532034
# 0.5427789669806662 0.23170182463706646 0.11859964124064828 0.06699520018450734 0.03992436695711173
# 0.543780061428475 0.23115146562633973 0.11829058471084658 0.06704837225813995 0.039729515976198816
# 0.5450736931772411 0.23017321829801296 0.11824406083204819 0.06665183155944467 0.039857196133253094
# 0.5469322598285524 0.22958321378860186 0.11728120884755047 0.06659972230193932 0.039603595233355916
# ...

# %%
0.379515953558022/0.22327329491621775
# Out:
# 1.6997821154582484

# %%
0.3890552539900179/0.21707705753707918
# Out:
# 1.7922449217074123

# %%
0.39567032744990227/0.21620699472529606
# Out:
# 1.8300533151234313

# %%
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(8,4))
y1listpos =[]
y1listneg =[]
y2listpos =[]
y2listneg =[]


y3listpos =[]
y3listneg =[]
y4listpos =[]
y4listneg =[]
y5listpos =[]
y5listneg =[]

ytotalpos =[]
ytotalneg =[]


color1 =[]
for i in range(0,len(omegas_l1),1):
    
    y1 =(np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:]))/m1_rescale[i,1]
    if y1>0:
        y1listpos.append(np.abs(y1))
        y1listneg.append(None)
    if y1<0:
        y1listpos.append(None)
        y1listneg.append(np.abs(y1))
    y2 =(np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:]))/m1_rescale[i,2]
    if y2>0:
        y2listpos.append(np.abs(y2))
        y2listneg.append(None)
    if y2<0:
        y2listpos.append(None)
        y2listneg.append(np.abs(y2))
    
    y3 =(np.sum(array_results_l3[2*i][:])+np.sum(array_results_l3[2*i +1][:]))/m1_rescale[i,3]
    if y3>0:
        y3listpos.append(np.abs(y3))
        y3listneg.append(None)
    if y3<0:
        y3listpos.append(None)
        y3listneg.append(np.abs(y3))
    y4 =(np.sum(array_results_l4[2*i][:])+np.sum(array_results_l4[2*i +1][:]))/m1_rescale[i,4]
    if y4>0:
        y4listpos.append(np.abs(y4))
        y4listneg.append(None)
    if y4<0:
        y4listpos.append(None)
        y4listneg.append(np.abs(y4))
    y5 =(np.sum(array_results_l5[2*i][:])+np.sum(array_results_l5[2*i +1][:]))/m1_rescale[i,5]
    if y5>0:
        y5listpos.append(np.abs(y5))
        y5listneg.append(None)
    if y5<0:
        y5listpos.append(None)
        y5listneg.append(np.abs(y5))
        
    yall =y1+y2+y3+y4+y5
    if yall>0:
        ytotalpos.append(np.abs(yall))
        ytotalneg.append(None)
    if yall<0:
        ytotalpos.append(None)
        ytotalneg.append(np.abs(yall))
        
    
    
    #color1.append('r' if y1<0 else 'g')


    
ax.plot(omegas_l1,np.array(y1listpos), label = 'l1', color ='r',linestyle='-')
ax.plot(omegas_l1,np.array(y1listneg), label = 'l1', color ='r',linestyle='--')

ax.plot(omegas_l1,np.array(y2listpos), label = 'l2', color ='g',linestyle='-')
ax.plot(omegas_l1,np.array(y2listneg), label = 'l2', color ='g',linestyle='--')

ax.plot(omegas_l3,np.array(y3listpos), label = 'l3', color ='b',linestyle='-')
ax.plot(omegas_l3,np.array(y3listneg), label = 'l3', color ='b',linestyle='--')
ax.plot(omegas_l4,np.array(y4listpos), label = 'l4', color ='orange',linestyle='-')
ax.plot(omegas_l4,np.array(y4listneg), label = 'l4', color ='orange',linestyle='--')
ax.plot(omegas_l4,np.array(y5listpos), label = 'l5', color ='magenta',linestyle='-')
ax.plot(omegas_l4,np.array(y5listneg), label = 'l5', color ='magenta',linestyle='--')

ax.plot(omegas_l4,np.array(ytotalpos), label = 'sum', color ='black',linestyle='-')
ax.plot(omegas_l4,np.array(ytotalneg), label = 'sum', color ='black',linestyle='--')


#plt.plot(omegas_l1, 1.042e-4/np.array(omegas_l1), label ='fitted', color = 'cyan')

ax.scatter(5.25,1.2661721787952992e-07,color='red',marker='x')
ax.scatter(5.5,2.580926024607328e-07,color='red',marker='x')
ax.scatter(9.5,3.8644539932221423e-10,color='g',marker='x')
ax.scatter(10.0,6.166298497697745e-09,color='g',marker='x')
ax.scatter(13.5,4.257663153588525e-11,color='b',marker='x')
ax.scatter(14.0,2.2699690865799916e-11,color='b',marker='x')
ax.scatter(5.5,1.4484646439527064e-08,color='black',marker='x')
ax.scatter(5.75,3.5051506468999694e-07,color='black',marker='x')

#for i in range(0,len(omegas_l2)-1,1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*(np.abs(np.sum(array_results_l2[2*i][:]))+np.abs(np.sum(array_results_l2[2*i +1][:]))), label = 'l2', color='b')

#for i in range(0,len(omegas_l2)-,1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*((np.abs(np.sum(array_results_l2[2*i][:]))+np.abs(np.sum(array_results_l2[2*i +1][:])))+(np.abs(np.sum(array_results_l1[2*i][:]))+np.abs(np.sum(array_results_l1[2*i +1][:])))), label = 'summed', color='g')

ax.set_xscale('log')
ax.set_yscale('log')

handles, labels = ax.get_legend_handles_labels()
ax.legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6],handles[7],handles[8],handles[9],handles[10],handles[11]],['l=1 positive','l=1 negative','l=2 positive','l=2 negative','l=3 positive','l=3 negative','l=4 positive','l=4 negative','l=5 positive','l=5 negative','total positive','total negative'],bbox_to_anchor=(0.85, 0.45, 0.5, 0.5))
#ax.legend([handles[0],handles[1]],['l=1 positive','l=1 negative'])

ax.set_xlim(.04,16)
ax.set_ylim(1e-10,1e-2)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][:]))+np.abs(np.sum(array_results_l2[2*i +1][:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][:]))+np.abs(np.sum(array_results_l1[2*i +1][:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""
#ax[1].set_ylabel('l1/l2')
plt.xlabel('$\omega$ (units of $T_{H}$)',size=13)
plt.ylabel(r'$ \frac{dN_{\gamma}}{d\omega dt}$',size=17)
ax.set_title(r' $M=1\times 10^{21}m_{planck}$',size=14)
#ax.legend(bbox_to_anchor=(0.7, 0.5, 0.5, 0.5))
#plt.savefig('totall1and3.pdf',bbox_inches='tight')
plt.savefig("PBH/absnegandposFIXED.pdf",bbox_inches='tight')
plt.show()

# %%
ytotalpos[1]
# Out:
# 0.0017377688750301239

# %%
1.042e-4 /0.06
# Out:
# 0.0017366666666666667

# %%
0.0017377688750301239 - 0.0017366666666666667
# Out:
# 1.1022083634571345e-06

# %%
np.array(ytotalneg)
# Out:
# array([None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, 3.5051506468999694e-07, 6.38584498057867e-07,
#        8.459280371038789e-07, 9.665630785540397e-07, 9.94834716645343e-07,
#        9.40425422429012e-07, 8.359718764419779e-07, 7.141259734754826e-07,
#        5.948445665319601e-07, 4.875533389226248e-07,
#        3.180367903085151e-07, 2.0204013293321527e-07,
#        1.2748839497085448e-07, 8.316058416666378e-08,
#        5.848267315670351e-08, 4.449881781343697e-08,
#        3.4677963786235496e-08, 2.5836895684416473e-08,
#        1.786847165657194e-08, 1.1597381726415611e-08,
#        7.245800907307465e-09, 4.460711124385084e-09,
#        2.7589756634253152e-09, 1.746875073028182e-09], dtype=object)

# %%
transmission_coeffs = np.load("TransmissionCoeffs.npy")

# %%
om = np.linspace(0.01,20,2000)
prim= np.zeros(2000)
for i in range(2000):
    for l in range(0,5):
        prim[i] += (np.abs(transmission_coeffs[l][i])**2)*(2*l+2)/(np.pi*np.exp(om[i]) -1)

# %%
plt.plot(om,(np.abs(transmission_coeffs[0][:])**2)*(2*1+2)/(np.pi*np.exp(om[:]) -1),label="1")
plt.plot(om,(np.abs(transmission_coeffs[1][:])**2)*(2*2+2)/(np.pi*np.exp(om[:]) -1),label='2')
plt.plot(om,(np.abs(transmission_coeffs[2][:])**2)*(2*3+2)/(np.pi*np.exp(om[:]) -1),label='3')
plt.plot(om,(np.abs(transmission_coeffs[3][:])**2)*(2*4+2)/(np.pi*np.exp(om[:]) -1),label='4')
plt.plot(om,(np.abs(transmission_coeffs[4][:])**2)*(2*5+2)/(np.pi*np.exp(om[:]) -1),label='5')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.title("$dN_{0}/d\omega dt$")
plt.xlabel('$\omega$ in units T_{H}')
plt.show()

# %%
total_results = np.zeros(len(omegas_l1))

for i in range(len(omegas_l1)):
    ind = int(np.round(omegas_l1[i]*100)-1)
    if ytotalpos[i] !=None: 
        total_results[i] = prim[ind]+ytotalpos[i]
        print(str(omegas_l1[i])+"first\n")
    if ytotalneg[i]!=None:
        total_results[i] = prim[ind]-ytotalneg[i]
        print(str(omegas_l1[i])+"second\n")
# Out:
# 0.05first
#
# 0.06first
#
# 0.07first
#
# 0.09first
#
# 0.11first
#
# 0.14first
#
# 0.17first
#
# 0.2first
#
# 0.25first
#
# 0.31first
#
# 0.37first
#
# 0.46first
#
# 0.56first
#
# 0.68first
#
# 0.84first
#
# 1.02first
#
# 1.25first
#
# 1.5first
#
# 1.75first
#
# 2.0first
#
# 2.25first
#
# 2.5first
#
# 2.75first
#
# 3.0first
#
# 3.25first
#
# 3.5first
#
# 3.75first
#
# 4.0first
#
# 4.25first
#
# 4.5first
#
# 4.75first
#
# 5.0first
#
# 5.25first
#
# 5.5first
#
# 5.75second
#
# 6.0second
#
# 6.25second
#
# 6.5second
#
# 6.75second
#
# 7.0second
#
# 7.25second
#
# 7.5second
#
# 7.75second
#
# 8.0second
#
# 8.5second
#
# 9.0second
#
# 9.5second
#
# 10.0second
#
# 10.5second
#
# 11.0second
#
# 11.5second
#
# 12.0second
#
# 12.5second
#
# 13.0second
#
# 13.5second
#
# 14.0second
#
# 14.5second
#
# 15.0second

# %%
np.save("PBHTotalDataArrays/M1totalcposN1Corrected",ytotalpos,allow_pickle=True)
np.save("PBHTotalDataArrays/M1totalcnegN1Corrected",ytotalneg,allow_pickle=True)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(8,4))
ax.plot(omegas_l1,total_results,color='black',label='total',linestyle ='-.')
ax.plot(om,prim,label ='primary',color ="orange")
ax.plot(omegas_l1,ytotalpos,label ='secondary emisson',color ='deeppink')
ax.plot(omegas_l1,ytotalneg,label ='secondary absorption',linestyle='--',color = 'deeppink')
ax.set_xscale('log')
ax.set_ylim((1.e-8,1.e-2))
ax.set_yscale('log')
plt.xlim(0.04,16)
plt.xlabel(r"$\omega$ (in units $T_{H})$",size=12)
plt.ylabel(r"$\frac{dN_{\gamma}}{d\omega dt}$",size=17)
plt.title(r"Spectrum results For $\mathcal{O}(1)$ and $\mathcal{O}(\alpha)$, $M=1\times 10^{21}m_{planck}$")
plt.legend()
plt.savefig("Order0andAlphaM1.pdf",bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(12,6))

ax.plot(om,om*prim,label ='$\mathcal{O}(1)$',linewidth=2,color ="orange")
ax.plot(omegas_l1[:33],omegas_l1[:33]*np.array(ytotalpos[:33]),linewidth=2,label =r'$\mathcal{O}(\alpha)$ emisson',color ='deeppink')
ax.plot(omegas_l1[34:],omegas_l1[34:]*np.array(ytotalneg[34:]),linewidth=2,label =r'$\mathcal{O}(\alpha)$ absorption',linestyle='--',color = 'deeppink')
ax.plot(omegas_l1,omegas_l1*total_results,color='black',label='total',linestyle ='-.')
ax.set_xscale('log')
ax.set_ylim((1.e-8,1.e-2))
ax.set_yscale('log')
plt.xlim(0.04,16)
plt.xlabel(r"$\omega/T_{H}$",size=15)
plt.ylabel(r"$\left(\frac{\omega}{T_{H}}\right) \frac{dN_{\gamma}}{d\omega dt}$",size=18)
plt.title(r"$M=2\times 10^{16} g$",size=15)
plt.legend(fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.savefig("Order1andAlphaM1",bbox_inches='tight')
plt.show()

# %%
omegas_l1[0]*np.array(ytotalpos[0])
# Out:
# 0.00010421076741841856

# %%
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(8,4))
y1listpos_o =[]
y1listneg_o =[]
y2listpos_o =[]
y2listneg_o =[]


y3listpos_o =[]
y3listneg_o =[]
y4listpos_o =[]
y4listneg_o =[]
y5listpos_o =[]
y5listneg_o =[]

ytotalpos_o =[]
ytotalneg_o =[]


color1 =[]
for i in range(0,len(omegas_l1),1):
    
    y1 =(np.sum(array_results_l1[2*i][:])+np.sum(array_results_l1[2*i +1][:]))/m1_rescale[i,1]
    if y1>0:
        y1listpos_o.append(np.abs(y1)*omegas_l1[i])
        y1listneg_o.append(None)
    if y1<0:
        y1listpos_o.append(None)
        y1listneg_o.append(np.abs(y1)*omegas_l1[i])
    y2 =(np.sum(array_results_l2[2*i][:])+np.sum(array_results_l2[2*i +1][:]))/m1_rescale[i,2]
    if y2>0:
        y2listpos_o.append(np.abs(y2)*omegas_l1[i])
        y2listneg_o.append(None)
    if y2<0:
        y2listpos_o.append(None)
        y2listneg_o.append(np.abs(y2)*omegas_l1[i])
    
    y3 =(np.sum(array_results_l3[2*i][:])+np.sum(array_results_l3[2*i +1][:]))/m1_rescale[i,3]
    if y3>0:
        y3listpos_o.append(np.abs(y3)*omegas_l1[i])
        y3listneg_o.append(None)
    if y3<0:
        y3listpos_o.append(None)
        y3listneg_o.append(np.abs(y3)*omegas_l1[i])
    y4 =(np.sum(array_results_l4[2*i][:])+np.sum(array_results_l4[2*i +1][:]))/m1_rescale[i,4]
    if y4>0:
        y4listpos_o.append(np.abs(y4)*omegas_l1[i])
        y4listneg_o.append(None)
    if y4<0:
        y4listpos_o.append(None)
        y4listneg_o.append(np.abs(y4)*omegas_l1[i])
    y5 =(np.sum(array_results_l5[2*i][:])+np.sum(array_results_l5[2*i +1][:]))/m1_rescale[i,5]
    if y5>0:
        y5listpos_o.append(np.abs(y5)*omegas_l1[i])
        y5listneg_o.append(None)
    if y5<0:
        y5listpos_o.append(None)
        y5listneg_o.append(np.abs(y5)*omegas_l1[i])
       
    yall =y1+y2+y3+y4+y5
    if yall>0:
        ytotalpos_o.append(np.abs(yall)*omegas_l1[i])
        ytotalneg_o.append(None)
    if yall<0:
        ytotalpos_o.append(None)
        ytotalneg_o.append(np.abs(yall)*omegas_l1[i])
        
    
    
    #color1.append('r' if y1<0 else 'g')


    
ax.plot(omegas_l1,np.array(y1listpos_o), label = 'l1', color ='r',linestyle='-')
ax.plot(omegas_l1,np.array(y1listneg_o), label = 'l1', color ='r',linestyle='--')
ax.plot(omegas_l1,np.array(y2listpos_o), label = 'l2', color ='g',linestyle='-')
ax.plot(omegas_l1,np.array(y2listneg_o), label = 'l2', color ='g',linestyle='--')
ax.plot(omegas_l3,np.array(y3listpos_o), label = 'l3', color ='b',linestyle='-')
ax.plot(omegas_l3,np.array(y3listneg_o), label = 'l3', color ='b',linestyle='--')
ax.plot(omegas_l4,np.array(y4listpos_o), label = 'l4', color ='orange',linestyle='-')
ax.plot(omegas_l4,np.array(y4listneg_o), label = 'l4', color ='orange',linestyle='--')
ax.plot(omegas_l4,np.array(y5listpos_o), label = 'l5', color ='magenta',linestyle='-')
ax.plot(omegas_l4,np.array(y5listneg_o), label = 'l5', color ='magenta',linestyle='--')

ax.plot(omegas_l1,np.array(ytotalpos_o), label = 'sum', color ='black',linestyle='-')
ax.plot(omegas_l1,np.array(ytotalneg_o), label = 'sum', color ='black',linestyle='--')

#for i in range(0,len(omegas_l2)-1,1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*(np.abs(np.sum(array_results_l2[2*i][:]))+np.abs(np.sum(array_results_l2[2*i +1][:]))), label = 'l2', color='b')

#for i in range(0,len(omegas_l2)-,1):
#    ax[0].scatter(omegas_l2[i],4*np.pi*((np.abs(np.sum(array_results_l2[2*i][:]))+np.abs(np.sum(array_results_l2[2*i +1][:])))+(np.abs(np.sum(array_results_l1[2*i][:]))+np.abs(np.sum(array_results_l1[2*i +1][:])))), label = 'summed', color='g')

ax.set_xscale('log')
ax.set_yscale('log')

ax.scatter(5.25,1.2661721787952992e-07*5.75,color='red',marker='x')
ax.scatter(5.5,2.580926024607328e-07*5.5,color='red',marker='x')
ax.scatter(9.5,3.8644539932221423e-10*9.5,color='g',marker='x')
ax.scatter(10.0,6.166298497697745e-09*10,color='g',marker='x')
ax.scatter(13.5,4.257663153588525e-11*13.5,color='b',marker='x')
ax.scatter(14.0,2.2699690865799916e-11*14,color='b',marker='x')
ax.scatter(5.5,1.4484646439527064e-08*5.5,color='black',marker='x')
ax.scatter(5.75,3.5051506468999694e-07*5.75,color='black',marker='x')



handles, labels = ax.get_legend_handles_labels()
#ax.legend([handles[0],handles[1],handles[2],handles[3],handles[4],handles[5],handles[6],handles[7],handles[8],handles[9]],['l=1 positive','l=1 negative','l=2 positive','l=2 negative','l=3 positive','l=3 negative','l=4 positive','l=4 negative','summed positive','summed negative'])
#ax.legend([handles[0],handles[1]],['l=1 positive','l=1 negative'])

handles, labels = ax.get_legend_handles_labels()
ax.legend([handles[0],handles[2],handles[4],handles[6],handles[8],handles[10]],['$\ell=1$','$\ell=1$','$\ell=1$','$\ell=1$','$\ell=1$'],fontsize=12)


ax.set_xlim(.04,16)
#ax.set_ylim(1e-10,1e-2)

"""for i in range(0,len(omegas_l2),1):
    val_l2 = (np.abs(np.sum(array_results_l2[2*i][:]))+np.abs(np.sum(array_results_l2[2*i +1][:])))
    val_l1 = (np.abs(np.sum(array_results_l1[2*i][:]))+np.abs(np.sum(array_results_l1[2*i +1][:])))
    val = val_l1/val_l2
    ax[1].scatter(omegas_l2[i],val, label = 'l1/l2', color='y')
"""

#ax[1].set_ylabel('l1/l2')

plt.xlabel('$\omega/T_{H}$',size=14)
plt.ylabel(r'$ \left(\frac{\omega}{T_{H}}\right) \frac{dN_{\gamma}}{d\omega dt}$',size=17)
ax.set_title(r' $M=1\times 10^{21}m_{planck}$',size=14)
#ax.legend(bbox_to_anchor=(0.7, 0.5, 0.5, 0.5))
#plt.savefig('totall1and3.pdf',bbox_inches='tight')
plt.ylim((1e-11,5e-4))
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.savefig("PBH/absnegandposFIXED.pdf",bbox_inches='tight')


#plt.savefig('totall1and3.pdf',bbox_inches='tight')
#plt.savefig("PBH/absnegandpos.pdf",bbox_inches='tight')
plt.show()

# %%
#can only do this for M= 4e21 rn since other electron wfs got deleted so move this there

# %%
def dNi_FSR_per_dE_gamma(h,omega):
    x = omega/h
    mu = 4.1796514508e-23
    mu_ = mu/(2*h)
    P_x = (1 +(1-x)**2)/x
    return alpha*P_x * (np.log((1-x)/mu_**2)-1)/np.pi/2/h

# %%
def dNi_b21_dE_gamma(h,omega):
    coeff = alpha/np.pi
    mu = 4.1796514508e-23
    nu = np.sqrt(h**2 - mu**2)/h
    return coeff *((1+nu**2)*np.log((1+nu)/(1-nu))/(2*nu) -1)/omega

# %%
def dNi_b18_dE_gamma(h,omega):
    coeff = alpha/np.pi
    mu = 4.1796514508e-23
    nu = np.sqrt(h**2 - mu**2)/h
    return coeff *(np.log((1+nu)/(1-nu))/nu -2)/omega

# %%
def dNi_b19_dE_gamma(h,omega):
    coeff = alpha/np.pi
    mu = 4.1796514508e-23
    nu = np.sqrt(h**2 - mu**2)/h
    return coeff *(np.log(4/(1-nu**2))-1)/omega

# %%
Ts = np.load("TransmissionCoeffsElectron.npy")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-133-1858f4613bd6> in <module>
# ----> 1 Ts = np.load("TransmissionCoeffsElectron.npy")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: 'TransmissionCoeffsElectron.npy'

# %%
alpha=  1/137.036

# %%
def T_coeff(k,h_ind):
    if k>0:
        return Ts[k-1][h_ind]
    if k<0:
        return Ts[np.abs(k)+10-1][h_ind]

# %%
def dNi_dEdt(h_ind):
    h = np.linspace(0.01,20,2000)
    val = 0.0
    for k in range(-10,10,1):
        if k!=0:
            val += 2*(2* np.abs(k))*np.abs(T_coeff(k,h_ind))**2 /((np.exp(h[h_ind])+1))/2/np.pi
    return val

# %%
def Spectra_from_coogan(omega_scale):
    h = np.linspace(0.01,20,2000)
    inte = 0.0
    for i in range(1,len(h)-1,1):
        #print(i)
        #print(dNi_dEdt(i))
        if h[i] > mu*8*np.pi*M and h[i] > omega_scale*1.0001:
            inte += 0.5*(dNi_dEdt(i)*dNi_FSR_per_dE_gamma(h[i]*Temp,omega_scale*Temp)+dNi_dEdt(i+1)
                         *dNi_FSR_per_dE_gamma(h[i+1]*Temp,omega_scale*Temp))*0.01*Temp
       
    return inte

# %%
def Spectra_b19_other(omega_scale):
    h = np.linspace(0.01,20,2000)
    inte = 0.0
    for i in range(1,len(h)-1,1):
        #print(i)
        #print(dNi_dEdt(i))
        if h[i] > mu*8*np.pi*M and h[i] > omega_scale*1.0001:
            inte += 0.5*(dNi_dEdt(i)*dNi_b19_dE_gamma(h[i]*Temp,omega_scale*Temp)+dNi_dEdt(i+1)
                         *dNi_b19_dE_gamma(h[i+1]*Temp,omega_scale*Temp))*0.01*Temp
       
    return inte

# %%
def Spectra_b21_other(omega_scale):
    h = np.linspace(0.01,20,2000)
    inte = 0.0
    for i in range(1,len(h)-1,1):
        #print(i)
        #print(dNi_dEdt(i))
        if h[i] > mu*8*np.pi*M and h[i] > omega_scale*1.0001:
            inte += 0.5*(dNi_dEdt(i)*dNi_b21_dE_gamma(h[i]*Temp,omega_scale*Temp)+dNi_dEdt(i+1)
                         *dNi_b21_dE_gamma(h[i+1]*Temp,omega_scale*Temp))*0.01*Temp
       
    return inte

# %%
def Spectra_b18_other(omega_scale):
    h = np.linspace(0.01,20,2000)
    inte = 0.0
    for i in range(1,len(h)-1,1):
        #print(i)
        #print(dNi_dEdt(i))
        if h[i] > mu*8*np.pi*M and h[i] > omega_scale*1.0001:
            inte += 0.5*(dNi_dEdt(i)*dNi_b18_dE_gamma(h[i]*Temp,omega_scale*Temp)+dNi_dEdt(i+1)
                         *dNi_b18_dE_gamma(h[i+1]*Temp,omega_scale*Temp))*0.01*Temp
       
    return inte

# %%
test1 = np.zeros(len(omegas_l1))
count=0
for i in omegas_l1:
    test1[count] = Spectra_from_coogan(i)
    count+=1

# %%
test2 = np.zeros(len(omegas_l1))
count=0
for i in omegas_l1:
    test2[count] = Spectra_b21_other(i)
    count+=1

# %%
test3 = np.zeros(len(omegas_l1))
count=0
for i in omegas_l1:
    test3[count] = Spectra_b19_other(i)
    count+=1

# %%
test4 = np.zeros(len(omegas_l1))
count=0
for i in omegas_l1:
    test4[count] = Spectra_b18_other(i)
    count+=1

# %%
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(14,6))
plt.plot(omegas_l1,test1,label="Coogan Paper (Eq 6)")
plt.plot(omegas_l1,test2,label="Double Particle/2 (B21)")
plt.plot(omegas_l1,test3,label = "Coogan approx (B19)")
plt.plot(omegas_l1,test4, label = 'Single Particle (B18)')

for i in range(0,len(omegas_l1),1):
    ax.scatter(omegas_l1[i],((np.sum(array_results_l1[2*i][:]))+(np.sum(array_results_l1[2*i +1][:]))), color='r')
plt.yscale('log')
plt.xscale('log')
plt.xlabel('$\omega/T_{H}$')
plt.ylabel("$dN/d\omega dt$")
plt.legend()
plt.title("M1")
#plt.savefig('SpectraComparisonLowFrequency.pdf')
plt.show()

# %%
mu = 4.1796514508e-23

# %%
def dNi_FSR_per_dE_gamma(h,omega):
    x = omega/h
    mu = 4.1796514508e-23
    mu_ = mu/(2*h)
    P_x = (1 +(1-x)**2)/x
    return alpha*P_x * (np.log((1-x)/mu_**2)-1)/np.pi/2/h

# %%
def dNi_b21_dE_gamma(h,omega):
    coeff = alpha/np.pi
    mu = 4.1796514508e-23
    nu = np.sqrt(h**2 - mu**2)/h
    return coeff *((1+nu**2)*np.log((1+nu)/(1-nu))/(2*nu) -1)/omega

# %%
def dNi_b18_dE_gamma(h,omega):
    coeff = alpha/np.pi
    mu = 4.1796514508e-23
    nu = np.sqrt(h**2 - mu**2)/h
    return coeff *(np.log((1+nu)/(1-nu))/nu -2)/omega

# %%
def dNi_b19_dE_gamma(h,omega):
    coeff = alpha/np.pi
    mu = 4.1796514508e-23
    nu = np.sqrt(h**2 - mu**2)/h
    return coeff *(np.log(4/(1-nu**2))-1)/omega

# %%
Ts = np.load("TransmissionCoeffsElectronM1.npy")

# %%
alpha=  1/137.036

# %%
def T_coeff(k,h_ind):
    if k>0:
        return Ts[k-1][h_ind]
    if k<0:
        return Ts[np.abs(k)+10-1][h_ind]

# %%
def dNi_dEdt(h_ind):
    h = np.linspace(0.01,20,2000)
    val = 0.0
    for k in range(-10,10,1):
        if k!=0:
            val += 2*(2* np.abs(k))*np.abs(T_coeff(k,h_ind))**2 /((np.exp(h[h_ind])+1))/2/np.pi
    return val

# %%
def Spectra_from_coogan(omega_scale):
    h = np.linspace(0.01,20,2000)
    inte = 0.0
    for i in range(1,len(h)-1,1):
        #print(i)
        #print(dNi_dEdt(i))
        if h[i] > mu*8*np.pi*M and h[i] > omega_scale*1.0001:
            inte += 0.5*(dNi_dEdt(i)*dNi_FSR_per_dE_gamma(h[i]*Temp,omega_scale*Temp)+dNi_dEdt(i+1)
                         *dNi_FSR_per_dE_gamma(h[i+1]*Temp,omega_scale*Temp))*0.01*Temp
       
    return inte

# %%
def Spectra_b19_other(omega_scale):
    h = np.linspace(0.01,20,2000)
    inte = 0.0
    for i in range(1,len(h)-1,1):
        #print(i)
        #print(dNi_dEdt(i))
        if h[i] > mu*8*np.pi*M and h[i] > omega_scale*1.0001:
            inte += 0.5*(dNi_dEdt(i)*dNi_b19_dE_gamma(h[i]*Temp,omega_scale*Temp)+dNi_dEdt(i+1)
                         *dNi_b19_dE_gamma(h[i+1]*Temp,omega_scale*Temp))*0.01*Temp
       
    return inte

# %%
def Spectra_b21_other(omega_scale):
    h = np.linspace(0.01,20,2000)
    inte = 0.0
    for i in range(1,len(h)-1,1):
        #print(i)
        #print(dNi_dEdt(i))
        if h[i] > mu*8*np.pi*M and h[i] > omega_scale*1.0001:
            inte += 0.5*(dNi_dEdt(i)*dNi_b21_dE_gamma(h[i]*Temp,omega_scale*Temp)+dNi_dEdt(i+1)
                         *dNi_b21_dE_gamma(h[i+1]*Temp,omega_scale*Temp))*0.01*Temp
       
    return inte

# %%
def Spectra_b18_other(omega_scale):
    h = np.linspace(0.01,20,2000)
    inte = 0.0
    for i in range(1,len(h)-1,1):
        #print(i)
        #print(dNi_dEdt(i))
        if h[i] > mu*8*np.pi*M and h[i] > omega_scale*1.0001:
            inte += 0.5*(dNi_dEdt(i)*dNi_b18_dE_gamma(h[i]*Temp,omega_scale*Temp)+dNi_dEdt(i+1)
                         *dNi_b18_dE_gamma(h[i+1]*Temp,omega_scale*Temp))*0.01*Temp
       
    return inte

# %%
test1 = np.zeros(len(omegas_l1))
count=0
for i in omegas_l1:
    test1[count] = Spectra_from_coogan(i)
    count+=1

# %%
test2 = np.zeros(len(omegas_l1))
count=0
for i in omegas_l1:
    test2[count] = Spectra_b21_other(i)
    count+=1

# %%
test3 = np.zeros(len(omegas_l1))
count=0
for i in omegas_l1:
    test3[count] = Spectra_b19_other(i)
    count+=1

# %%
test4 = np.zeros(len(omegas_l1))
count=0
for i in omegas_l1:
    test4[count] = Spectra_b18_other(i)
    count+=1

# %%
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(14,6))
plt.plot(omegas_l1,test1,label="Coogan Paper (Eq 6)")
plt.plot(omegas_l1,test2,label="Double Particle/2 (B21)")
plt.plot(omegas_l1,test3,label = "Coogan approx (B19)")
plt.plot(omegas_l1,test4, label = 'Single Particle (B18)')

ax.scatter(omegas_l1,ytotalpos, color='r')
ax.scatter(omegas_l1,ytotalneg, color='r',marker='x')
plt.yscale('log')
plt.xscale('log')
plt.xlabel('$\omega/T_{H}$')
plt.ylabel("$dN/d\omega dt$")

plt.legend()
plt.savefig('SpectraComparisonLowFrequencyM1.pdf')
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(8,4))
plt.plot(omegas_l1,test1*omegas_l1,label="Coogan Paper",linestyle='--')

plt.plot(omegas_l1,test3*omegas_l1,label = "Log approx",linestyle='-.')
plt.plot(omegas_l1,test2*omegas_l1,label="Double Particle/2 ",linestyle=':')
plt.plot(omegas_l1,test4*omegas_l1, label = 'Single Particle')


ax.scatter(omegas_l1,ytotalpos_o, color='r')
ax.scatter(omegas_l1,ytotalneg_o, color='r',marker='x')
plt.ylim(0,2e-4)
plt.ticklabel_format(axis='both', style='sci', scilimits=(0,0))
#plt.yscale('log')
plt.xscale('log')
plt.xlabel('$\omega/T_{H}$',size=13)
plt.title(r'$M=1\times 10^{21} m_{planck}$')
plt.ylabel(r"$\left(\frac{\omega}{T_{H}}\right) \frac{dN_{\gamma}}{d\omega dt}$",size=14)
plt.legend()

plt.savefig('EnergyComparisonLowFrequencyM1.pdf')
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(8,4))
#plt.plot(omegas_l1,test1*omegas_l1,label="Coogan Paper (Eq 6)",linestyle='--')

#plt.plot(omegas_l1,test3*omegas_l1,label = "Coogan approx (B19)",linestyle='-.')
#plt.plot(omegas_l1,test2*omegas_l1,label="Double Particle/2 (B21)",linestyle=':')



ax.scatter(omegas_l1[:10],100*np.abs(-1*np.array(ytotalpos_o[:10])+test4[:10]*omegas_l1[:10])/(test4[:10]*omegas_l1[:10]), label = 'Single Particle (B18)', color='r')
#ax.scatter(omegas_l1,ytotalneg_o, color='r',marker='x')
#plt.ylim(1e-5,3e-4)
#plt.yscale('log')
#plt.xscale('log')
plt.xlabel('$\omega/T_{H}$',size=13)
plt.title(r'$M=1\times 10^{21} m_{planck}$')
plt.ylabel("100*(single particle - data)/single particle",size=14)
#plt.legend()

#plt.savefig('EnergyComparisonLowFrequencyM1.pdf')
plt.show()

# %%
ytotalpos_o[0]
# Out:
# 0.00010421076741841856

# %%
test4[0]*omegas_l1[0]
# Out:
# 0.00011698462671117372

# %%
(0.00010421076741841856 - 0.00011698462671117372)/0.00010421076741841856
# Out:
# -0.12257715406188889

# %%
from scipy.stats import linregress

# %%
res = linregress(omegas_l1[0:8],np.array(100*np.abs(-1*np.array(ytotalpos_o[:8])+test4[:8]*omegas_l1[:8])/(test4[:8]*omegas_l1[:8])))

# %%
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(8,4))
#plt.plot(omegas_l1,test1*omegas_l1,label="Coogan Paper (Eq 6)",linestyle='--')

#plt.plot(omegas_l1,test3*omegas_l1,label = "Coogan approx (B19)",linestyle='-.')
#plt.plot(omegas_l1,test2*omegas_l1,label="Double Particle/2 (B21)",linestyle=':')



ax.scatter(omegas_l1[:10],100*np.abs(-1*np.array(ytotalpos_o[:10])+test4[:10]*omegas_l1[:10])/(test4[:10]*omegas_l1[:10]), label = 'Single Particle (B18)', color='r')
plt.plot(omegas_l1[0:10],res.intercept + res.slope*np.array(omegas_l1[:10]))
#ax.scatter(omegas_l1,ytotalneg_o, color='r',marker='x')
#plt.ylim(1e-5,3e-4)
#plt.yscale('log')
#plt.xscale('log')
plt.xlabel('$\omega/T_{H}$',size=13)
plt.title(r'$M=1\times 10^{21} m_{planck}$')
plt.ylabel("100*(single particle - data)/single particle",size=14)
#plt.legend()

#plt.savefig('EnergyComparisonLowFrequencyM1.pdf')
plt.show()
print('slope is :' + str(res.slope))
print('intercept is :' + str(res.intercept))
# Out:
# slope is :27.93766003288589
# intercept is :9.228298872405533
